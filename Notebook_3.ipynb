# %% [markdown]
# # Imports

# %%
from utils import NounParser,VerbParser,AdjectiveNumeralParser
import pandas as pd
from lingpy import *
from lingpy.sequence.sound_classes import check_tokens
from lingpy.compare.util import (mutual_coverage_check, mutual_coverage_subset)
from lingpy.compare.sanity import average_coverage
from lingpy.compare.sanity import synonymy
from segments.tokenizer import Tokenizer
from collections import defaultdict
import matplotlib.pyplot as plt
import os
from pprint import pprint
from lingpy.evaluate.acd import bcubes
from lingpy.compare.partial import Partial

# %% [markdown]
# # Functions

# %%
#dictionaries, sets and lists
replacement_dict={"DogulDomBendiely":"DogulDomKundialang",
                  "JamsayGourou":"JamsayDouentza",
                  "JamsayMondoro":"JamsayDouentza",
                  "PergeTegu":"JamsayDouentza",
                  "TomoKanSegue":"TomoKanDiangassagou"}

new_name={'TommoSoTongoTongo': "TommoSo",
         "BonduSoNajamba": "BonduSo",
          
         "TomoKanDiangassagou": "TomoKan",
         "TomoKanSegue":"TomoKan",
          
         "DogulDomKundialang": "DogulDom",
         'DogulDomBendiely':"DogulDom",
          
          "JamsayDouentza":"Jamsay",
         'JamsayGourou':"Jamsay",
         'JamsayMondoro':"Jamsay",
          "PergeTegu": "Jamsay"}
replacements={'j':'j','á':'a','w': 'w','d':'d','ì': 'i','-':'-','m':'m',':': ':','b': 'b','à': 'a','r':'r',
              's':'s','ɛ':'ɛ','k':'k','ɔ': 'ɔ','l':'l','g':'g','ù':'u','ú':'u','è':'e','í':'i','ŋ': 'ŋ',
              'ó':'o','n': 'n','ⁿ': '\u207F','ý':'y','z':'z','ɲ':'\u0272','y':'y','ò':'o','ɣ': 'ɣ',
              'ʔ': '\u0294','ǎ':'a','â':'a','é':'e','ě':'e','ê':'e','î':'i','ǐ': 'i','ǹ': 'n','û':'u',
              'š':'s','ə': 'ə','p':'p','ǒ':'o','t':'t','e':'e','ô':'o','ǔ':'u','ń':'n','ỳ':'y','c':'c',
              'h':'h','f': 'f','ʷ': '\u02B7','i':'i','?': '\u0294','x':'x','o':'o','a':'a','ɗ': 'ɗ',
              'ḱ':'k','ǽ':'ae','ẁ':'w','ʒ': '\u0292','v':'v','ḿ':'m','ẃ':'w','å':'a','u':'u','q':'q',
              'ʄ': 'ƒ','ɓ':'b','ᵇ': '\u1D47','ʸ':'\u02B9','Ǹ':'n','V': 'v', " ": " "}

#Instantiating parser objects
noun_parser=NounParser()
verb_parser=VerbParser()
adj_num_parser=AdjectiveNumeralParser()


def prior_forms(row):
    """
    puts all forms that have been parsed into a single column
    """
    if pd.isna(row["POS"]):  
        return None
    elif row["POS"] in ["noun", "numeral", "adjective"]:
        form = str(row["SINGULAR"]) if isinstance(row["SINGULAR"], str) else ""
        return form
    elif row["POS"] == "verb":
        verb = row["FORM"]
        if pd.isna(verb):
            return None
        else:
            return verb
    else:
        form = str(row["SINGULAR"]) if isinstance(row["SINGULAR"], str) else ""
        return form




def parsing_data(row):
    """
    puts all forms that have been parsed into a single column
    """
    if pd.isna(row["POS"]):  
        return None
    elif row["POS"]=="noun":
        noun=row["BEFORE_PARSE"]
        if pd.isna(noun):
            return None
        else:
            noun=(noun_parser.identified_suffixes(
            noun_parser.hyphen_space(
                noun_parser.nasalized_stops(
                    noun_parser.cvcv_segmentation(
                        noun_parser.parse_noun_durationals(
                            noun_parser.parse_off_final_nasals(
                                noun_parser.existing_parses(
                                    adj_num_parser.y_suffixes(noun.strip("()/_")))))))))) if (noun.endswith("y") or (noun.endswith("ⁿ") and noun[-2]=="y")) else \
                            (noun_parser.identified_suffixes(
                                noun_parser.hyphen_space(
                                    noun_parser.nasalized_stops(
                                        noun_parser.cvcv_segmentation(
                                            noun_parser.parse_noun_durationals(
                                                noun_parser.parse_off_final_nasals(
                                                    noun_parser.existing_parses(noun.strip("()/_")))))))))
            return noun
            
    elif row["POS"] == "numeral" or row["POS"] == "adjective":
        form = row["BEFORE_PARSE"]
        if pd.isna(form):
            return None
        else:
            form=adj_num_parser.miscellaneous(
            adj_num_parser.switch_hyphen_position(
                adj_num_parser.replace_hyphens_keep_last(
                    adj_num_parser.y_suffixes(
                        adj_num_parser.isolating_suffixes(
                            adj_num_parser.parse_verb_durationals(
                                adj_num_parser.existing_parses(form.strip("()/_"))))))))
            return form
    elif row["POS"] == "verb":
        verb = row["BEFORE_PARSE"]
        if pd.isna(verb):
            return None
        else:
            verb=verb_parser.post_editing_short_strings(
            verb_parser.segment_cvcs(
                verb_parser.parse_verb_durationals(
                    verb_parser.existing_parses(verb.strip(")(_")))))
            return verb
    else:
        form = str(row["BEFORE_PARSE"]) if isinstance(row["BEFORE_PARSE"], str) else ""
        return noun_parser.parse_noun_durationals(form)



def data_prep_for_ortho_profile(input_file):
    """
    prepares data so that command line can run on it to output an orthography profile
    """
    df = pd.read_csv(input_file, delimiter='\t')
    df["ID"]=df["ID"].astype(str)
    df['ID'] = pd.to_numeric(df['ID'].str.replace(',', '').str.replace('.', ''), errors='coerce')
    df = df.dropna(subset=['ID'])
    df['ID'] = df['ID'].astype(int)
    return df.to_csv('heathdogon2.tsv', index=False, sep='\t')



def add_tab_after_quote(input_file, output_file, encoding='utf-8'):
    """
    creates a tsv file in which quotation characters are eliminated
    input_file: orthography profile created via the command line: $ lingpy profile -i heathdogon2.tsv -o  P_created-profile.tsv --column=ipa
    """
    with open(input_file, 'r', encoding=encoding) as infile, open(output_file, 'w', encoding=encoding) as outfile:
        for line in infile:
            new_line = ''
            quote_added = False
            for char in line:
                if char == '"':
                    new_line += char + '\t'
                    quote_added = True
                else:
                    new_line += char
                    if quote_added:
                        quote_added = False
            outfile.write(new_line)


def merges(row, concepts, replacement_dict):
    """
    merges various rows based on the presence of a gloss
    """
    
    if not isinstance(row["CONCEPT"], str) or not isinstance(row["DOCULECT"], str):
        # Handle unexpected types
        return None
    
    for concept in concepts:
        for key, value in replacement_dict.items():
            if concept in row["CONCEPT"] and row["DOCULECT"] == value and row["DOCULECT"] == key:
                return row["DOCULECT"] == value
            elif concept in row["CONCEPT"] and row["DOCULECT"] != value:
                if row["CONCEPT"] == key:
                    return row["CONCEPT"] == key
            elif concept in row["CONCEPT"] and row["DOCULECT"] != value or row["DOCULECT"] != key:
                return row



def change_name(name, new_name):
    """
    changes the names of various language dialects into language
    """
    for key, value in new_name.items():  
        keep_name = value
        discard_name = key
        if name == discard_name:  
            return keep_name
    return name


def remove_tones(word):
    """
    removes tones and keeps only segments
    """
    if word is None:
        return None

    new_word=""
    for letter in word:
        if letter in replacements.keys():
            new_word += replacements.get(letter)
        elif letter==" ":
            new_word +="#"
        else:
            new_word +=""
    return new_word

def remove_spaces(word):
    if word is None:
        return None
    new_word=""
    for letter in word:
        if letter==" ":
            new_word += ""
        else:
            new_word += letter
    return new_word

# %% [markdown]
# # Loading data

# %%
#loading data
pd.set_option('display.max_rows', None)
path = r"D:\ERC_Bang\Tasks\data_cleaning" 
os.chdir(path)
data = pd.read_csv("data.tsv", sep="\t", encoding="utf-8")
list_to_drop=["ID","FRENCH", "ENGLISH_SHORT", "FRENCH_SHORT", "ENGLISH_CATEGORY", "FRENCH_CATEGORY", "PARSED FORM", "MCF", "RECONSTRUCTION", "NOTE", "NOTES","Unnamed: 18", "Unnamed: 19", "Unnamed: 20", "Unnamed: 21", "COGID", "COGIDS", "Unnamed: 24"]
data=data.drop(list_to_drop, axis=1)

# %%
#visualizing data
data.head()
# Out:
#    VARID          DOCULECT                             GLOSS  \
# 0    0.0         BankanTey  domestic animal (esp. livestock)
# 1    1.0         BankanTey  domestic animal (esp. livestock)
# 2    0.0            BenTey  domestic animal (esp. livestock)
# 3    0.0            Bunoge  domestic animal (esp. livestock)
# 4    0.0  DogulDomBendiely  domestic animal (esp. livestock)
#
#                         VALUE_ORG  SINGULAR     PLURAL FORM    CONCEPT   POS
# 0  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   jáwdì-m      jáwdì  NaN  LIVESTOCK  noun
# 1  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   dá:bà-m      dá:bà  NaN  LIVESTOCK  noun
# 2                àrsɛ̌:-m\\àrsɛ̌:  àrsɛ̌:-m     àrsɛ̌:  NaN  LIVESTOCK  noun
# 3                         kɔ́mbɔ̀   kɔ́mbɔ̀   kɔmbɔ=gè  NaN  LIVESTOCK  noun
# 4               bɛ́lɛ̀g, bɛ́lɛ̀gù  bɛ́lɛ̀-g  bɛlɛ-g-yà  NaN  LIVESTOCK  noun

# %% [markdown]
# # Creating new columns

# %%
data["BEFORE_PARSE"]=data.apply(prior_forms, axis=1) #put all eligible data in one columns

# %%
data.head()
# Out:
#    VARID          DOCULECT                             GLOSS  \
# 0    0.0         BankanTey  domestic animal (esp. livestock)
# 1    1.0         BankanTey  domestic animal (esp. livestock)
# 2    0.0            BenTey  domestic animal (esp. livestock)
# 3    0.0            Bunoge  domestic animal (esp. livestock)
# 4    0.0  DogulDomBendiely  domestic animal (esp. livestock)
#
#                         VALUE_ORG  SINGULAR     PLURAL FORM    CONCEPT   POS  \
# 0  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   jáwdì-m      jáwdì  NaN  LIVESTOCK  noun
# 1  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   dá:bà-m      dá:bà  NaN  LIVESTOCK  noun
# 2                àrsɛ̌:-m\\àrsɛ̌:  àrsɛ̌:-m     àrsɛ̌:  NaN  LIVESTOCK  noun
# 3                         kɔ́mbɔ̀   kɔ́mbɔ̀   kɔmbɔ=gè  NaN  LIVESTOCK  noun
# 4               bɛ́lɛ̀g, bɛ́lɛ̀gù  bɛ́lɛ̀-g  bɛlɛ-g-yà  NaN  LIVESTOCK  noun
#
#   BEFORE_PARSE
# 0      jáwdì-m
# 1      dá:bà-m
# 2     àrsɛ̌:-m
# 3      kɔ́mbɔ̀
# 4     bɛ́lɛ̀-g

# %%
data["PARSED"]=data.apply(parsing_data,axis=1)#parse all eligible data

# %%
data.head()
# Out:
#    VARID          DOCULECT                             GLOSS  \
# 0    0.0         BankanTey  domestic animal (esp. livestock)
# 1    1.0         BankanTey  domestic animal (esp. livestock)
# 2    0.0            BenTey  domestic animal (esp. livestock)
# 3    0.0            Bunoge  domestic animal (esp. livestock)
# 4    0.0  DogulDomBendiely  domestic animal (esp. livestock)
#
#                         VALUE_ORG  SINGULAR     PLURAL FORM    CONCEPT   POS  \
# 0  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   jáwdì-m      jáwdì  NaN  LIVESTOCK  noun
# 1  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   dá:bà-m      dá:bà  NaN  LIVESTOCK  noun
# 2                àrsɛ̌:-m\\àrsɛ̌:  àrsɛ̌:-m     àrsɛ̌:  NaN  LIVESTOCK  noun
# 3                         kɔ́mbɔ̀   kɔ́mbɔ̀   kɔmbɔ=gè  NaN  LIVESTOCK  noun
# 4               bɛ́lɛ̀g, bɛ́lɛ̀gù  bɛ́lɛ̀-g  bɛlɛ-g-yà  NaN  LIVESTOCK  noun
#
#   BEFORE_PARSE     PARSED
# 0      jáwdì-m   jáw-dì-m
# 1      dá:bà-m    dáábà-m
# 2     àrsɛ̌:-m  àrsɛ̌ɛ̌-m
# 3      kɔ́mbɔ̀   kɔ́-mbɔ̀
# 4     bɛ́lɛ̀-g   bɛ́lɛ̀-g

# %%
# data["TONES_REMOVED"] = data["PARSED"].apply(lambda x: remove_tones(x)) #remove tones

# %%
tk = Tokenizer('output.tsv')
data["IPA"]=data["PARSED"].apply(lambda x: tk(x, column="IPA") if isinstance(x, str) else x) #running orthography profile
data["IPA"]=data["IPA"].apply(remove_spaces)#removing spaces, else Lingpy throws an error

# %%
data.head()
# Out:
#    VARID          DOCULECT                             GLOSS  \
# 0    0.0         BankanTey  domestic animal (esp. livestock)
# 1    1.0         BankanTey  domestic animal (esp. livestock)
# 2    0.0            BenTey  domestic animal (esp. livestock)
# 3    0.0            Bunoge  domestic animal (esp. livestock)
# 4    0.0  DogulDomBendiely  domestic animal (esp. livestock)
#
#                         VALUE_ORG  SINGULAR     PLURAL FORM    CONCEPT   POS  \
# 0  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   jáwdì-m      jáwdì  NaN  LIVESTOCK  noun
# 1  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   dá:bà-m      dá:bà  NaN  LIVESTOCK  noun
# 2                àrsɛ̌:-m\\àrsɛ̌:  àrsɛ̌:-m     àrsɛ̌:  NaN  LIVESTOCK  noun
# 3                         kɔ́mbɔ̀   kɔ́mbɔ̀   kɔmbɔ=gè  NaN  LIVESTOCK  noun
# 4               bɛ́lɛ̀g, bɛ́lɛ̀gù  bɛ́lɛ̀-g  bɛlɛ-g-yà  NaN  LIVESTOCK  noun
#
#   BEFORE_PARSE     PARSED        IPA
# 0      jáwdì-m   jáw-dì-m   jáw+dì+m
# 1      dá:bà-m    dáábà-m    dáábà+m
# 2     àrsɛ̌:-m  àrsɛ̌ɛ̌-m  àrsɛ̌ɛ̌+m
# 3      kɔ́mbɔ̀   kɔ́-mbɔ̀   kɔ́+mbɔ̀
# 4     bɛ́lɛ̀-g   bɛ́lɛ̀-g   bɛ́lɛ̀+g

# %%
data=data[["DOCULECT", "GLOSS", "IPA"]].dropna(subset=["DOCULECT", "GLOSS", "IPA"])

# %%
data.head()
# Out:
#            DOCULECT                             GLOSS        IPA
# 0         BankanTey  domestic animal (esp. livestock)   jáw+dì+m
# 1         BankanTey  domestic animal (esp. livestock)    dáábà+m
# 2            BenTey  domestic animal (esp. livestock)  àrsɛ̌ɛ̌+m
# 3            Bunoge  domestic animal (esp. livestock)   kɔ́+mbɔ̀
# 4  DogulDomBendiely  domestic animal (esp. livestock)   bɛ́lɛ̀+g

# %%
data.to_csv("with_tone_1.csv", index=False, encoding="utf-8")#empty spaces cleaned in Google sheets

# %% [markdown]
# # Special data processing(with Lingpy)

# %%
wl=Wordlist("with_tone_2.tsv")

# %%
wl.header
# Out:
# {'doculect': 0, 'concept': 1, 'ipa': 2}

# %%
x=25
count, results = mutual_coverage_subset(wl, x)
coverage, languages = results[0]

# %%
concepts={}
for i in languages:
    concepts[i]=set(wl.get_dict(language=i, entry="concepts"))

# %%
wl.output("tsv", filename="with_tone_3", subset=True, rows=dict(doculect = "in "+str(languages)))
wl.output("csv", filename="with_tone_3", subset=True, rows=dict(doculect = "in "+str(languages))) #empty spaces cleaned in Google sheets
# Out:
# 2024-04-23 17:27:32,884 [INFO] Data has been written to file <with_tone_3.tsv>.
# 2024-04-23 17:27:33,598 [INFO] Data has been written to file <with_tone_3.csv>.

# %% [markdown]
# # Running algorithm

# %%
path = r"D:\ERC_Bang\Tasks\data_cleaning" 
os.chdir(path)

# %%
wl=Wordlist("with_tone_4.tsv")

# %%
lex=LexStat(wl)

# %%
lex.get_scorer(runs=10000)
lex.cluster(method='lexstat', threshold=0.55, ref='cogid')
lex.output('tsv', filename='with_tone_clusters')
lex.output('csv', filename='with_tone_clusters')
# Out:
# CORRESPONDENCE CALCULATION:   0%|                                                            | 0/288.0 [00:00<?, ?it/s]2024-04-23 17:43:11,825 [INFO] Calculating alignments for pair Ampari / Ampari.
# 2024-04-23 17:43:11,833 [INFO] Calculating alignments for pair Ampari / BankanTey.
# 2024-04-23 17:43:11,846 [INFO] Calculating alignments for pair Ampari / BenTey.
# 2024-04-23 17:43:11,860 [INFO] Calculating alignments for pair Ampari / BonduSoNajamba.
# 2024-04-23 17:43:11,869 [INFO] Calculating alignments for pair Ampari / Bunoge.
# 2024-04-23 17:43:11,877 [INFO] Calculating alignments for pair Ampari / DogulDomBendiely.
# 2024-04-23 17:43:11,884 [INFO] Calculating alignments for pair Ampari / DogulDomKundialang.
# 2024-04-23 17:43:11,892 [INFO] Calculating alignments for pair Ampari / DonnoSo.
# 2024-04-23 17:43:11,900 [INFO] Calculating alignments for pair Ampari / JamsayDouentza.
# 2024-04-23 17:43:11,908 [INFO] Calculating alignments for pair Ampari / JamsayGourou.
# 2024-04-23 17:43:11,914 [INFO] Calculating alignments for pair Ampari / JamsayMondoro.
# 2024-04-23 17:43:11,918 [INFO] Calculating alignments for pair Ampari / Mombo.
# CORRESPONDENCE CALCULATION:   5%|██▎                                               | 13/288.0 [00:00<00:02, 128.77it/s]2024-04-23 17:43:11,926 [INFO] Calculating alignments for pair Ampari / Nanga.
# 2024-04-23 17:43:11,935 [INFO] Calculating alignments for pair Ampari / Penange.
# 2024-04-23 17:43:11,942 [INFO] Calculating alignments for pair Ampari / PergeTegu.
# 2024-04-23 17:43:11,948 [INFO] Calculating alignments for pair Ampari / TebulUre.
# 2024-04-23 17:43:11,956 [INFO] Calculating alignments for pair Ampari / Tiranige.
# 2024-04-23 17:43:11,963 [INFO] Calculating alignments for pair Ampari / TogoKan.
# 2024-04-23 17:43:11,970 [INFO] Calculating alignments for pair Ampari / TommoSoTongoTongo.
# 2024-04-23 17:43:11,979 [INFO] Calculating alignments for pair Ampari / TomoKanDiangassagou.
# 2024-04-23 17:43:11,981 [INFO] Calculating alignments for pair Ampari / TomoKanSegue.
# 2024-04-23 17:43:11,984 [INFO] Calculating alignments for pair Ampari / ToroTegu.
# 2024-04-23 17:43:11,991 [INFO] Calculating alignments for pair Ampari / YandaDom.
# 2024-04-23 17:43:12,001 [INFO] Calculating alignments for pair Ampari / YornoSo.
# 2024-04-23 17:43:12,008 [INFO] Calculating alignments for pair BankanTey / BankanTey.
# CORRESPONDENCE CALCULATION:   9%|████▌                                              | 26/288.0 [00:00<00:02, 94.29it/s]2024-04-23 17:43:12,089 [INFO] Calculating alignments for pair BankanTey / BenTey.
# 2024-04-23 17:43:12,179 [INFO] Calculating alignments for pair BankanTey / BonduSoNajamba.
# 2024-04-23 17:43:12,270 [INFO] Calculating alignments for pair BankanTey / Bunoge.
# 2024-04-23 17:43:12,327 [INFO] Calculating alignments for pair BankanTey / DogulDomBendiely.
# 2024-04-23 17:43:12,370 [INFO] Calculating alignments for pair BankanTey / DogulDomKundialang.
# 2024-04-23 17:43:12,419 [INFO] Calculating alignments for pair BankanTey / DonnoSo.
# 2024-04-23 17:43:12,486 [INFO] Calculating alignments for pair BankanTey / JamsayDouentza.
# 2024-04-23 17:43:12,572 [INFO] Calculating alignments for pair BankanTey / JamsayGourou.
# 2024-04-23 17:43:12,608 [INFO] Calculating alignments for pair BankanTey / JamsayMondoro.
# 2024-04-23 17:43:12,629 [INFO] Calculating alignments for pair BankanTey / Mombo.
# CORRESPONDENCE CALCULATION:  12%|██████▍                                            | 36/288.0 [00:00<00:07, 32.63it/s]2024-04-23 17:43:12,707 [INFO] Calculating alignments for pair BankanTey / Nanga.
# 2024-04-23 17:43:12,801 [INFO] Calculating alignments for pair BankanTey / Penange.
# 2024-04-23 17:43:12,857 [INFO] Calculating alignments for pair BankanTey / PergeTegu.
# 2024-04-23 17:43:12,929 [INFO] Calculating alignments for pair BankanTey / TebulUre.
# 2024-04-23 17:43:12,982 [INFO] Calculating alignments for pair BankanTey / Tiranige.
# 2024-04-23 17:43:13,040 [INFO] Calculating alignments for pair BankanTey / TogoKan.
# 2024-04-23 17:43:13,107 [INFO] Calculating alignments for pair BankanTey / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  15%|███████▌                                           | 43/288.0 [00:01<00:10, 23.82it/s]2024-04-23 17:43:13,203 [INFO] Calculating alignments for pair BankanTey / TomoKanDiangassagou.
# 2024-04-23 17:43:13,218 [INFO] Calculating alignments for pair BankanTey / TomoKanSegue.
# 2024-04-23 17:43:13,240 [INFO] Calculating alignments for pair BankanTey / ToroTegu.
# 2024-04-23 17:43:13,318 [INFO] Calculating alignments for pair BankanTey / YandaDom.
# 2024-04-23 17:43:13,391 [INFO] Calculating alignments for pair BankanTey / YornoSo.
# CORRESPONDENCE CALCULATION:  17%|████████▌                                          | 48/288.0 [00:01<00:10, 22.50it/s]2024-04-23 17:43:13,467 [INFO] Calculating alignments for pair BenTey / BenTey.
# 2024-04-23 17:43:13,556 [INFO] Calculating alignments for pair BenTey / BonduSoNajamba.
# 2024-04-23 17:43:13,656 [INFO] Calculating alignments for pair BenTey / Bunoge.
# 2024-04-23 17:43:13,718 [INFO] Calculating alignments for pair BenTey / DogulDomBendiely.
# CORRESPONDENCE CALCULATION:  18%|█████████▏                                         | 52/288.0 [00:01<00:11, 19.70it/s]2024-04-23 17:43:13,769 [INFO] Calculating alignments for pair BenTey / DogulDomKundialang.
# 2024-04-23 17:43:13,824 [INFO] Calculating alignments for pair BenTey / DonnoSo.
# 2024-04-23 17:43:13,903 [INFO] Calculating alignments for pair BenTey / JamsayDouentza.
# CORRESPONDENCE CALCULATION:  19%|█████████▋                                         | 55/288.0 [00:02<00:12, 17.94it/s]2024-04-23 17:43:14,006 [INFO] Calculating alignments for pair BenTey / JamsayGourou.
# 2024-04-23 17:43:14,044 [INFO] Calculating alignments for pair BenTey / JamsayMondoro.
# 2024-04-23 17:43:14,068 [INFO] Calculating alignments for pair BenTey / Mombo.
# CORRESPONDENCE CALCULATION:  20%|██████████▎                                        | 58/288.0 [00:02<00:12, 18.28it/s]2024-04-23 17:43:14,158 [INFO] Calculating alignments for pair BenTey / Nanga.
# 2024-04-23 17:43:14,267 [INFO] Calculating alignments for pair BenTey / Penange.
# 2024-04-23 17:43:14,329 [INFO] Calculating alignments for pair BenTey / PergeTegu.
# CORRESPONDENCE CALCULATION:  21%|██████████▊                                        | 61/288.0 [00:02<00:13, 16.31it/s]2024-04-23 17:43:14,409 [INFO] Calculating alignments for pair BenTey / TebulUre.
# 2024-04-23 17:43:14,471 [INFO] Calculating alignments for pair BenTey / Tiranige.
# CORRESPONDENCE CALCULATION:  22%|███████████▏                                       | 63/288.0 [00:02<00:13, 16.25it/s]2024-04-23 17:43:14,535 [INFO] Calculating alignments for pair BenTey / TogoKan.
# 2024-04-23 17:43:14,615 [INFO] Calculating alignments for pair BenTey / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  23%|███████████▌                                       | 65/288.0 [00:02<00:15, 14.35it/s]2024-04-23 17:43:14,739 [INFO] Calculating alignments for pair BenTey / TomoKanDiangassagou.
# 2024-04-23 17:43:14,753 [INFO] Calculating alignments for pair BenTey / TomoKanSegue.
# 2024-04-23 17:43:14,777 [INFO] Calculating alignments for pair BenTey / ToroTegu.
# CORRESPONDENCE CALCULATION:  24%|████████████                                       | 68/288.0 [00:03<00:13, 16.44it/s]2024-04-23 17:43:14,859 [INFO] Calculating alignments for pair BenTey / YandaDom.
# 2024-04-23 17:43:14,936 [INFO] Calculating alignments for pair BenTey / YornoSo.
# CORRESPONDENCE CALCULATION:  24%|████████████▍                                      | 70/288.0 [00:03<00:14, 15.46it/s]2024-04-23 17:43:15,016 [INFO] Calculating alignments for pair BonduSoNajamba / BonduSoNajamba.
# 2024-04-23 17:43:15,104 [INFO] Calculating alignments for pair BonduSoNajamba / Bunoge.
# CORRESPONDENCE CALCULATION:  25%|████████████▊                                      | 72/288.0 [00:03<00:14, 15.05it/s]2024-04-23 17:43:15,159 [INFO] Calculating alignments for pair BonduSoNajamba / DogulDomBendiely.
# 2024-04-23 17:43:15,204 [INFO] Calculating alignments for pair BonduSoNajamba / DogulDomKundialang.
# 2024-04-23 17:43:15,253 [INFO] Calculating alignments for pair BonduSoNajamba / DonnoSo.
# CORRESPONDENCE CALCULATION:  26%|█████████████▎                                     | 75/288.0 [00:03<00:13, 16.02it/s]2024-04-23 17:43:15,323 [INFO] Calculating alignments for pair BonduSoNajamba / JamsayDouentza.
# 2024-04-23 17:43:15,409 [INFO] Calculating alignments for pair BonduSoNajamba / JamsayGourou.
# CORRESPONDENCE CALCULATION:  27%|█████████████▋                                     | 77/288.0 [00:03<00:13, 16.21it/s]2024-04-23 17:43:15,443 [INFO] Calculating alignments for pair BonduSoNajamba / JamsayMondoro.
# 2024-04-23 17:43:15,463 [INFO] Calculating alignments for pair BonduSoNajamba / Mombo.
# 2024-04-23 17:43:15,539 [INFO] Calculating alignments for pair BonduSoNajamba / Nanga.
# CORRESPONDENCE CALCULATION:  28%|██████████████▏                                    | 80/288.0 [00:03<00:13, 15.43it/s]2024-04-23 17:43:15,655 [INFO] Calculating alignments for pair BonduSoNajamba / Penange.
# 2024-04-23 17:43:15,711 [INFO] Calculating alignments for pair BonduSoNajamba / PergeTegu.
# CORRESPONDENCE CALCULATION:  28%|██████████████▌                                    | 82/288.0 [00:03<00:13, 15.45it/s]2024-04-23 17:43:15,784 [INFO] Calculating alignments for pair BonduSoNajamba / TebulUre.
# 2024-04-23 17:43:15,837 [INFO] Calculating alignments for pair BonduSoNajamba / Tiranige.
# CORRESPONDENCE CALCULATION:  29%|██████████████▉                                    | 84/288.0 [00:04<00:12, 16.08it/s]2024-04-23 17:43:15,894 [INFO] Calculating alignments for pair BonduSoNajamba / TogoKan.
# 2024-04-23 17:43:15,963 [INFO] Calculating alignments for pair BonduSoNajamba / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  30%|███████████████▏                                   | 86/288.0 [00:04<00:13, 14.74it/s]2024-04-23 17:43:16,059 [INFO] Calculating alignments for pair BonduSoNajamba / TomoKanDiangassagou.
# 2024-04-23 17:43:16,072 [INFO] Calculating alignments for pair BonduSoNajamba / TomoKanSegue.
# 2024-04-23 17:43:16,096 [INFO] Calculating alignments for pair BonduSoNajamba / ToroTegu.
# CORRESPONDENCE CALCULATION:  31%|███████████████▊                                   | 89/288.0 [00:04<00:11, 17.66it/s]2024-04-23 17:43:16,172 [INFO] Calculating alignments for pair BonduSoNajamba / YandaDom.
# 2024-04-23 17:43:16,246 [INFO] Calculating alignments for pair BonduSoNajamba / YornoSo.
# CORRESPONDENCE CALCULATION:  32%|████████████████                                   | 91/288.0 [00:04<00:12, 16.26it/s]2024-04-23 17:43:16,322 [INFO] Calculating alignments for pair Bunoge / Bunoge.
# 2024-04-23 17:43:16,373 [INFO] Calculating alignments for pair Bunoge / DogulDomBendiely.
# 2024-04-23 17:43:16,404 [INFO] Calculating alignments for pair Bunoge / DogulDomKundialang.
# CORRESPONDENCE CALCULATION:  33%|████████████████▋                                  | 94/288.0 [00:04<00:10, 18.66it/s]2024-04-23 17:43:16,441 [INFO] Calculating alignments for pair Bunoge / DonnoSo.
# 2024-04-23 17:43:16,488 [INFO] Calculating alignments for pair Bunoge / JamsayDouentza.
# CORRESPONDENCE CALCULATION:  33%|█████████████████                                  | 96/288.0 [00:04<00:10, 18.85it/s]2024-04-23 17:43:16,543 [INFO] Calculating alignments for pair Bunoge / JamsayGourou.
# 2024-04-23 17:43:16,570 [INFO] Calculating alignments for pair Bunoge / JamsayMondoro.
# 2024-04-23 17:43:16,587 [INFO] Calculating alignments for pair Bunoge / Mombo.
# 2024-04-23 17:43:16,634 [INFO] Calculating alignments for pair Bunoge / Nanga.
# CORRESPONDENCE CALCULATION:  35%|█████████████████▎                                | 100/288.0 [00:04<00:08, 21.64it/s]2024-04-23 17:43:16,691 [INFO] Calculating alignments for pair Bunoge / Penange.
# 2024-04-23 17:43:16,739 [INFO] Calculating alignments for pair Bunoge / PergeTegu.
# 2024-04-23 17:43:16,782 [INFO] Calculating alignments for pair Bunoge / TebulUre.
# CORRESPONDENCE CALCULATION:  36%|█████████████████▉                                | 103/288.0 [00:04<00:08, 22.02it/s]2024-04-23 17:43:16,822 [INFO] Calculating alignments for pair Bunoge / Tiranige.
# 2024-04-23 17:43:16,871 [INFO] Calculating alignments for pair Bunoge / TogoKan.
# 2024-04-23 17:43:16,920 [INFO] Calculating alignments for pair Bunoge / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  37%|██████████████████▍                               | 106/288.0 [00:05<00:08, 20.81it/s]2024-04-23 17:43:16,983 [INFO] Calculating alignments for pair Bunoge / TomoKanDiangassagou.
# 2024-04-23 17:43:16,994 [INFO] Calculating alignments for pair Bunoge / TomoKanSegue.
# 2024-04-23 17:43:17,012 [INFO] Calculating alignments for pair Bunoge / ToroTegu.
# 2024-04-23 17:43:17,066 [INFO] Calculating alignments for pair Bunoge / YandaDom.
# CORRESPONDENCE CALCULATION:  38%|███████████████████                               | 110/288.0 [00:05<00:07, 23.33it/s]2024-04-23 17:43:17,119 [INFO] Calculating alignments for pair Bunoge / YornoSo.
# 2024-04-23 17:43:17,170 [INFO] Calculating alignments for pair DogulDomBendiely / DogulDomBendiely.
# 2024-04-23 17:43:17,213 [INFO] Calculating alignments for pair DogulDomBendiely / DogulDomKundialang.
# CORRESPONDENCE CALCULATION:  39%|███████████████████▌                              | 113/288.0 [00:05<00:07, 23.36it/s]2024-04-23 17:43:17,248 [INFO] Calculating alignments for pair DogulDomBendiely / DonnoSo.
# 2024-04-23 17:43:17,290 [INFO] Calculating alignments for pair DogulDomBendiely / JamsayDouentza.
# 2024-04-23 17:43:17,338 [INFO] Calculating alignments for pair DogulDomBendiely / JamsayGourou.
# CORRESPONDENCE CALCULATION:  40%|████████████████████▏                             | 116/288.0 [00:05<00:07, 24.09it/s]2024-04-23 17:43:17,363 [INFO] Calculating alignments for pair DogulDomBendiely / JamsayMondoro.
# 2024-04-23 17:43:17,378 [INFO] Calculating alignments for pair DogulDomBendiely / Mombo.
# 2024-04-23 17:43:17,421 [INFO] Calculating alignments for pair DogulDomBendiely / Nanga.
# CORRESPONDENCE CALCULATION:  41%|████████████████████▋                             | 119/288.0 [00:05<00:06, 24.99it/s]2024-04-23 17:43:17,472 [INFO] Calculating alignments for pair DogulDomBendiely / Penange.
# 2024-04-23 17:43:17,505 [INFO] Calculating alignments for pair DogulDomBendiely / PergeTegu.
# 2024-04-23 17:43:17,545 [INFO] Calculating alignments for pair DogulDomBendiely / TebulUre.
# CORRESPONDENCE CALCULATION:  42%|█████████████████████▏                            | 122/288.0 [00:05<00:06, 25.75it/s]2024-04-23 17:43:17,580 [INFO] Calculating alignments for pair DogulDomBendiely / Tiranige.
# 2024-04-23 17:43:17,615 [INFO] Calculating alignments for pair DogulDomBendiely / TogoKan.
# 2024-04-23 17:43:17,654 [INFO] Calculating alignments for pair DogulDomBendiely / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  43%|█████████████████████▋                            | 125/288.0 [00:05<00:06, 25.21it/s]2024-04-23 17:43:17,705 [INFO] Calculating alignments for pair DogulDomBendiely / TomoKanDiangassagou.
# 2024-04-23 17:43:17,714 [INFO] Calculating alignments for pair DogulDomBendiely / TomoKanSegue.
# 2024-04-23 17:43:17,728 [INFO] Calculating alignments for pair DogulDomBendiely / ToroTegu.
# 2024-04-23 17:43:17,771 [INFO] Calculating alignments for pair DogulDomBendiely / YandaDom.
# CORRESPONDENCE CALCULATION:  45%|██████████████████████▍                           | 129/288.0 [00:05<00:05, 28.35it/s]2024-04-23 17:43:17,815 [INFO] Calculating alignments for pair DogulDomBendiely / YornoSo.
# 2024-04-23 17:43:17,857 [INFO] Calculating alignments for pair DogulDomKundialang / DogulDomKundialang.
# 2024-04-23 17:43:17,903 [INFO] Calculating alignments for pair DogulDomKundialang / DonnoSo.
# CORRESPONDENCE CALCULATION:  46%|██████████████████████▉                           | 132/288.0 [00:06<00:05, 26.18it/s]2024-04-23 17:43:17,952 [INFO] Calculating alignments for pair DogulDomKundialang / JamsayDouentza.
# 2024-04-23 17:43:18,005 [INFO] Calculating alignments for pair DogulDomKundialang / JamsayGourou.
# 2024-04-23 17:43:18,033 [INFO] Calculating alignments for pair DogulDomKundialang / JamsayMondoro.
# 2024-04-23 17:43:18,048 [INFO] Calculating alignments for pair DogulDomKundialang / Mombo.
# CORRESPONDENCE CALCULATION:  47%|███████████████████████▌                          | 136/288.0 [00:06<00:05, 26.71it/s]2024-04-23 17:43:18,096 [INFO] Calculating alignments for pair DogulDomKundialang / Nanga.
# 2024-04-23 17:43:18,151 [INFO] Calculating alignments for pair DogulDomKundialang / Penange.
# 2024-04-23 17:43:18,191 [INFO] Calculating alignments for pair DogulDomKundialang / PergeTegu.
# CORRESPONDENCE CALCULATION:  48%|████████████████████████▏                         | 139/288.0 [00:06<00:05, 25.10it/s]2024-04-23 17:43:18,235 [INFO] Calculating alignments for pair DogulDomKundialang / TebulUre.
# 2024-04-23 17:43:18,278 [INFO] Calculating alignments for pair DogulDomKundialang / Tiranige.
# 2024-04-23 17:43:18,319 [INFO] Calculating alignments for pair DogulDomKundialang / TogoKan.
# CORRESPONDENCE CALCULATION:  49%|████████████████████████▋                         | 142/288.0 [00:06<00:05, 24.50it/s]2024-04-23 17:43:18,364 [INFO] Calculating alignments for pair DogulDomKundialang / TommoSoTongoTongo.
# 2024-04-23 17:43:18,423 [INFO] Calculating alignments for pair DogulDomKundialang / TomoKanDiangassagou.
# 2024-04-23 17:43:18,433 [INFO] Calculating alignments for pair DogulDomKundialang / TomoKanSegue.
# 2024-04-23 17:43:18,451 [INFO] Calculating alignments for pair DogulDomKundialang / ToroTegu.
# CORRESPONDENCE CALCULATION:  51%|█████████████████████████▎                        | 146/288.0 [00:06<00:05, 26.24it/s]2024-04-23 17:43:18,497 [INFO] Calculating alignments for pair DogulDomKundialang / YandaDom.
# 2024-04-23 17:43:18,545 [INFO] Calculating alignments for pair DogulDomKundialang / YornoSo.
# 2024-04-23 17:43:18,590 [INFO] Calculating alignments for pair DonnoSo / DonnoSo.
# CORRESPONDENCE CALCULATION:  52%|█████████████████████████▊                        | 149/288.0 [00:06<00:05, 23.63it/s]2024-04-23 17:43:18,657 [INFO] Calculating alignments for pair DonnoSo / JamsayDouentza.
# 2024-04-23 17:43:18,736 [INFO] Calculating alignments for pair DonnoSo / JamsayGourou.
# 2024-04-23 17:43:18,768 [INFO] Calculating alignments for pair DonnoSo / JamsayMondoro.
# CORRESPONDENCE CALCULATION:  53%|██████████████████████████▍                       | 152/288.0 [00:06<00:05, 23.42it/s]2024-04-23 17:43:18,788 [INFO] Calculating alignments for pair DonnoSo / Mombo.
# 2024-04-23 17:43:18,856 [INFO] Calculating alignments for pair DonnoSo / Nanga.
# 2024-04-23 17:43:18,937 [INFO] Calculating alignments for pair DonnoSo / Penange.
# CORRESPONDENCE CALCULATION:  54%|██████████████████████████▉                       | 155/288.0 [00:07<00:06, 20.07it/s]2024-04-23 17:43:18,992 [INFO] Calculating alignments for pair DonnoSo / PergeTegu.
# 2024-04-23 17:43:19,055 [INFO] Calculating alignments for pair DonnoSo / TebulUre.
# 2024-04-23 17:43:19,109 [INFO] Calculating alignments for pair DonnoSo / Tiranige.
# CORRESPONDENCE CALCULATION:  55%|███████████████████████████▍                      | 158/288.0 [00:07<00:06, 19.20it/s]2024-04-23 17:43:19,164 [INFO] Calculating alignments for pair DonnoSo / TogoKan.
# 2024-04-23 17:43:19,227 [INFO] Calculating alignments for pair DonnoSo / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  56%|███████████████████████████▊                      | 160/288.0 [00:07<00:07, 17.80it/s]2024-04-23 17:43:19,307 [INFO] Calculating alignments for pair DonnoSo / TomoKanDiangassagou.
# 2024-04-23 17:43:19,320 [INFO] Calculating alignments for pair DonnoSo / TomoKanSegue.
# 2024-04-23 17:43:19,341 [INFO] Calculating alignments for pair DonnoSo / ToroTegu.
# CORRESPONDENCE CALCULATION:  57%|████████████████████████████▎                     | 163/288.0 [00:07<00:06, 20.26it/s]2024-04-23 17:43:19,411 [INFO] Calculating alignments for pair DonnoSo / YandaDom.
# 2024-04-23 17:43:19,477 [INFO] Calculating alignments for pair DonnoSo / YornoSo.
# 2024-04-23 17:43:19,543 [INFO] Calculating alignments for pair JamsayDouentza / JamsayDouentza.
# CORRESPONDENCE CALCULATION:  58%|████████████████████████████▊                     | 166/288.0 [00:07<00:06, 17.79it/s]2024-04-23 17:43:19,624 [INFO] Calculating alignments for pair JamsayDouentza / JamsayGourou.
# 2024-04-23 17:43:19,662 [INFO] Calculating alignments for pair JamsayDouentza / JamsayMondoro.
# 2024-04-23 17:43:19,684 [INFO] Calculating alignments for pair JamsayDouentza / Mombo.
# CORRESPONDENCE CALCULATION:  59%|█████████████████████████████▎                    | 169/288.0 [00:07<00:06, 18.56it/s]2024-04-23 17:43:19,771 [INFO] Calculating alignments for pair JamsayDouentza / Nanga.
# 2024-04-23 17:43:19,877 [INFO] Calculating alignments for pair JamsayDouentza / Penange.
# CORRESPONDENCE CALCULATION:  59%|█████████████████████████████▋                    | 171/288.0 [00:08<00:07, 16.47it/s]2024-04-23 17:43:19,938 [INFO] Calculating alignments for pair JamsayDouentza / PergeTegu.
# 2024-04-23 17:43:20,017 [INFO] Calculating alignments for pair JamsayDouentza / TebulUre.
# CORRESPONDENCE CALCULATION:  60%|██████████████████████████████                    | 173/288.0 [00:08<00:07, 15.91it/s]2024-04-23 17:43:20,078 [INFO] Calculating alignments for pair JamsayDouentza / Tiranige.
# 2024-04-23 17:43:20,139 [INFO] Calculating alignments for pair JamsayDouentza / TogoKan.
# CORRESPONDENCE CALCULATION:  61%|██████████████████████████████▍                   | 175/288.0 [00:08<00:07, 15.48it/s]2024-04-23 17:43:20,217 [INFO] Calculating alignments for pair JamsayDouentza / TommoSoTongoTongo.
# 2024-04-23 17:43:20,324 [INFO] Calculating alignments for pair JamsayDouentza / TomoKanDiangassagou.
# CORRESPONDENCE CALCULATION:  61%|██████████████████████████████▋                   | 177/288.0 [00:08<00:07, 15.72it/s]2024-04-23 17:43:20,339 [INFO] Calculating alignments for pair JamsayDouentza / TomoKanSegue.
# 2024-04-23 17:43:20,362 [INFO] Calculating alignments for pair JamsayDouentza / ToroTegu.
# CORRESPONDENCE CALCULATION:  62%|███████████████████████████████                   | 179/288.0 [00:08<00:06, 16.33it/s]2024-04-23 17:43:20,449 [INFO] Calculating alignments for pair JamsayDouentza / YandaDom.
# 2024-04-23 17:43:20,532 [INFO] Calculating alignments for pair JamsayDouentza / YornoSo.
# CORRESPONDENCE CALCULATION:  63%|███████████████████████████████▍                  | 181/288.0 [00:08<00:07, 14.74it/s]2024-04-23 17:43:20,618 [INFO] Calculating alignments for pair JamsayGourou / JamsayGourou.
# 2024-04-23 17:43:20,648 [INFO] Calculating alignments for pair JamsayGourou / JamsayMondoro.
# 2024-04-23 17:43:20,661 [INFO] Calculating alignments for pair JamsayGourou / Mombo.
# 2024-04-23 17:43:20,693 [INFO] Calculating alignments for pair JamsayGourou / Nanga.
# CORRESPONDENCE CALCULATION:  64%|████████████████████████████████                  | 185/288.0 [00:08<00:05, 19.87it/s]2024-04-23 17:43:20,733 [INFO] Calculating alignments for pair JamsayGourou / Penange.
# 2024-04-23 17:43:20,761 [INFO] Calculating alignments for pair JamsayGourou / PergeTegu.
# 2024-04-23 17:43:20,794 [INFO] Calculating alignments for pair JamsayGourou / TebulUre.
# 2024-04-23 17:43:20,821 [INFO] Calculating alignments for pair JamsayGourou / Tiranige.
# CORRESPONDENCE CALCULATION:  66%|████████████████████████████████▊                 | 189/288.0 [00:09<00:04, 23.76it/s]2024-04-23 17:43:20,850 [INFO] Calculating alignments for pair JamsayGourou / TogoKan.
# 2024-04-23 17:43:20,881 [INFO] Calculating alignments for pair JamsayGourou / TommoSoTongoTongo.
# 2024-04-23 17:43:20,920 [INFO] Calculating alignments for pair JamsayGourou / TomoKanDiangassagou.
# 2024-04-23 17:43:20,927 [INFO] Calculating alignments for pair JamsayGourou / TomoKanSegue.
# 2024-04-23 17:43:20,940 [INFO] Calculating alignments for pair JamsayGourou / ToroTegu.
# CORRESPONDENCE CALCULATION:  67%|█████████████████████████████████▋                | 194/288.0 [00:09<00:03, 28.65it/s]2024-04-23 17:43:20,972 [INFO] Calculating alignments for pair JamsayGourou / YandaDom.
# 2024-04-23 17:43:21,006 [INFO] Calculating alignments for pair JamsayGourou / YornoSo.
# 2024-04-23 17:43:21,039 [INFO] Calculating alignments for pair JamsayMondoro / JamsayMondoro.
# 2024-04-23 17:43:21,057 [INFO] Calculating alignments for pair JamsayMondoro / Mombo.
# CORRESPONDENCE CALCULATION:  69%|██████████████████████████████████▍               | 198/288.0 [00:09<00:02, 31.19it/s]2024-04-23 17:43:21,076 [INFO] Calculating alignments for pair JamsayMondoro / Nanga.
# 2024-04-23 17:43:21,099 [INFO] Calculating alignments for pair JamsayMondoro / Penange.
# 2024-04-23 17:43:21,117 [INFO] Calculating alignments for pair JamsayMondoro / PergeTegu.
# 2024-04-23 17:43:21,136 [INFO] Calculating alignments for pair JamsayMondoro / TebulUre.
# 2024-04-23 17:43:21,154 [INFO] Calculating alignments for pair JamsayMondoro / Tiranige.
# 2024-04-23 17:43:21,172 [INFO] Calculating alignments for pair JamsayMondoro / TogoKan.
# CORRESPONDENCE CALCULATION:  71%|███████████████████████████████████▍              | 204/288.0 [00:09<00:02, 37.19it/s]2024-04-23 17:43:21,192 [INFO] Calculating alignments for pair JamsayMondoro / TommoSoTongoTongo.
# 2024-04-23 17:43:21,221 [INFO] Calculating alignments for pair JamsayMondoro / TomoKanDiangassagou.
# 2024-04-23 17:43:21,227 [INFO] Calculating alignments for pair JamsayMondoro / TomoKanSegue.
# 2024-04-23 17:43:21,235 [INFO] Calculating alignments for pair JamsayMondoro / ToroTegu.
# 2024-04-23 17:43:21,262 [INFO] Calculating alignments for pair JamsayMondoro / YandaDom.
# 2024-04-23 17:43:21,285 [INFO] Calculating alignments for pair JamsayMondoro / YornoSo.
# CORRESPONDENCE CALCULATION:  73%|████████████████████████████████████▍             | 210/288.0 [00:09<00:01, 41.79it/s]2024-04-23 17:43:21,306 [INFO] Calculating alignments for pair Mombo / Mombo.
# 2024-04-23 17:43:21,393 [INFO] Calculating alignments for pair Mombo / Nanga.
# 2024-04-23 17:43:21,484 [INFO] Calculating alignments for pair Mombo / Penange.
# 2024-04-23 17:43:21,537 [INFO] Calculating alignments for pair Mombo / PergeTegu.
# 2024-04-23 17:43:21,606 [INFO] Calculating alignments for pair Mombo / TebulUre.
# CORRESPONDENCE CALCULATION:  75%|█████████████████████████████████████▎            | 215/288.0 [00:09<00:02, 26.23it/s]2024-04-23 17:43:21,659 [INFO] Calculating alignments for pair Mombo / Tiranige.
# 2024-04-23 17:43:21,713 [INFO] Calculating alignments for pair Mombo / TogoKan.
# 2024-04-23 17:43:21,782 [INFO] Calculating alignments for pair Mombo / TommoSoTongoTongo.
# 2024-04-23 17:43:21,878 [INFO] Calculating alignments for pair Mombo / TomoKanDiangassagou.
# CORRESPONDENCE CALCULATION:  76%|██████████████████████████████████████            | 219/288.0 [00:10<00:02, 23.15it/s]2024-04-23 17:43:21,890 [INFO] Calculating alignments for pair Mombo / TomoKanSegue.
# 2024-04-23 17:43:21,908 [INFO] Calculating alignments for pair Mombo / ToroTegu.
# 2024-04-23 17:43:21,975 [INFO] Calculating alignments for pair Mombo / YandaDom.
# CORRESPONDENCE CALCULATION:  77%|██████████████████████████████████████▌           | 222/288.0 [00:10<00:02, 22.39it/s]2024-04-23 17:43:22,040 [INFO] Calculating alignments for pair Mombo / YornoSo.
# 2024-04-23 17:43:22,106 [INFO] Calculating alignments for pair Nanga / Nanga.
# 2024-04-23 17:43:22,190 [INFO] Calculating alignments for pair Nanga / Penange.
# CORRESPONDENCE CALCULATION:  78%|███████████████████████████████████████           | 225/288.0 [00:10<00:03, 19.84it/s]2024-04-23 17:43:22,247 [INFO] Calculating alignments for pair Nanga / PergeTegu.
# 2024-04-23 17:43:22,319 [INFO] Calculating alignments for pair Nanga / TebulUre.
# 2024-04-23 17:43:22,373 [INFO] Calculating alignments for pair Nanga / Tiranige.
# CORRESPONDENCE CALCULATION:  79%|███████████████████████████████████████▌          | 228/288.0 [00:10<00:03, 18.78it/s]2024-04-23 17:43:22,432 [INFO] Calculating alignments for pair Nanga / TogoKan.
# 2024-04-23 17:43:22,503 [INFO] Calculating alignments for pair Nanga / TommoSoTongoTongo.
# 2024-04-23 17:43:22,604 [INFO] Calculating alignments for pair Nanga / TomoKanDiangassagou.
# CORRESPONDENCE CALCULATION:  80%|████████████████████████████████████████          | 231/288.0 [00:10<00:03, 17.99it/s]2024-04-23 17:43:22,618 [INFO] Calculating alignments for pair Nanga / TomoKanSegue.
# 2024-04-23 17:43:22,641 [INFO] Calculating alignments for pair Nanga / ToroTegu.
# CORRESPONDENCE CALCULATION:  81%|████████████████████████████████████████▍         | 233/288.0 [00:10<00:03, 18.13it/s]2024-04-23 17:43:22,725 [INFO] Calculating alignments for pair Nanga / YandaDom.
# 2024-04-23 17:43:22,803 [INFO] Calculating alignments for pair Nanga / YornoSo.
# CORRESPONDENCE CALCULATION:  82%|████████████████████████████████████████▊         | 235/288.0 [00:11<00:03, 16.56it/s]2024-04-23 17:43:22,881 [INFO] Calculating alignments for pair Penange / Penange.
# 2024-04-23 17:43:22,935 [INFO] Calculating alignments for pair Penange / PergeTegu.
# CORRESPONDENCE CALCULATION:  82%|█████████████████████████████████████████▏        | 237/288.0 [00:11<00:02, 17.17it/s]2024-04-23 17:43:22,985 [INFO] Calculating alignments for pair Penange / TebulUre.
# 2024-04-23 17:43:23,028 [INFO] Calculating alignments for pair Penange / Tiranige.
# 2024-04-23 17:43:23,076 [INFO] Calculating alignments for pair Penange / TogoKan.
# CORRESPONDENCE CALCULATION:  83%|█████████████████████████████████████████▋        | 240/288.0 [00:11<00:02, 18.46it/s]2024-04-23 17:43:23,124 [INFO] Calculating alignments for pair Penange / TommoSoTongoTongo.
# 2024-04-23 17:43:23,187 [INFO] Calculating alignments for pair Penange / TomoKanDiangassagou.
# 2024-04-23 17:43:23,199 [INFO] Calculating alignments for pair Penange / TomoKanSegue.
# 2024-04-23 17:43:23,217 [INFO] Calculating alignments for pair Penange / ToroTegu.
# CORRESPONDENCE CALCULATION:  85%|██████████████████████████████████████████▎       | 244/288.0 [00:11<00:02, 21.09it/s]2024-04-23 17:43:23,272 [INFO] Calculating alignments for pair Penange / YandaDom.
# 2024-04-23 17:43:23,326 [INFO] Calculating alignments for pair Penange / YornoSo.
# 2024-04-23 17:43:23,378 [INFO] Calculating alignments for pair PergeTegu / PergeTegu.
# CORRESPONDENCE CALCULATION:  86%|██████████████████████████████████████████▉       | 247/288.0 [00:11<00:02, 19.86it/s]2024-04-23 17:43:23,444 [INFO] Calculating alignments for pair PergeTegu / TebulUre.
# 2024-04-23 17:43:23,494 [INFO] Calculating alignments for pair PergeTegu / Tiranige.
# 2024-04-23 17:43:23,544 [INFO] Calculating alignments for pair PergeTegu / TogoKan.
# CORRESPONDENCE CALCULATION:  87%|███████████████████████████████████████████▍      | 250/288.0 [00:11<00:01, 19.37it/s]2024-04-23 17:43:23,608 [INFO] Calculating alignments for pair PergeTegu / TommoSoTongoTongo.
# 2024-04-23 17:43:23,694 [INFO] Calculating alignments for pair PergeTegu / TomoKanDiangassagou.
# 2024-04-23 17:43:23,705 [INFO] Calculating alignments for pair PergeTegu / TomoKanSegue.
# CORRESPONDENCE CALCULATION:  88%|███████████████████████████████████████████▉      | 253/288.0 [00:11<00:01, 20.85it/s]2024-04-23 17:43:23,725 [INFO] Calculating alignments for pair PergeTegu / ToroTegu.
# 2024-04-23 17:43:23,793 [INFO] Calculating alignments for pair PergeTegu / YandaDom.
# 2024-04-23 17:43:23,860 [INFO] Calculating alignments for pair PergeTegu / YornoSo.
# CORRESPONDENCE CALCULATION:  89%|████████████████████████████████████████████▍     | 256/288.0 [00:12<00:01, 18.50it/s]2024-04-23 17:43:23,931 [INFO] Calculating alignments for pair TebulUre / TebulUre.
# 2024-04-23 17:43:23,983 [INFO] Calculating alignments for pair TebulUre / Tiranige.
# 2024-04-23 17:43:24,028 [INFO] Calculating alignments for pair TebulUre / TogoKan.
# CORRESPONDENCE CALCULATION:  90%|████████████████████████████████████████████▉     | 259/288.0 [00:12<00:01, 19.03it/s]2024-04-23 17:43:24,078 [INFO] Calculating alignments for pair TebulUre / TommoSoTongoTongo.
# 2024-04-23 17:43:24,141 [INFO] Calculating alignments for pair TebulUre / TomoKanDiangassagou.
# 2024-04-23 17:43:24,153 [INFO] Calculating alignments for pair TebulUre / TomoKanSegue.
# 2024-04-23 17:43:24,172 [INFO] Calculating alignments for pair TebulUre / ToroTegu.
# CORRESPONDENCE CALCULATION:  91%|█████████████████████████████████████████████▋    | 263/288.0 [00:12<00:01, 21.40it/s]2024-04-23 17:43:24,223 [INFO] Calculating alignments for pair TebulUre / YandaDom.
# 2024-04-23 17:43:24,279 [INFO] Calculating alignments for pair TebulUre / YornoSo.
# 2024-04-23 17:43:24,332 [INFO] Calculating alignments for pair Tiranige / Tiranige.
# CORRESPONDENCE CALCULATION:  92%|██████████████████████████████████████████████▏   | 266/288.0 [00:12<00:01, 20.39it/s]2024-04-23 17:43:24,389 [INFO] Calculating alignments for pair Tiranige / TogoKan.
# 2024-04-23 17:43:24,439 [INFO] Calculating alignments for pair Tiranige / TommoSoTongoTongo.
# 2024-04-23 17:43:24,504 [INFO] Calculating alignments for pair Tiranige / TomoKanDiangassagou.
# CORRESPONDENCE CALCULATION:  93%|██████████████████████████████████████████████▋   | 269/288.0 [00:12<00:00, 21.31it/s]2024-04-23 17:43:24,514 [INFO] Calculating alignments for pair Tiranige / TomoKanSegue.
# 2024-04-23 17:43:24,531 [INFO] Calculating alignments for pair Tiranige / ToroTegu.
# 2024-04-23 17:43:24,584 [INFO] Calculating alignments for pair Tiranige / YandaDom.
# CORRESPONDENCE CALCULATION:  94%|███████████████████████████████████████████████▏  | 272/288.0 [00:12<00:00, 22.02it/s]2024-04-23 17:43:24,639 [INFO] Calculating alignments for pair Tiranige / YornoSo.
# 2024-04-23 17:43:24,693 [INFO] Calculating alignments for pair TogoKan / TogoKan.
# 2024-04-23 17:43:24,756 [INFO] Calculating alignments for pair TogoKan / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  95%|███████████████████████████████████████████████▋  | 275/288.0 [00:13<00:00, 19.29it/s]2024-04-23 17:43:24,841 [INFO] Calculating alignments for pair TogoKan / TomoKanDiangassagou.
# 2024-04-23 17:43:24,853 [INFO] Calculating alignments for pair TogoKan / TomoKanSegue.
# 2024-04-23 17:43:24,872 [INFO] Calculating alignments for pair TogoKan / ToroTegu.
# 2024-04-23 17:43:24,938 [INFO] Calculating alignments for pair TogoKan / YandaDom.
# CORRESPONDENCE CALCULATION:  97%|████████████████████████████████████████████████▍ | 279/288.0 [00:13<00:00, 20.90it/s]2024-04-23 17:43:25,004 [INFO] Calculating alignments for pair TogoKan / YornoSo.
# 2024-04-23 17:43:25,073 [INFO] Calculating alignments for pair TommoSoTongoTongo / TommoSoTongoTongo.
# 2024-04-23 17:43:25,182 [INFO] Calculating alignments for pair TommoSoTongoTongo / TomoKanDiangassagou.
# CORRESPONDENCE CALCULATION:  98%|████████████████████████████████████████████████▉ | 282/288.0 [00:13<00:00, 19.13it/s]2024-04-23 17:43:25,196 [INFO] Calculating alignments for pair TommoSoTongoTongo / TomoKanSegue.
# 2024-04-23 17:43:25,221 [INFO] Calculating alignments for pair TommoSoTongoTongo / ToroTegu.
# CORRESPONDENCE CALCULATION:  99%|█████████████████████████████████████████████████▎| 284/288.0 [00:13<00:00, 18.55it/s]2024-04-23 17:43:25,316 [INFO] Calculating alignments for pair TommoSoTongoTongo / YandaDom.
# 2024-04-23 17:43:25,406 [INFO] Calculating alignments for pair TommoSoTongoTongo / YornoSo.
# CORRESPONDENCE CALCULATION:  99%|█████████████████████████████████████████████████▋| 286/288.0 [00:13<00:00, 15.82it/s]2024-04-23 17:43:25,505 [INFO] Calculating alignments for pair TomoKanDiangassagou / TomoKanDiangassagou.
# 2024-04-23 17:43:25,519 [INFO] Calculating alignments for pair TomoKanDiangassagou / TomoKanSegue.
# 2024-04-23 17:43:25,533 [INFO] Calculating alignments for pair TomoKanDiangassagou / ToroTegu.
# 2024-04-23 17:43:25,544 [INFO] Calculating alignments for pair TomoKanDiangassagou / YandaDom.
# 2024-04-23 17:43:25,557 [INFO] Calculating alignments for pair TomoKanDiangassagou / YornoSo.
# 2024-04-23 17:43:25,569 [INFO] Calculating alignments for pair TomoKanSegue / TomoKanSegue.
# 2024-04-23 17:43:25,592 [INFO] Calculating alignments for pair TomoKanSegue / ToroTegu.
# CORRESPONDENCE CALCULATION: 293it [00:13, 26.60it/s]                                                                   2024-04-23 17:43:25,612 [INFO] Calculating alignments for pair TomoKanSegue / YandaDom.
# 2024-04-23 17:43:25,632 [INFO] Calculating alignments for pair TomoKanSegue / YornoSo.
# 2024-04-23 17:43:25,653 [INFO] Calculating alignments for pair ToroTegu / ToroTegu.
# 2024-04-23 17:43:25,723 [INFO] Calculating alignments for pair ToroTegu / YandaDom.
# CORRESPONDENCE CALCULATION: 297it [00:13, 24.96it/s]2024-04-23 17:43:25,795 [INFO] Calculating alignments for pair ToroTegu / YornoSo.
# 2024-04-23 17:43:25,869 [INFO] Calculating alignments for pair YandaDom / YandaDom.
# 2024-04-23 17:43:25,936 [INFO] Calculating alignments for pair YandaDom / YornoSo.
# CORRESPONDENCE CALCULATION: 300it [00:14, 21.16it/s]2024-04-23 17:43:26,003 [INFO] Calculating alignments for pair YornoSo / YornoSo.
# RANDOM CORRESPONDENCE CALCULATION:   0%|                                                     | 0/288.0 [00:00<?, ?it/s]2024-04-23 17:43:26,070 [INFO] Calculating random alignmentsfor pair Ampari/Ampari.
# RANDOM CORRESPONDENCE CALCULATION:   1%|▎                                            | 2/288.0 [00:00<01:08,  4.18it/s]2024-04-23 17:43:26,550 [INFO] Calculating random alignmentsfor pair Ampari/BankanTey.
# RANDOM CORRESPONDENCE CALCULATION:   1%|▍                                            | 3/288.0 [00:00<01:41,  2.81it/s]2024-04-23 17:43:27,069 [INFO] Calculating random alignmentsfor pair Ampari/BenTey.
# RANDOM CORRESPONDENCE CALCULATION:   1%|▋                                            | 4/288.0 [00:01<02:02,  2.31it/s]2024-04-23 17:43:27,630 [INFO] Calculating random alignmentsfor pair Ampari/BonduSoNajamba.
# RANDOM CORRESPONDENCE CALCULATION:   2%|▊                                            | 5/288.0 [00:02<02:22,  1.99it/s]2024-04-23 17:43:28,263 [INFO] Calculating random alignmentsfor pair Ampari/Bunoge.
# RANDOM CORRESPONDENCE CALCULATION:   2%|▉                                            | 6/288.0 [00:02<02:27,  1.91it/s]2024-04-23 17:43:28,829 [INFO] Calculating random alignmentsfor pair Ampari/DogulDomBendiely.
# RANDOM CORRESPONDENCE CALCULATION:   2%|█                                            | 7/288.0 [00:03<02:44,  1.71it/s]2024-04-23 17:43:29,541 [INFO] Calculating random alignmentsfor pair Ampari/DogulDomKundialang.
# RANDOM CORRESPONDENCE CALCULATION:   3%|█▎                                           | 8/288.0 [00:04<02:41,  1.73it/s]2024-04-23 17:43:30,104 [INFO] Calculating random alignmentsfor pair Ampari/DonnoSo.
# RANDOM CORRESPONDENCE CALCULATION:   3%|█▍                                           | 9/288.0 [00:04<02:36,  1.78it/s]2024-04-23 17:43:30,630 [INFO] Calculating random alignmentsfor pair Ampari/JamsayDouentza.
# RANDOM CORRESPONDENCE CALCULATION:   3%|█▌                                          | 10/288.0 [00:05<02:30,  1.85it/s]2024-04-23 17:43:31,124 [INFO] Calculating random alignmentsfor pair Ampari/JamsayGourou.
# RANDOM CORRESPONDENCE CALCULATION:   9%|███▉                                        | 26/288.0 [00:13<02:36,  1.67it/s]2024-04-23 17:43:39,091 [INFO] Calculating random alignmentsfor pair BankanTey/BenTey.
# RANDOM CORRESPONDENCE CALCULATION:   9%|████▏                                       | 27/288.0 [00:13<02:58,  1.46it/s]2024-04-23 17:43:39,991 [INFO] Calculating random alignmentsfor pair BankanTey/BonduSoNajamba.
# RANDOM CORRESPONDENCE CALCULATION:  10%|████▎                                       | 28/288.0 [00:14<03:19,  1.30it/s]2024-04-23 17:43:40,959 [INFO] Calculating random alignmentsfor pair BankanTey/Bunoge.
# RANDOM CORRESPONDENCE CALCULATION:  10%|████▍                                       | 29/288.0 [00:15<03:26,  1.26it/s]2024-04-23 17:43:41,823 [INFO] Calculating random alignmentsfor pair BankanTey/DogulDomBendiely.
# RANDOM CORRESPONDENCE CALCULATION:  10%|████▌                                       | 30/288.0 [00:16<03:23,  1.27it/s]2024-04-23 17:43:42,595 [INFO] Calculating random alignmentsfor pair BankanTey/DogulDomKundialang.
# RANDOM CORRESPONDENCE CALCULATION:  11%|████▋                                       | 31/288.0 [00:17<03:35,  1.19it/s]2024-04-23 17:43:43,547 [INFO] Calculating random alignmentsfor pair BankanTey/DonnoSo.
# RANDOM CORRESPONDENCE CALCULATION:  11%|████▉                                       | 32/288.0 [00:18<03:34,  1.19it/s]2024-04-23 17:43:44,390 [INFO] Calculating random alignmentsfor pair BankanTey/JamsayDouentza.
# RANDOM CORRESPONDENCE CALCULATION:  11%|█████                                       | 33/288.0 [00:19<03:36,  1.18it/s]2024-04-23 17:43:45,260 [INFO] Calculating random alignmentsfor pair BankanTey/JamsayGourou.
# RANDOM CORRESPONDENCE CALCULATION:  12%|█████▏                                      | 34/288.0 [00:19<03:24,  1.24it/s]2024-04-23 17:43:45,961 [INFO] Calculating random alignmentsfor pair BankanTey/JamsayMondoro.
# RANDOM CORRESPONDENCE CALCULATION:  12%|█████▎                                      | 35/288.0 [00:20<03:08,  1.34it/s]2024-04-23 17:43:46,568 [INFO] Calculating random alignmentsfor pair BankanTey/Mombo.
# RANDOM CORRESPONDENCE CALCULATION:  12%|█████▌                                      | 36/288.0 [00:21<03:21,  1.25it/s]2024-04-23 17:43:47,500 [INFO] Calculating random alignmentsfor pair BankanTey/Nanga.
# RANDOM CORRESPONDENCE CALCULATION:  13%|█████▋                                      | 37/288.0 [00:22<03:42,  1.13it/s]2024-04-23 17:43:48,590 [INFO] Calculating random alignmentsfor pair BankanTey/Penange.
# RANDOM CORRESPONDENCE CALCULATION:  13%|█████▊                                      | 38/288.0 [00:23<03:37,  1.15it/s]2024-04-23 17:43:49,421 [INFO] Calculating random alignmentsfor pair BankanTey/PergeTegu.
# RANDOM CORRESPONDENCE CALCULATION:  14%|█████▉                                      | 39/288.0 [00:24<03:34,  1.16it/s]2024-04-23 17:43:50,266 [INFO] Calculating random alignmentsfor pair BankanTey/TebulUre.
# RANDOM CORRESPONDENCE CALCULATION:  14%|██████                                      | 40/288.0 [00:24<03:28,  1.19it/s]2024-04-23 17:43:51,057 [INFO] Calculating random alignmentsfor pair BankanTey/Tiranige.
# RANDOM CORRESPONDENCE CALCULATION:  14%|██████▎                                     | 41/288.0 [00:25<03:27,  1.19it/s]2024-04-23 17:43:51,897 [INFO] Calculating random alignmentsfor pair BankanTey/TogoKan.
# RANDOM CORRESPONDENCE CALCULATION:  15%|██████▍                                     | 42/288.0 [00:26<03:24,  1.21it/s]2024-04-23 17:43:52,700 [INFO] Calculating random alignmentsfor pair BankanTey/TommoSoTongoTongo.
# RANDOM CORRESPONDENCE CALCULATION:  15%|██████▌                                     | 43/288.0 [00:27<03:31,  1.16it/s]2024-04-23 17:43:53,643 [INFO] Calculating random alignmentsfor pair BankanTey/TomoKanDiangassagou.
# RANDOM CORRESPONDENCE CALCULATION:  15%|██████▋                                     | 44/288.0 [00:28<03:55,  1.04it/s]2024-04-23 17:43:54,844 [INFO] Calculating random alignmentsfor pair BankanTey/TomoKanSegue.
# RANDOM CORRESPONDENCE CALCULATION:  16%|██████▉                                     | 45/288.0 [00:29<03:45,  1.08it/s]2024-04-23 17:43:55,685 [INFO] Calculating random alignmentsfor pair BankanTey/ToroTegu.
# RANDOM CORRESPONDENCE CALCULATION:  16%|███████                                     | 46/288.0 [00:30<03:38,  1.11it/s]2024-04-23 17:43:56,528 [INFO] Calculating random alignmentsfor pair BankanTey/YandaDom.
# RANDOM CORRESPONDENCE CALCULATION:  16%|███████▏                                    | 47/288.0 [00:31<03:31,  1.14it/s]2024-04-23 17:43:57,345 [INFO] Calculating random alignmentsfor pair BankanTey/YornoSo.
# RANDOM CORRESPONDENCE CALCULATION:  17%|███████▎                                    | 48/288.0 [00:32<03:26,  1.16it/s]2024-04-23 17:43:58,170 [INFO] Calculating random alignmentsfor pair BenTey/BenTey.
# RANDOM CORRESPONDENCE CALCULATION:  17%|███████▍                                    | 49/288.0 [00:32<03:27,  1.15it/s]2024-04-23 17:43:59,058 [INFO] Calculating random alignmentsfor pair BenTey/BonduSoNajamba.
# RANDOM CORRESPONDENCE CALCULATION:  17%|███████▋                                    | 50/288.0 [00:33<03:33,  1.12it/s]2024-04-23 17:44:00,016 [INFO] Calculating random alignmentsfor pair BenTey/Bunoge.
# RANDOM CORRESPONDENCE CALCULATION:  18%|███████▊                                    | 51/288.0 [00:34<03:40,  1.08it/s]2024-04-23 17:44:01,024 [INFO] Calculating random alignmentsfor pair BenTey/DogulDomBendiely.
# RANDOM CORRESPONDENCE CALCULATION:  18%|███████▉                                    | 52/288.0 [00:35<03:27,  1.14it/s]2024-04-23 17:44:01,784 [INFO] Calculating random alignmentsfor pair BenTey/DogulDomKundialang.
# RANDOM CORRESPONDENCE CALCULATION:  18%|████████                                    | 53/288.0 [00:36<03:18,  1.19it/s]2024-04-23 17:44:02,544 [INFO] Calculating random alignmentsfor pair BenTey/DonnoSo.
# RANDOM CORRESPONDENCE CALCULATION:  19%|████████▎                                   | 54/288.0 [00:37<03:18,  1.18it/s]2024-04-23 17:44:03,398 [INFO] Calculating random alignmentsfor pair BenTey/JamsayDouentza.
# ...
# 2024-04-23 17:47:36,202 [INFO] Analyzing words for concept <yesterday>.
# 2024-04-23 17:47:36,210 [INFO] Analyzing words for concept <yoke wrapped in cloth around donkey's neck and tied by a rope to the two long poles of a cart>.
# 2024-04-23 17:47:36,253 [INFO] Analyzing words for concept <young>.
# 2024-04-23 17:47:36,277 [INFO] Analyzing words for concept <young (adolescent) man, not yet bearded>.
# 2024-04-23 17:47:36,278 [INFO] Analyzing words for concept <young (adolescent) woman, not yet a mother>.
# SEQUENCE CLUSTERING: 100%|██████████████████████████████████████████████████████████▉| 945/947 [00:13<00:00, 69.91it/s]2024-04-23 17:47:36,290 [INFO] Analyzing words for concept <younger brother (of man or woman)>.
# 2024-04-23 17:47:36,291 [INFO] Analyzing words for concept <younger sister (of a woman)>.
# 2024-04-23 17:47:37,144 [INFO] Data has been written to file <with_tone_clusters.tsv>.
# 2024-04-23 17:47:38,010 [INFO] Data has been written to file <with_tone_clusters.csv>.

# %% [markdown]
# # ALIGNMENTS

# %%
lex=LexStat("with_tone_clusters.tsv")
alm = Alignments(lex, ref='cogid')
alm.align()

alm.output("html", filename='with_tones_alignments', subset=True,
cols=['doculect', 'concept', 'ipa', 'tokens', 'cogid', 'alignment'],
prettify=False, ignore='all')

alm.output("tsv", filename='with_tones_alignments', subset=True,
cols=['doculect', 'concept', 'ipa', 'tokens', 'cogid', 'alignment'],
prettify=False, ignore='all')
# Out:
# 2024-04-23 17:47:59,363 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:47:59,364 [INFO]
# 	7 9 7
# 	7 9 0
# 2024-04-23 17:47:59,499 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:47:59,500 [INFO]
# 	1 7 4 9 1 7 3 7 9 1 7 7
# 	1 7 4 7 9 1 7 3 7 9 1 7 0 7 0
# 2024-04-23 17:47:59,501 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:47:59,501 [INFO]
# 	[1, 7, 4, 4, 9, 1, 7, 3, 7, 9, 1, 7, 0, 7, 0]
# 2024-04-23 17:47:59,562 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:47:59,562 [INFO]
# 	1 7 4 9 7
# 	1 7 4 7 4 9 0
# 2024-04-23 17:47:59,575 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:47:59,576 [INFO]
# 	1 7 5 7 4 9 0
# 	1 7 5 7 5 9 7
# 2024-04-23 17:47:59,579 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:47:59,579 [INFO]
# 	1 7 4 7 4
# 	1 7 4 7 4 9 0
# 2024-04-23 17:47:59,580 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:47:59,581 [INFO]
# 	[1, 7, 4, 7, 4, 5, 0]
# 2024-04-23 17:47:59,646 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:47:59,647 [INFO]
# 	[1, 7, 0, 7, 0, 5, 7]
# 2024-04-23 17:47:59,742 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:47:59,743 [INFO]
# 	1 7 0 7 0
# 	1 7 4 7 9 1 7 0 7 0
# 2024-04-23 17:47:59,743 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:47:59,744 [INFO]
# 	1 4 2 4 5 1 7 0 7 0
# 	1 7 5 7 9 1 7 0 7 0
# 2024-04-23 17:47:59,745 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:47:59,745 [INFO]
# 	[0, 2, 2, 2, 3, 0, 2, 1, 2, 3, 1, 7, 0, 7, 0]
# 2024-04-23 17:47:59,811 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:47:59,812 [INFO]
# 	1 7 5 7 4 9 0
# 	1 7 5 7 9 7
# 2024-04-23 17:47:59,851 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17
[WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:00,833 [INFO]
# 	7 2 1 9 7 9 1 7 4 9 0 7
# 	7 7 1 9 7 9 1 7 4 9 7
# 2024-04-23 17:48:00,834 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:00,834 [INFO]
# 	[7, 4, 1, 9, 7, 9, 1, 7, 4, 9, 0, 7]
# 2024-04-23 17:48:00,953 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:00,954 [INFO]
# 	1 7 4
# 	1 7 4 9 0 7
# 2024-04-23 17:48:00,954 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:00,955 [INFO]
# 	[1, 7, 4, 5, 0, 4]
# 2024-04-23 17:48:00,956 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:00,956 [INFO]
# 	1 7 4 9 7
# 	1 7 4 9 0 7
# 2024-04-23 17:48:00,957 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:00,957 [INFO]
# 	[1, 7, 4, 9, 0, 7]
# 2024-04-23 17:48:00,969 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:00,970 [INFO]
# 	7 3 7 4
# 	7 3 7 4 9 0
# 2024-04-23 17:48:00,970 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:00,971 [INFO]
# 	[7, 3, 7, 4, 5, 0]
# 2024-04-23 17:48:00,974 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:00,974 [INFO]
# 	1 7 4 7 1 7 4 9 0
# 	1 7 1 7 4 9 0
# 2024-04-23 17:48:00,974 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:00,975 [INFO]
# 	[1, 7, 2, 4, 1, 7, 4, 9, 0]
# 2024-04-23 17:48:00,994 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:00,994 [INFO]
# 	6 7 4 1 9 7 1 9 7 4 4
# 	6 7 4 1 9 7 1 9 7 4 0 7
# 2024-04-23 17:48:00,995 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:00,995 [INFO]
# 	[6, 7, 4, 1, 9, 7, 1, 9, 7, 4, 0, 5]
# 2024-04-23 17:48:01,006 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,007 [INFO]
# 	1 7 4 7 4
# 	1 7 4 7 4 9 0
# 2024-04-23 17:48:01,007 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,008 [INFO]
# 	1 7 4 7 4 5 0
# 	1 7 4
# 2024-04-23 17:48:01,008 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,008 [INFO]
# 	1 7 4 9 7
# 	1 7 4 5 3 3 0
# 2024-04-23 17:48:01,009 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,009 [INFO]
# 	1 7 4 4 2 2 0 2 2
# 	1 7 4 9 7
# 2024-04-23 17:48:01,010 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,010 [INFO]
# 	1 7 4 3 2 2 0 2 1 2 1
# 	1 7 4 9 7
# 2024-04-23 17:48:01,010 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,011 [INFO]
# 	[1, 7, 4, 2, 1, 1, 0, 1, 1, 1, 1, 3, 2]
# 2024-04-23 17:48:01,018 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,018 [INFO]
# 	4 7 4 9 3 7 1 9 7 4 7
# 	4 7 4 9 7 9 3 7 1 9 7 4 0 7
# 2024-04-23 17:48:01,019 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,019 [INFO]
# 	4 7 4 9 4 5 3 7 1 9 7 4 0 7
# 	4 7 4 9 3 7 1 9 7 4
# 2024-04-23 17:48:01,020 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,020 [INFO]
# 	[4, 7, 4, 9, 2, 3, 3, 7, 1, 9, 7, 4, 0, 5]
# 2024-04-23 17:48:01,034 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,034 [INFO]
# 	0 3 7 5 9 7 9 4 7 0 4 1 9 7
# 	0 3 7 3 9 7 9 4 7 0 4 1 9 7
# 2024-04-23 17:48:01,035 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,036 [INFO]
# 	[0, 3, 7, 4, 9, 7, 9, 4, 7, 0, 4, 1, 9, 7]
# 2024-04-23 17:48:01,091 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,091 [INFO]
# 	1 5 7 5 7 4
# 	1 7 5 7 5 7 4 9 0
# 2024-04-23 17:48:01,092 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,092 [INFO]
# 	[1, 4, 5, 7, 5, 7, 4, 5, 0]
# 2024-04-23 17:48:01,168 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,169 [INFO]
# 	3 7 4 9 0
# 	3 7 4 1 9 7
# 2024-04-23 17:48:01,239 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,240 [INFO]
# 	2 2 7 4 7 4 9 7
# 	7 4 7 4 7 4 9 0
# 2024-04-23 17:48:01,247 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,247 [INFO]
# 	3 7 9 7
# 	3 9 7 0
# 2024-04-23 17:48:01,248 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,248 [INFO]
# 	[3, 5, 9, 7, 0]
# 2024-04-23 17:48:01,273 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,274 [INFO]
# 	1 7 5 9 7 9 1 7 4 9 0 1 7 5 9 1 7
# 	1 7 5 9 7 9 1 7 4 9 6 7
# 2024-04-23 17:48:01,297 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,298 [INFO]
# 	7 4 7 4 9 0
# 	7 4 7 4 9 7
# 2024-04-23 17:48:01,418 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,418 [INFO]
# 	1 7 0 7 0
# 	1 7 4 7 9 1 7 0 7 0
# 2024-04-23 17:48:01,419 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,419 [INFO]
# 	1 4 2 4 5 1 7 0 7 0
# 	1 7 5 7 9 1 7 0 7 0
# 2024-04-23 17:48:01,420 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,420 [INFO]
# 	[0, 2, 2, 2, 3, 0, 2, 1, 2, 3, 1, 7, 0, 7, 0]
# 2024-04-23 17:48:01,424 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,424 [INFO]
# 	7 5 7 9 7
# 	7 5 7 4 9 0
# 2024-04-23 17:48:01,565 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,566 [INFO]
# 	1 7 4 1 9 7 2 5 4
# 	1 7 4 1 9 7 4 9 0 7
# 2024-04-23 17:48:01,566 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,567 [INFO]
# 	[1, 7, 4, 1, 9, 7, 3, 3, 2, 3, 0, 2]
# 2024-04-23 17:48:01,602 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,602 [INFO]
# 	1 7 4
# 	1 7 4 9 0
# 2024-04-23 17:48:01,603 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,604 [INFO]
# 	2 7 4 9 7 2 0 1 1
# 	1 7 4 5 0
# 2024-04-23 17:48:01,605 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,606 [INFO]
# 	[2, 7, 4, 1, 0, 7, 5, 1, 0, 1, 1]
# 2024-04-23 17:48:01,646 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,646 [INFO]
# 	[7, 9, 0]
# 2024-04-23 17:48:01,669 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,670 [INFO]
# 	1 7 5 7 4
# 	1 7 5 7 4 9 0
# 2024-04-23 17:48:01,671 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,671 [INFO]
# 	[1, 7, 5, 7, 4, 5, 0]
# 2024-04-23 17:48:01,737 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,737 [INFO]
# 	[1, 7, 0, 7, 0]
# 2024-04-23 17:48:01,739 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,740 [INFO]
# 	7 5 7
# 	7 5 7 0 9
# 2024-04-23 17:48:01,741 [WARNING] There are empty segments in the consensus.
# 2024-04-23 17:48:01,741 [INFO]
# 	[7, 5, 7, 0, 5]
# 2024-04-23 17:48:01,902 [INFO] Data has been written to file <C:\Users\PROMIS~1\AppData\Local\Temp\tmpqv01730x.alm>.
# 2024-04-23 17:48:05,857 [INFO] Data has been written to file <with_tones_alignments.html>.
# 2024-04-23 17:48:06,201 [INFO] Data has been written to file <with_tones_alignments.tsv>.
