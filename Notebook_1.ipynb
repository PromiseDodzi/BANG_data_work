# %% [markdown]
# # Imports

# %%
from utils import NounParser,VerbParser,AdjectiveNumeralParser
import pandas as pd
from lingpy import *
from lingpy.sequence.sound_classes import check_tokens
from lingpy.compare.util import (mutual_coverage_check, mutual_coverage_subset)
from lingpy.compare.sanity import average_coverage
from lingpy.compare.sanity import synonymy
from segments.tokenizer import Tokenizer
from collections import defaultdict
import matplotlib.pyplot as plt
import os
from pprint import pprint
from lingpy.evaluate.acd import bcubes

# %% [markdown]
# # Functions

# %%
#dictionaries, sets and lists
replacement_dict={"DogulDomBendiely":"DogulDomKundialang",
                  "JamsayGourou":"JamsayDouentza",
                  "JamsayMondoro":"JamsayDouentza",
                  "PergeTegu":"JamsayDouentza",
                  "TomoKanSegue":"TomoKanDiangassagou"}

new_name={'TommoSoTongoTongo': "TommoSo",
         "BonduSoNajamba": "BonduSo",
          
         "TomoKanDiangassagou": "TomoKan",
         "TomoKanSegue":"TomoKan",
          
         "DogulDomKundialang": "DogulDom",
         'DogulDomBendiely':"DogulDom",
          
          "JamsayDouentza":"Jamsay",
         'JamsayGourou':"Jamsay",
         'JamsayMondoro':"Jamsay",
          "PergeTegu": "Jamsay"}
replacements={'j':'j','á':'a','w': 'w','d':'d','ì': 'i','-':'-','m':'m',':': ':','b': 'b','à': 'a','r':'r',
              's':'s','ɛ':'ɛ','k':'k','ɔ': 'ɔ','l':'l','g':'g','ù':'u','ú':'u','è':'e','í':'i','ŋ': 'ŋ',
              'ó':'o','n': 'n','ⁿ': '\u207F','ý':'y','z':'z','ɲ':'\u0272','y':'y','ò':'o','ɣ': 'ɣ',
              'ʔ': '\u0294','ǎ':'a','â':'a','é':'e','ě':'e','ê':'e','î':'i','ǐ': 'i','ǹ': 'n','û':'u',
              'š':'s','ə': 'ə','p':'p','ǒ':'o','t':'t','e':'e','ô':'o','ǔ':'u','ń':'n','ỳ':'y','c':'c',
              'h':'h','f': 'f','ʷ': '\u02B7','i':'i','?': '\u0294','x':'x','o':'o','a':'a','ɗ': 'ɗ',
              'ḱ':'k','ǽ':'ae','ẁ':'w','ʒ': '\u0292','v':'v','ḿ':'m','ẃ':'w','å':'a','u':'u','q':'q',
              'ʄ': 'ƒ','ɓ':'b','ᵇ': '\u1D47','ʸ':'\u02B9','Ǹ':'n','V': 'v', " ": " "}

#Instantiating parser objects
noun_parser=NounParser()
verb_parser=VerbParser()
adj_num_parser=AdjectiveNumeralParser()


def prior_forms(row):
    """
    puts all forms that have been parsed into a single column
    """
    if pd.isna(row["POS"]):  
        return None
    elif row["POS"] in ["noun", "numeral", "adjective"]:
        form = str(row["SINGULAR"]) if isinstance(row["SINGULAR"], str) else ""
        return form
    elif row["POS"] == "verb":
        verb = row["FORM"]
        if pd.isna(verb):
            return None
        else:
            return verb
    else:
        form = str(row["SINGULAR"]) if isinstance(row["SINGULAR"], str) else ""
        return form




def parsing_data(row):
    """
    puts all forms that have been parsed into a single column
    """
    if pd.isna(row["POS"]):  
        return None
    elif row["POS"]=="noun":
        noun=row["BEFORE_PARSE"]
        if pd.isna(noun):
            return None
        else:
            noun=(noun_parser.identified_suffixes(
            noun_parser.hyphen_space(
                noun_parser.nasalized_stops(
                    noun_parser.cvcv_segmentation(
                        noun_parser.parse_noun_durationals(
                            noun_parser.parse_off_final_nasals(
                                noun_parser.existing_parses(
                                    adj_num_parser.y_suffixes(noun.strip("()/_")))))))))) if (noun.endswith("y") or (noun.endswith("ⁿ") and noun[-2]=="y")) else \
                            (noun_parser.identified_suffixes(
                                noun_parser.hyphen_space(
                                    noun_parser.nasalized_stops(
                                        noun_parser.cvcv_segmentation(
                                            noun_parser.parse_noun_durationals(
                                                noun_parser.parse_off_final_nasals(
                                                    noun_parser.existing_parses(noun.strip("()/_")))))))))
            return noun
            
    elif row["POS"] == "numeral" or row["POS"] == "adjective":
        form = row["BEFORE_PARSE"]
        if pd.isna(form):
            return None
        else:
            form=adj_num_parser.miscellaneous(
            adj_num_parser.switch_hyphen_position(
                adj_num_parser.replace_hyphens_keep_last(
                    adj_num_parser.y_suffixes(
                        adj_num_parser.isolating_suffixes(
                            adj_num_parser.parse_verb_durationals(
                                adj_num_parser.existing_parses(form.strip("()/_"))))))))
            return form
    elif row["POS"] == "verb":
        verb = row["BEFORE_PARSE"]
        if pd.isna(verb):
            return None
        else:
            verb=verb_parser.post_editing_short_strings(
            verb_parser.segment_cvcs(
                verb_parser.parse_verb_durationals(
                    verb_parser.existing_parses(verb.strip(")(_")))))
            return verb
    else:
        form = str(row["BEFORE_PARSE"]) if isinstance(row["BEFORE_PARSE"], str) else ""
        return noun_parser.parse_noun_durationals(form)



def data_prep_for_ortho_profile(input_file):
    """
    prepares data so that command line can run on it to output an orthography profile
    """
    df = pd.read_csv(input_file, delimiter='\t')
    df["ID"]=df["ID"].astype(str)
    df['ID'] = pd.to_numeric(df['ID'].str.replace(',', '').str.replace('.', ''), errors='coerce')
    df = df.dropna(subset=['ID'])
    df['ID'] = df['ID'].astype(int)
    return df.to_csv('heathdogon2.tsv', index=False, sep='\t')



def add_tab_after_quote(input_file, output_file, encoding='utf-8'):
    """
    creates a tsv file in which quotation characters are eliminated
    input_file: orthography profile created via the command line: $ lingpy profile -i heathdogon2.tsv -o  P_created-profile.tsv --column=ipa
    """
    with open(input_file, 'r', encoding=encoding) as infile, open(output_file, 'w', encoding=encoding) as outfile:
        for line in infile:
            new_line = ''
            quote_added = False
            for char in line:
                if char == '"':
                    new_line += char + '\t'
                    quote_added = True
                else:
                    new_line += char
                    if quote_added:
                        quote_added = False
            outfile.write(new_line)


def merges(row, concepts, replacement_dict):
    """
    merges various rows based on the presence of a gloss
    """
    
    if not isinstance(row["CONCEPT"], str) or not isinstance(row["DOCULECT"], str):
        # Handle unexpected types
        return None
    
    for concept in concepts:
        for key, value in replacement_dict.items():
            if concept in row["CONCEPT"] and row["DOCULECT"] == value and row["DOCULECT"] == key:
                return row["DOCULECT"] == value
            elif concept in row["CONCEPT"] and row["DOCULECT"] != value:
                if row["CONCEPT"] == key:
                    return row["CONCEPT"] == key
            elif concept in row["CONCEPT"] and row["DOCULECT"] != value or row["DOCULECT"] != key:
                return row



def change_name(name, new_name):
    """
    changes the names of various language dialects into language
    """
    for key, value in new_name.items():  
        keep_name = value
        discard_name = key
        if name == discard_name:  
            return keep_name
    return name


def remove_tones(word):
    """
    removes tones and keeps only segments
    """
    if word is None:
        return None

    new_word=""
    for letter in word:
        if letter in replacements.keys():
            new_word += replacements.get(letter)
        elif letter==" ":
            new_word +="#"
        else:
            new_word +=""
    return new_word

def remove_spaces(word):
    if word is None:
        return None
    new_word=""
    for letter in word:
        if letter==" ":
            new_word += ""
        else:
            new_word += letter
    return new_word

# %% [markdown]
# # Loading data

# %%
#loading data
pd.set_option('display.max_rows', None)
path = r"D:\ERC_Bang\Tasks\data_cleaning" 
os.chdir(path)
data = pd.read_csv("data.tsv", sep="\t", encoding="utf-8")
list_to_drop=["ID","FRENCH", "ENGLISH_SHORT", "FRENCH_SHORT", "ENGLISH_CATEGORY", "FRENCH_CATEGORY", "PARSED FORM", "MCF", "RECONSTRUCTION", "NOTE", "NOTES","Unnamed: 18", "Unnamed: 19", "Unnamed: 20", "Unnamed: 21", "COGID", "COGIDS", "Unnamed: 24"]
data=data.drop(list_to_drop, axis=1)

# %%
#visualizing data
data.head()
# Out:
#    VARID          DOCULECT                             GLOSS  \
# 0    0.0         BankanTey  domestic animal (esp. livestock)
# 1    1.0         BankanTey  domestic animal (esp. livestock)
# 2    0.0            BenTey  domestic animal (esp. livestock)
# 3    0.0            Bunoge  domestic animal (esp. livestock)
# 4    0.0  DogulDomBendiely  domestic animal (esp. livestock)
#
#                         VALUE_ORG  SINGULAR     PLURAL FORM    CONCEPT   POS
# 0  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   jáwdì-m      jáwdì  NaN  LIVESTOCK  noun
# 1  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   dá:bà-m      dá:bà  NaN  LIVESTOCK  noun
# 2                àrsɛ̌:-m\\àrsɛ̌:  àrsɛ̌:-m     àrsɛ̌:  NaN  LIVESTOCK  noun
# 3                         kɔ́mbɔ̀   kɔ́mbɔ̀   kɔmbɔ=gè  NaN  LIVESTOCK  noun
# 4               bɛ́lɛ̀g, bɛ́lɛ̀gù  bɛ́lɛ̀-g  bɛlɛ-g-yà  NaN  LIVESTOCK  noun

# %% [markdown]
# # Creating new columns

# %%
data["BEFORE_PARSE"]=data.apply(prior_forms, axis=1) #put all eligible data in one columns

# %%
data.head()
# Out:
#    VARID          DOCULECT                             GLOSS  \
# 0    0.0         BankanTey  domestic animal (esp. livestock)
# 1    1.0         BankanTey  domestic animal (esp. livestock)
# 2    0.0            BenTey  domestic animal (esp. livestock)
# 3    0.0            Bunoge  domestic animal (esp. livestock)
# 4    0.0  DogulDomBendiely  domestic animal (esp. livestock)
#
#                         VALUE_ORG  SINGULAR     PLURAL FORM    CONCEPT   POS  \
# 0  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   jáwdì-m      jáwdì  NaN  LIVESTOCK  noun
# 1  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   dá:bà-m      dá:bà  NaN  LIVESTOCK  noun
# 2                àrsɛ̌:-m\\àrsɛ̌:  àrsɛ̌:-m     àrsɛ̌:  NaN  LIVESTOCK  noun
# 3                         kɔ́mbɔ̀   kɔ́mbɔ̀   kɔmbɔ=gè  NaN  LIVESTOCK  noun
# 4               bɛ́lɛ̀g, bɛ́lɛ̀gù  bɛ́lɛ̀-g  bɛlɛ-g-yà  NaN  LIVESTOCK  noun
#
#   BEFORE_PARSE
# 0      jáwdì-m
# 1      dá:bà-m
# 2     àrsɛ̌:-m
# 3      kɔ́mbɔ̀
# 4     bɛ́lɛ̀-g

# %%
data["PARSED"]=data.apply(parsing_data,axis=1)#parse all eligible data

# %%
data.head()
# Out:
#    VARID          DOCULECT                             GLOSS  \
# 0    0.0         BankanTey  domestic animal (esp. livestock)
# 1    1.0         BankanTey  domestic animal (esp. livestock)
# 2    0.0            BenTey  domestic animal (esp. livestock)
# 3    0.0            Bunoge  domestic animal (esp. livestock)
# 4    0.0  DogulDomBendiely  domestic animal (esp. livestock)
#
#                         VALUE_ORG  SINGULAR     PLURAL FORM    CONCEPT   POS  \
# 0  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   jáwdì-m      jáwdì  NaN  LIVESTOCK  noun
# 1  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   dá:bà-m      dá:bà  NaN  LIVESTOCK  noun
# 2                àrsɛ̌:-m\\àrsɛ̌:  àrsɛ̌:-m     àrsɛ̌:  NaN  LIVESTOCK  noun
# 3                         kɔ́mbɔ̀   kɔ́mbɔ̀   kɔmbɔ=gè  NaN  LIVESTOCK  noun
# 4               bɛ́lɛ̀g, bɛ́lɛ̀gù  bɛ́lɛ̀-g  bɛlɛ-g-yà  NaN  LIVESTOCK  noun
#
#   BEFORE_PARSE     PARSED
# 0      jáwdì-m   jáw-dì-m
# 1      dá:bà-m    dáábà-m
# 2     àrsɛ̌:-m  àrsɛ̌ɛ̌-m
# 3      kɔ́mbɔ̀   kɔ́-mbɔ̀
# 4     bɛ́lɛ̀-g   bɛ́lɛ̀-g

# %%
data["TONES_REMOVED"] = data["PARSED"].apply(lambda x: remove_tones(x)) #remove tones

# %%
data.head()
# Out:
#    VARID          DOCULECT                             GLOSS  \
# 0    0.0         BankanTey  domestic animal (esp. livestock)
# 1    1.0         BankanTey  domestic animal (esp. livestock)
# 2    0.0            BenTey  domestic animal (esp. livestock)
# 3    0.0            Bunoge  domestic animal (esp. livestock)
# 4    0.0  DogulDomBendiely  domestic animal (esp. livestock)
#
#                         VALUE_ORG  SINGULAR     PLURAL FORM    CONCEPT   POS  \
# 0  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   jáwdì-m      jáwdì  NaN  LIVESTOCK  noun
# 1  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   dá:bà-m      dá:bà  NaN  LIVESTOCK  noun
# 2                àrsɛ̌:-m\\àrsɛ̌:  àrsɛ̌:-m     àrsɛ̌:  NaN  LIVESTOCK  noun
# 3                         kɔ́mbɔ̀   kɔ́mbɔ̀   kɔmbɔ=gè  NaN  LIVESTOCK  noun
# 4               bɛ́lɛ̀g, bɛ́lɛ̀gù  bɛ́lɛ̀-g  bɛlɛ-g-yà  NaN  LIVESTOCK  noun
#
#   BEFORE_PARSE     PARSED TONES_REMOVED
# 0      jáwdì-m   jáw-dì-m      jaw-di-m
# 1      dá:bà-m    dáábà-m       daaba-m
# 2     àrsɛ̌:-m  àrsɛ̌ɛ̌-m       arsɛɛ-m
# 3      kɔ́mbɔ̀   kɔ́-mbɔ̀        kɔ-mbɔ
# 4     bɛ́lɛ̀-g   bɛ́lɛ̀-g        bɛlɛ-g

# %%
tk = Tokenizer('profile.tsv')
data["IPA"]=data["TONES_REMOVED"].apply(lambda x: tk(x, column="IPA") if isinstance(x, str) else x) #running orthography profile
data["IPA"]=data["IPA"].apply(remove_spaces)#removing spaces, else Lingpy throws an error

# %%
data.head()
# Out:
#    VARID          DOCULECT                             GLOSS  \
# 0    0.0         BankanTey  domestic animal (esp. livestock)
# 1    1.0         BankanTey  domestic animal (esp. livestock)
# 2    0.0            BenTey  domestic animal (esp. livestock)
# 3    0.0            Bunoge  domestic animal (esp. livestock)
# 4    0.0  DogulDomBendiely  domestic animal (esp. livestock)
#
#                         VALUE_ORG  SINGULAR     PLURAL FORM    CONCEPT   POS  \
# 0  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   jáwdì-m      jáwdì  NaN  LIVESTOCK  noun
# 1  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   dá:bà-m      dá:bà  NaN  LIVESTOCK  noun
# 2                àrsɛ̌:-m\\àrsɛ̌:  àrsɛ̌:-m     àrsɛ̌:  NaN  LIVESTOCK  noun
# 3                         kɔ́mbɔ̀   kɔ́mbɔ̀   kɔmbɔ=gè  NaN  LIVESTOCK  noun
# 4               bɛ́lɛ̀g, bɛ́lɛ̀gù  bɛ́lɛ̀-g  bɛlɛ-g-yà  NaN  LIVESTOCK  noun
#
#   BEFORE_PARSE     PARSED TONES_REMOVED       IPA
# 0      jáwdì-m   jáw-dì-m      jaw-di-m  jaw+di+m
# 1      dá:bà-m    dáábà-m       daaba-m   daaba+m
# 2     àrsɛ̌:-m  àrsɛ̌ɛ̌-m       arsɛɛ-m   arsɛɛ+m
# 3      kɔ́mbɔ̀   kɔ́-mbɔ̀        kɔ-mbɔ    kɔ+mbɔ
# 4     bɛ́lɛ̀-g   bɛ́lɛ̀-g        bɛlɛ-g    bɛlɛ+g

# %%
data=data[["DOCULECT", "GLOSS", "IPA"]].dropna(subset=["DOCULECT", "GLOSS", "IPA"])

# %%
data.head()
# Out:
#            DOCULECT                             GLOSS       IPA
# 0         BankanTey  domestic animal (esp. livestock)  jaw+di+m
# 1         BankanTey  domestic animal (esp. livestock)   daaba+m
# 2            BenTey  domestic animal (esp. livestock)   arsɛɛ+m
# 3            Bunoge  domestic animal (esp. livestock)    kɔ+mbɔ
# 4  DogulDomBendiely  domestic animal (esp. livestock)    bɛlɛ+g

# %%
data.to_csv("new_beginining_1.csv", index=False, encoding="utf-8")#empty spaces cleaned in Google sheets

# %% [markdown]
# # Special data processing(with Lingpy)

# %%
wl=Wordlist("new_beginining_2.tsv")

# %%
wl.header
# Out:
# {'doculect': 0, 'concept': 1, 'ipa': 2}

# %%
x=25
count, results = mutual_coverage_subset(wl, x)
coverage, languages = results[0]

# %%
concepts={}
for i in languages:
    concepts[i]=set(wl.get_dict(language=i, entry="concepts"))

# %%
wl.output("tsv", filename="new_beginining_3", subset=True, rows=dict(doculect = "in "+str(languages)))
wl.output("csv", filename="new_beginining_3", subset=True, rows=dict(doculect = "in "+str(languages))) #empty spaces cleaned in Google sheets
# Out:
# 2024-04-23 13:03:47,223 [INFO] Data has been written to file <new_beginining_3.tsv>.
# 2024-04-23 13:03:47,926 [INFO] Data has been written to file <new_beginining_3.csv>.

# %% [markdown]
# # Running algorithm

# %%
wl=Wordlist("new_beginining_4.tsv")

# %%
lex=LexStat(wl)

# %%
lex.get_scorer(runs=10000)
lex.cluster(method='lexstat', threshold=0.55, ref='cogid')
lex.output('tsv', filename='new_beginining_clusters')
lex.output('csv', filename='part_beginining_clusters')
# Out:
# CORRESPONDENCE CALCULATION:   0%|                                                            | 0/288.0 [00:00<?, ?it/s]2024-04-23 14:35:37,645 [INFO] Calculating alignments for pair Ampari / Ampari.
# 2024-04-23 14:35:37,657 [INFO] Calculating alignments for pair Ampari / BankanTey.
# 2024-04-23 14:35:37,667 [INFO] Calculating alignments for pair Ampari / BenTey.
# 2024-04-23 14:35:37,675 [INFO] Calculating alignments for pair Ampari / BonduSoNajamba.
# 2024-04-23 14:35:37,686 [INFO] Calculating alignments for pair Ampari / Bunoge.
# 2024-04-23 14:35:37,695 [INFO] Calculating alignments for pair Ampari / DogulDomBendiely.
# 2024-04-23 14:35:37,702 [INFO] Calculating alignments for pair Ampari / DogulDomKundialang.
# 2024-04-23 14:35:37,709 [INFO] Calculating alignments for pair Ampari / DonnoSo.
# 2024-04-23 14:35:37,716 [INFO] Calculating alignments for pair Ampari / JamsayDouentza.
# 2024-04-23 14:35:37,724 [INFO] Calculating alignments for pair Ampari / JamsayGourou.
# 2024-04-23 14:35:37,729 [INFO] Calculating alignments for pair Ampari / JamsayMondoro.
# 2024-04-23 14:35:37,734 [INFO] Calculating alignments for pair Ampari / Mombo.
# 2024-04-23 14:35:37,741 [INFO] Calculating alignments for pair Ampari / Nanga.
# CORRESPONDENCE CALCULATION:   5%|██▍                                               | 14/288.0 [00:00<00:02, 134.55it/s]2024-04-23 14:35:37,749 [INFO] Calculating alignments for pair Ampari / Penange.
# 2024-04-23 14:35:37,756 [INFO] Calculating alignments for pair Ampari / PergeTegu.
# 2024-04-23 14:35:37,763 [INFO] Calculating alignments for pair Ampari / TebulUre.
# 2024-04-23 14:35:37,770 [INFO] Calculating alignments for pair Ampari / Tiranige.
# 2024-04-23 14:35:37,776 [INFO] Calculating alignments for pair Ampari / TogoKan.
# 2024-04-23 14:35:37,784 [INFO] Calculating alignments for pair Ampari / TommoSoTongoTongo.
# 2024-04-23 14:35:37,791 [INFO] Calculating alignments for pair Ampari / TomoKanDiangassagou.
# 2024-04-23 14:35:37,793 [INFO] Calculating alignments for pair Ampari / TomoKanSegue.
# 2024-04-23 14:35:37,796 [INFO] Calculating alignments for pair Ampari / ToroTegu.
# 2024-04-23 14:35:37,804 [INFO] Calculating alignments for pair Ampari / YandaDom.
# 2024-04-23 14:35:37,814 [INFO] Calculating alignments for pair Ampari / YornoSo.
# 2024-04-23 14:35:37,821 [INFO] Calculating alignments for pair BankanTey / BankanTey.
# 2024-04-23 14:35:37,896 [INFO] Calculating alignments for pair BankanTey / BenTey.
# 2024-04-23 14:35:37,982 [INFO] Calculating alignments for pair BankanTey / BonduSoNajamba.
# CORRESPONDENCE CALCULATION:  10%|████▉                                              | 28/288.0 [00:00<00:04, 60.59it/s]2024-04-23 14:35:38,069 [INFO] Calculating alignments for pair BankanTey / Bunoge.
# 2024-04-23 14:35:38,123 [INFO] Calculating alignments for pair BankanTey / DogulDomBendiely.
# 2024-04-23 14:35:38,166 [INFO] Calculating alignments for pair BankanTey / DogulDomKundialang.
# 2024-04-23 14:35:38,210 [INFO] Calculating alignments for pair BankanTey / DonnoSo.
# 2024-04-23 14:35:38,274 [INFO] Calculating alignments for pair BankanTey / JamsayDouentza.
# 2024-04-23 14:35:38,356 [INFO] Calculating alignments for pair BankanTey / JamsayGourou.
# 2024-04-23 14:35:38,390 [INFO] Calculating alignments for pair BankanTey / JamsayMondoro.
# 2024-04-23 14:35:38,409 [INFO] Calculating alignments for pair BankanTey / Mombo.
# 2024-04-23 14:35:38,483 [INFO] Calculating alignments for pair BankanTey / Nanga.
# CORRESPONDENCE CALCULATION:  13%|██████▌                                            | 37/288.0 [00:00<00:07, 32.98it/s]2024-04-23 14:35:38,572 [INFO] Calculating alignments for pair BankanTey / Penange.
# 2024-04-23 14:35:38,626 [INFO] Calculating alignments for pair BankanTey / PergeTegu.
# 2024-04-23 14:35:38,695 [INFO] Calculating alignments for pair BankanTey / TebulUre.
# 2024-04-23 14:35:38,747 [INFO] Calculating alignments for pair BankanTey / Tiranige.
# 2024-04-23 14:35:38,800 [INFO] Calculating alignments for pair BankanTey / TogoKan.
# 2024-04-23 14:35:38,863 [INFO] Calculating alignments for pair BankanTey / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  15%|███████▌                                           | 43/288.0 [00:01<00:09, 25.94it/s]2024-04-23 14:35:38,952 [INFO] Calculating alignments for pair BankanTey / TomoKanDiangassagou.
# 2024-04-23 14:35:38,965 [INFO] Calculating alignments for pair BankanTey / TomoKanSegue.
# 2024-04-23 14:35:38,987 [INFO] Calculating alignments for pair BankanTey / ToroTegu.
# 2024-04-23 14:35:39,059 [INFO] Calculating alignments for pair BankanTey / YandaDom.
# CORRESPONDENCE CALCULATION:  16%|████████▎                                          | 47/288.0 [00:01<00:09, 25.19it/s]2024-04-23 14:35:39,129 [INFO] Calculating alignments for pair BankanTey / YornoSo.
# 2024-04-23 14:35:39,202 [INFO] Calculating alignments for pair BenTey / BenTey.
# 2024-04-23 14:35:39,284 [INFO] Calculating alignments for pair BenTey / BonduSoNajamba.
# 2024-04-23 14:35:39,379 [INFO] Calculating alignments for pair BenTey / Bunoge.
# CORRESPONDENCE CALCULATION:  18%|█████████                                          | 51/288.0 [00:01<00:11, 20.95it/s]2024-04-23 14:35:39,438 [INFO] Calculating alignments for pair BenTey / DogulDomBendiely.
# 2024-04-23 14:35:39,486 [INFO] Calculating alignments for pair BenTey / DogulDomKundialang.
# 2024-04-23 14:35:39,536 [INFO] Calculating alignments for pair BenTey / DonnoSo.
# CORRESPONDENCE CALCULATION:  19%|█████████▌                                         | 54/288.0 [00:01<00:11, 20.19it/s]2024-04-23 14:35:39,610 [INFO] Calculating alignments for pair BenTey / JamsayDouentza.
# 2024-04-23 14:35:39,707 [INFO] Calculating alignments for pair BenTey / JamsayGourou.
# 2024-04-23 14:35:39,745 [INFO] Calculating alignments for pair BenTey / JamsayMondoro.
# CORRESPONDENCE CALCULATION:  20%|██████████                                         | 57/288.0 [00:02<00:11, 19.92it/s]2024-04-23 14:35:39,767 [INFO] Calculating alignments for pair BenTey / Mombo.
# 2024-04-23 14:35:39,851 [INFO] Calculating alignments for pair BenTey / Nanga.
# 2024-04-23 14:35:39,959 [INFO] Calculating alignments for pair BenTey / Penange.
# CORRESPONDENCE CALCULATION:  21%|██████████▋                                        | 60/288.0 [00:02<00:13, 17.23it/s]2024-04-23 14:35:40,020 [INFO] Calculating alignments for pair BenTey / PergeTegu.
# 2024-04-23 14:35:40,095 [INFO] Calculating alignments for pair BenTey / TebulUre.
# CORRESPONDENCE CALCULATION:  22%|██████████▉                                        | 62/288.0 [00:02<00:13, 16.74it/s]2024-04-23 14:35:40,155 [INFO] Calculating alignments for pair BenTey / Tiranige.
# 2024-04-23 14:35:40,211 [INFO] Calculating alignments for pair BenTey / TogoKan.
# CORRESPONDENCE CALCULATION:  22%|███████████▎                                       | 64/288.0 [00:02<00:13, 16.64it/s]2024-04-23 14:35:40,277 [INFO] Calculating alignments for pair BenTey / TommoSoTongoTongo.
# 2024-04-23 14:35:40,367 [INFO] Calculating alignments for pair BenTey / TomoKanDiangassagou.
# CORRESPONDENCE CALCULATION:  23%|███████████▋                                       | 66/288.0 [00:02<00:12, 17.23it/s]2024-04-23 14:35:40,380 [INFO] Calculating alignments for pair BenTey / TomoKanSegue.
# 2024-04-23 14:35:40,401 [INFO] Calculating alignments for pair BenTey / ToroTegu.
# 2024-04-23 14:35:40,478 [INFO] Calculating alignments for pair BenTey / YandaDom.
# CORRESPONDENCE CALCULATION:  24%|████████████▏                                      | 69/288.0 [00:02<00:12, 17.36it/s]2024-04-23 14:35:40,550 [INFO] Calculating alignments for pair BenTey / YornoSo.
# 2024-04-23 14:35:40,624 [INFO] Calculating alignments for pair BonduSoNajamba / BonduSoNajamba.
# CORRESPONDENCE CALCULATION:  25%|████████████▌                                      | 71/288.0 [00:03<00:13, 15.98it/s]2024-04-23 14:35:40,707 [INFO] Calculating alignments for pair BonduSoNajamba / Bunoge.
# 2024-04-23 14:35:40,761 [INFO] Calculating alignments for pair BonduSoNajamba / DogulDomBendiely.
# 2024-04-23 14:35:40,803 [INFO] Calculating alignments for pair BonduSoNajamba / DogulDomKundialang.
# CORRESPONDENCE CALCULATION:  26%|█████████████                                      | 74/288.0 [00:03<00:12, 17.38it/s]2024-04-23 14:35:40,850 [INFO] Calculating alignments for pair BonduSoNajamba / DonnoSo.
# 2024-04-23 14:35:40,916 [INFO] Calculating alignments for pair BonduSoNajamba / JamsayDouentza.
# CORRESPONDENCE CALCULATION:  26%|█████████████▍                                     | 76/288.0 [00:03<00:13, 16.19it/s]2024-04-23 14:35:41,000 [INFO] Calculating alignments for pair BonduSoNajamba / JamsayGourou.
# 2024-04-23 14:35:41,032 [INFO] Calculating alignments for pair BonduSoNajamba / JamsayMondoro.
# 2024-04-23 14:35:41,052 [INFO] Calculating alignments for pair BonduSoNajamba / Mombo.
# CORRESPONDENCE CALCULATION:  27%|█████████████▉                                     | 79/288.0 [00:03<00:11, 18.14it/s]2024-04-23 14:35:41,127 [INFO] Calculating alignments for pair BonduSoNajamba / Nanga.
# 2024-04-23 14:35:41,216 [INFO] Calculating alignments for pair BonduSoNajamba / Penange.
# CORRESPONDENCE CALCULATION:  28%|██████████████▎                                    | 81/288.0 [00:03<00:12, 16.66it/s]2024-04-23 14:35:41,277 [INFO] Calculating alignments for pair BonduSoNajamba / PergeTegu.
# 2024-04-23 14:35:41,354 [INFO] Calculating alignments for pair BonduSoNajamba / TebulUre.
# CORRESPONDENCE CALCULATION:  29%|██████████████▋                                    | 83/288.0 [00:03<00:12, 16.07it/s]2024-04-23 14:35:41,414 [INFO] Calculating alignments for pair BonduSoNajamba / Tiranige.
# 2024-04-23 14:35:41,474 [INFO] Calculating alignments for pair BonduSoNajamba / TogoKan.
# CORRESPONDENCE CALCULATION:  30%|███████████████                                    | 85/288.0 [00:03<00:12, 15.68it/s]2024-04-23 14:35:41,549 [INFO] Calculating alignments for pair BonduSoNajamba / TommoSoTongoTongo.
# 2024-04-23 14:35:41,654 [INFO] Calculating alignments for pair BonduSoNajamba / TomoKanDiangassagou.
# CORRESPONDENCE CALCULATION:  30%|███████████████▍                                   | 87/288.0 [00:04<00:12, 15.98it/s]2024-04-23 14:35:41,669 [INFO] Calculating alignments for pair BonduSoNajamba / TomoKanSegue.
# 2024-04-23 14:35:41,694 [INFO] Calculating alignments for pair BonduSoNajamba / ToroTegu.
# CORRESPONDENCE CALCULATION:  31%|███████████████▊                                   | 89/288.0 [00:04<00:11, 16.59it/s]2024-04-23 14:35:41,778 [INFO] Calculating alignments for pair BonduSoNajamba / YandaDom.
# 2024-04-23 14:35:41,857 [INFO] Calculating alignments for pair BonduSoNajamba / YornoSo.
# CORRESPONDENCE CALCULATION:  32%|████████████████                                   | 91/288.0 [00:04<00:13, 15.08it/s]2024-04-23 14:35:41,941 [INFO] Calculating alignments for pair Bunoge / Bunoge.
# 2024-04-23 14:35:41,997 [INFO] Calculating alignments for pair Bunoge / DogulDomBendiely.
# 2024-04-23 14:35:42,031 [INFO] Calculating alignments for pair Bunoge / DogulDomKundialang.
# CORRESPONDENCE CALCULATION:  33%|████████████████▋                                  | 94/288.0 [00:04<00:11, 17.42it/s]2024-04-23 14:35:42,070 [INFO] Calculating alignments for pair Bunoge / DonnoSo.
# 2024-04-23 14:35:42,122 [INFO] Calculating alignments for pair Bunoge / JamsayDouentza.
# CORRESPONDENCE CALCULATION:  33%|█████████████████                                  | 96/288.0 [00:04<00:10, 17.50it/s]2024-04-23 14:35:42,182 [INFO] Calculating alignments for pair Bunoge / JamsayGourou.
# 2024-04-23 14:35:42,211 [INFO] Calculating alignments for pair Bunoge / JamsayMondoro.
# 2024-04-23 14:35:42,230 [INFO] Calculating alignments for pair Bunoge / Mombo.
# 2024-04-23 14:35:42,282 [INFO] Calculating alignments for pair Bunoge / Nanga.
# CORRESPONDENCE CALCULATION:  35%|█████████████████▎                                | 100/288.0 [00:04<00:09, 20.07it/s]2024-04-23 14:35:42,344 [INFO] Calculating alignments for pair Bunoge / Penange.
# 2024-04-23 14:35:42,398 [INFO] Calculating alignments for pair Bunoge / PergeTegu.
# CORRESPONDENCE CALCULATION:  35%|█████████████████▋                                | 102/288.0 [00:04<00:09, 19.96it/s]2024-04-23 14:35:42,446 [INFO] Calculating alignments for pair Bunoge / TebulUre.
# 2024-04-23 14:35:42,487 [INFO] Calculating alignments for pair Bunoge / Tiranige.
# 2024-04-23 14:35:42,534 [INFO] Calculating alignments for pair Bunoge / TogoKan.
# CORRESPONDENCE CALCULATION:  36%|██████████████████▏                               | 105/288.0 [00:04<00:08, 20.65it/s]2024-04-23 14:35:42,581 [INFO] Calculating alignments for pair Bunoge / TommoSoTongoTongo.
# 2024-04-23 14:35:42,643 [INFO] Calculating alignments for pair Bunoge / TomoKanDiangassagou.
# 2024-04-23 14:35:42,653 [INFO] Calculating alignments for pair Bunoge / TomoKanSegue.
# 2024-04-23 14:35:42,670 [INFO] Calculating alignments for pair Bunoge / ToroTegu.
# CORRESPONDENCE CALCULATION:  38%|██████████████████▉                               | 109/288.0 [00:05<00:07, 23.05it/s]2024-04-23 14:35:42,723 [INFO] Calculating alignments for pair Bunoge / YandaDom.
# 2024-04-23 14:35:42,774 [INFO] Calculating alignments for pair Bunoge / YornoSo.
# 2024-04-23 14:35:42,822 [INFO] Calculating alignments for pair DogulDomBendiely / DogulDomBendiely.
# CORRESPONDENCE CALCULATION:  39%|███████████████████▍                              | 112/288.0 [00:05<00:07, 22.50it/s]2024-04-23 14:35:42,864 [INFO] Calculating alignments for pair DogulDomBendiely / DogulDomKundialang.
# 2024-04-23 14:35:42,897 [INFO] Calculating alignments for pair DogulDomBendiely / DonnoSo.
# 2024-04-23 14:35:42,937 [INFO] Calculating alignments for pair DogulDomBendiely / JamsayDouentza.
# CORRESPONDENCE CALCULATION:  40%|███████████████████▉                              | 115/288.0 [00:05<00:07, 23.14it/s]2024-04-23 14:35:42,985 [INFO] Calculating alignments for pair DogulDomBendiely / JamsayGourou.
# 2024-04-23 14:35:43,006 [INFO] Calculating alignments for pair DogulDomBendiely / JamsayMondoro.
# 2024-04-23 14:35:43,021 [INFO] Calculating alignments for pair DogulDomBendiely / Mombo.
# 2024-04-23 14:35:43,062 [INFO] Calculating alignments for pair DogulDomBendiely / Nanga.
# CORRESPONDENCE CALCULATION:  41%|████████████████████▋                             | 119/288.0 [00:05<00:06, 25.62it/s]2024-04-23 14:35:43,111 [INFO] Calculating alignments for pair DogulDomBendiely / Penange.
# 2024-04-23 14:35:43,144 [INFO] Calculating alignments for pair DogulDomBendiely / PergeTegu.
# 2024-04-23 14:35:43,182 [INFO] Calculating alignments for pair DogulDomBendiely / TebulUre.
# CORRESPONDENCE CALCULATION:  42%|█████████████████████▏                            | 122/288.0 [00:05<00:06, 26.33it/s]2024-04-23 14:35:43,216 [INFO] Calculating alignments for pair DogulDomBendiely / Tiranige.
# 2024-04-23 14:35:43,251 [INFO] Calculating alignments for pair DogulDomBendiely / TogoKan.
# 2024-04-23 14:35:43,288 [INFO] Calculating alignments for pair DogulDomBendiely / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  43%|█████████████████████▋                            | 125/288.0 [00:05<00:06, 25.88it/s]2024-04-23 14:35:43,337 [INFO] Calculating alignments for pair DogulDomBendiely / TomoKanDiangassagou.
# 2024-04-23 14:35:43,345 [INFO] Calculating alignments for pair DogulDomBendiely / TomoKanSegue.
# 2024-04-23 14:35:43,358 [INFO] Calculating alignments for pair DogulDomBendiely / ToroTegu.
# 2024-04-23 14:35:43,400 [INFO] Calculating alignments for pair DogulDomBendiely / YandaDom.
# CORRESPONDENCE CALCULATION:  45%|██████████████████████▍                           | 129/288.0 [00:05<00:05, 29.30it/s]2024-04-23 14:35:43,441 [INFO] Calculating alignments for pair DogulDomBendiely / YornoSo.
# 2024-04-23 14:35:43,481 [INFO] Calculating alignments for pair DogulDomKundialang / DogulDomKundialang.
# 2024-04-23 14:35:43,524 [INFO] Calculating alignments for pair DogulDomKundialang / DonnoSo.
# CORRESPONDENCE CALCULATION:  46%|██████████████████████▉                           | 132/288.0 [00:05<00:05, 27.43it/s]2024-04-23 14:35:43,569 [INFO] Calculating alignments for pair DogulDomKundialang / JamsayDouentza.
# 2024-04-23 14:35:43,619 [INFO] Calculating alignments for pair DogulDomKundialang / JamsayGourou.
# 2024-04-23 14:35:43,643 [INFO] Calculating alignments for pair DogulDomKundialang / JamsayMondoro.
# 2024-04-23 14:35:43,657 [INFO] Calculating alignments for pair DogulDomKundialang / Mombo.
# CORRESPONDENCE CALCULATION:  47%|███████████████████████▌                          | 136/288.0 [00:06<00:05, 28.21it/s]2024-04-23 14:35:43,703 [INFO] Calculating alignments for pair DogulDomKundialang / Nanga.
# 2024-04-23 14:35:43,755 [INFO] Calculating alignments for pair DogulDomKundialang / Penange.
# 2024-04-23 14:35:43,792 [INFO] Calculating alignments for pair DogulDomKundialang / PergeTegu.
# CORRESPONDENCE CALCULATION:  48%|████████████████████████▏                         | 139/288.0 [00:06<00:05, 26.49it/s]2024-04-23 14:35:43,835 [INFO] Calculating alignments for pair DogulDomKundialang / TebulUre.
# 2024-04-23 14:35:43,874 [INFO] Calculating alignments for pair DogulDomKundialang / Tiranige.
# 2024-04-23 14:35:43,913 [INFO] Calculating alignments for pair DogulDomKundialang / TogoKan.
# CORRESPONDENCE CALCULATION:  49%|████████████████████████▋                         | 142/288.0 [00:06<00:05, 26.00it/s]2024-04-23 14:35:43,955 [INFO] Calculating alignments for pair DogulDomKundialang / TommoSoTongoTongo.
# 2024-04-23 14:35:44,010 [INFO] Calculating alignments for pair DogulDomKundialang / TomoKanDiangassagou.
# 2024-04-23 14:35:44,019 [INFO] Calculating alignments for pair DogulDomKundialang / TomoKanSegue.
# 2024-04-23 14:35:44,036 [INFO] Calculating alignments for pair DogulDomKundialang / ToroTegu.
# CORRESPONDENCE CALCULATION:  51%|█████████████████████████▎                        | 146/288.0 [00:06<00:05, 27.93it/s]2024-04-23 14:35:44,079 [INFO] Calculating alignments for pair DogulDomKundialang / YandaDom.
# 2024-04-23 14:35:44,124 [INFO] Calculating alignments for pair DogulDomKundialang / YornoSo.
# 2024-04-23 14:35:44,167 [INFO] Calculating alignments for pair DonnoSo / DonnoSo.
# CORRESPONDENCE CALCULATION:  52%|█████████████████████████▊                        | 149/288.0 [00:06<00:05, 25.12it/s]2024-04-23 14:35:44,230 [INFO] Calculating alignments for pair DonnoSo / JamsayDouentza.
# 2024-04-23 14:35:44,304 [INFO] Calculating alignments for pair DonnoSo / JamsayGourou.
# 2024-04-23 14:35:44,335 [INFO] Calculating alignments for pair DonnoSo / JamsayMondoro.
# CORRESPONDENCE CALCULATION:  53%|██████████████████████████▍                       | 152/288.0 [00:06<00:05, 24.80it/s]2024-04-23 14:35:44,355 [INFO] Calculating alignments for pair DonnoSo / Mombo.
# 2024-04-23 14:35:44,420 [INFO] Calculating alignments for pair DonnoSo / Nanga.
# 2024-04-23 14:35:44,504 [INFO] Calculating alignments for pair DonnoSo / Penange.
# CORRESPONDENCE CALCULATION:  54%|██████████████████████████▉                       | 155/288.0 [00:06<00:06, 20.87it/s]2024-04-23 14:35:44,557 [INFO] Calculating alignments for pair DonnoSo / PergeTegu.
# 2024-04-23 14:35:44,616 [INFO] Calculating alignments for pair DonnoSo / TebulUre.
# 2024-04-23 14:35:44,668 [INFO] Calculating alignments for pair DonnoSo / Tiranige.
# CORRESPONDENCE CALCULATION:  55%|███████████████████████████▍                      | 158/288.0 [00:07<00:06, 19.98it/s]2024-04-23 14:35:44,723 [INFO] Calculating alignments for pair DonnoSo / TogoKan.
# 2024-04-23 14:35:44,783 [INFO] Calculating alignments for pair DonnoSo / TommoSoTongoTongo.
# 2024-04-23 14:35:44,858 [INFO] Calculating alignments for pair DonnoSo / TomoKanDiangassagou.
# CORRESPONDENCE CALCULATION:  56%|███████████████████████████▉                      | 161/288.0 [00:07<00:06, 20.07it/s]2024-04-23 14:35:44,871 [INFO] Calculating alignments for pair DonnoSo / TomoKanSegue.
# 2024-04-23 14:35:44,891 [INFO] Calculating alignments for pair DonnoSo / ToroTegu.
# 2024-04-23 14:35:44,955 [INFO] Calculating alignments for pair DonnoSo / YandaDom.
# CORRESPONDENCE CALCULATION:  57%|████████████████████████████▍                     | 164/288.0 [00:07<00:06, 20.09it/s]2024-04-23 14:35:45,020 [INFO] Calculating alignments for pair DonnoSo / YornoSo.
# 2024-04-23 14:35:45,081 [INFO] Calculating alignments for pair JamsayDouentza / JamsayDouentza.
# 2024-04-23 14:35:45,159 [INFO] Calculating alignments for pair JamsayDouentza / JamsayGourou.
# CORRESPONDENCE CALCULATION:  58%|████████████████████████████▉                     | 167/288.0 [00:07<00:06, 19.08it/s]2024-04-23 14:35:45,196 [INFO] Calculating alignments for pair JamsayDouentza / JamsayMondoro.
# 2024-04-23 14:35:45,218 [INFO] Calculating alignments for pair JamsayDouentza / Mombo.
# CORRESPONDENCE CALCULATION:  59%|█████████████████████████████▎                    | 169/288.0 [00:07<00:06, 19.19it/s]2024-04-23 14:35:45,297 [INFO] Calculating alignments for pair JamsayDouentza / Nanga.
# 2024-04-23 14:35:45,387 [INFO] Calculating alignments for pair JamsayDouentza / Penange.
# CORRESPONDENCE CALCULATION:  59%|█████████████████████████████▋                    | 171/288.0 [00:07<00:06, 17.70it/s]2024-04-23 14:35:45,439 [INFO] Calculating alignments for pair JamsayDouentza / PergeTegu.
# 2024-04-23 14:35:45,506 [INFO] Calculating alignments for pair JamsayDouentza / TebulUre.
# CORRESPONDENCE CALCULATION:  60%|██████████████████████████████                    | 173/288.0 [00:07<00:06, 17.42it/s]2024-04-23 14:35:45,558 [INFO] Calculating alignments for pair JamsayDouentza / Tiranige.
# 2024-04-23 14:35:45,611 [INFO] Calculating alignments for pair JamsayDouentza / TogoKan.
# CORRESPONDENCE CALCULATION:  61%|██████████████████████████████▍                   | 175/288.0 [00:08<00:06, 17.14it/s]2024-04-23 14:35:45,680 [INFO] Calculating alignments for pair JamsayDouentza / TommoSoTongoTongo.
# 2024-04-23 14:35:45,773 [INFO] Calculating alignments for pair JamsayDouentza / TomoKanDiangassagou.
# CORRESPONDENCE CALCULATION:  61%|██████████████████████████████▋                   | 177/288.0 [00:08<00:06, 17.62it/s]2024-04-23 14:35:45,785 [INFO] Calculating alignments for pair JamsayDouentza / TomoKanSegue.
# 2024-04-23 14:35:45,805 [INFO] Calculating alignments for pair JamsayDouentza / ToroTegu.
# 2024-04-23 14:35:45,879 [INFO] Calculating alignments for pair JamsayDouentza / YandaDom.
# CORRESPONDENCE CALCULATION:  62%|███████████████████████████████▎                  | 180/288.0 [00:08<00:06, 17.83it/s]2024-04-23 14:35:45,951 [INFO] Calculating alignments for pair JamsayDouentza / YornoSo.
# 2024-04-23 14:35:46,022 [INFO] Calculating alignments for pair JamsayGourou / JamsayGourou.
# 2024-04-23 14:35:46,048 [INFO] Calculating alignments for pair JamsayGourou / JamsayMondoro.
# CORRESPONDENCE CALCULATION:  64%|███████████████████████████████▊                  | 183/288.0 [00:08<00:05, 20.26it/s]2024-04-23 14:35:46,061 [INFO] Calculating alignments for pair JamsayGourou / Mombo.
# 2024-04-23 14:35:46,089 [INFO] Calculating alignments for pair JamsayGourou / Nanga.
# 2024-04-23 14:35:46,123 [INFO] Calculating alignments for pair JamsayGourou / Penange.
# 2024-04-23 14:35:46,147 [INFO] Calculating alignments for pair JamsayGourou / PergeTegu.
# CORRESPONDENCE CALCULATION:  65%|████████████████████████████████▍                 | 187/288.0 [00:08<00:04, 24.35it/s]2024-04-23 14:35:46,175 [INFO] Calculating alignments for pair JamsayGourou / TebulUre.
# 2024-04-23 14:35:46,198 [INFO] Calculating alignments for pair JamsayGourou / Tiranige.
# 2024-04-23 14:35:46,223 [INFO] Calculating alignments for pair JamsayGourou / TogoKan.
# 2024-04-23 14:35:46,249 [INFO] Calculating alignments for pair JamsayGourou / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  66%|█████████████████████████████████▏                | 191/288.0 [00:08<00:03, 27.66it/s]2024-04-23 14:35:46,285 [INFO] Calculating alignments for pair JamsayGourou / TomoKanDiangassagou.
# 2024-04-23 14:35:46,291 [INFO] Calculating alignments for pair JamsayGourou / TomoKanSegue.
# 2024-04-23 14:35:46,303 [INFO] Calculating alignments for pair JamsayGourou / ToroTegu.
# 2024-04-23 14:35:46,334 [INFO] Calculating alignments for pair JamsayGourou / YandaDom.
# 2024-04-23 14:35:46,366 [INFO] Calculating alignments for pair JamsayGourou / YornoSo.
# CORRESPONDENCE CALCULATION:  68%|██████████████████████████████████                | 196/288.0 [00:08<00:02, 32.44it/s]2024-04-23 14:35:46,398 [INFO] Calculating alignments for pair JamsayMondoro / JamsayMondoro.
# 2024-04-23 14:35:46,414 [INFO] Calculating alignments for pair JamsayMondoro / Mombo.
# 2024-04-23 14:35:46,434 [INFO] Calculating alignments for pair JamsayMondoro / Nanga.
# 2024-04-23 14:35:46,456 [INFO] Calculating alignments for pair JamsayMondoro / Penange.
# 2024-04-23 14:35:46,474 [INFO] Calculating alignments for pair JamsayMondoro / PergeTegu.
# 2024-04-23 14:35:46,492 [INFO] Calculating alignments for pair JamsayMondoro / TebulUre.
# CORRESPONDENCE CALCULATION:  70%|███████████████████████████████████               | 202/288.0 [00:08<00:02, 38.48it/s]2024-04-23 14:35:46,510 [INFO] Calculating alignments for pair JamsayMondoro / Tiranige.
# 2024-04-23 14:35:46,526 [INFO] Calculating alignments for pair JamsayMondoro / TogoKan.
# 2024-04-23 14:35:46,544 [INFO] Calculating alignments for pair JamsayMondoro / TommoSoTongoTongo.
# 2024-04-23 14:35:46,567 [INFO] Calculating alignments for pair JamsayMondoro / TomoKanDiangassagou.
# 2024-04-23 14:35:46,572 [INFO] Calculating alignments for pair JamsayMondoro / TomoKanSegue.
# 2024-04-23 14:35:46,578 [INFO] Calculating alignments for pair JamsayMondoro / ToroTegu.
# 2024-04-23 14:35:46,597 [INFO] Calculating alignments for pair JamsayMondoro / YandaDom.
# CORRESPONDENCE CALCULATION:  73%|████████████████████████████████████▎             | 209/288.0 [00:08<00:01, 45.98it/s]2024-04-23 14:35:46,618 [INFO] Calculating alignments for pair JamsayMondoro / YornoSo.
# 2024-04-23 14:35:46,637 [INFO] Calculating alignments for pair Mombo / Mombo.
# 2024-04-23 14:35:46,721 [INFO] Calculating alignments for pair Mombo / Nanga.
# 2024-04-23 14:35:46,808 [INFO] Calculating alignments for pair Mombo / Penange.
# 2024-04-23 14:35:46,860 [INFO] Calculating alignments for pair Mombo / PergeTegu.
# CORRESPONDENCE CALCULATION:  74%|█████████████████████████████████████▏            | 214/288.0 [00:09<00:02, 30.00it/s]2024-04-23 14:35:46,926 [INFO] Calculating alignments for pair Mombo / TebulUre.
# 2024-04-23 14:35:46,978 [INFO] Calculating alignments for pair Mombo / Tiranige.
# 2024-04-23 14:35:47,031 [INFO] Calculating alignments for pair Mombo / TogoKan.
# 2024-04-23 14:35:47,098 [INFO] Calculating alignments for pair Mombo / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  76%|█████████████████████████████████████▊            | 218/288.0 [00:09<00:02, 24.11it/s]2024-04-23 14:35:47,191 [INFO] Calculating alignments for pair Mombo / TomoKanDiangassagou.
# 2024-04-23 14:35:47,207 [INFO] Calculating alignments for pair Mombo / TomoKanSegue.
# 2024-04-23 14:35:47,228 [INFO] Calculating alignments for pair Mombo / ToroTegu.
# 2024-04-23 14:35:47,301 [INFO] Calculating alignments for pair Mombo / YandaDom.
# CORRESPONDENCE CALCULATION:  77%|██████████████████████████████████████▌           | 222/288.0 [00:09<00:02, 23.55it/s]2024-04-23 14:35:47,372 [INFO] Calculating alignments for pair Mombo / YornoSo.
# 2024-04-23 14:35:47,443 [INFO] Calculating alignments for pair Nanga / Nanga.
# 2024-04-23 14:35:47,531 [INFO] Calculating alignments for pair Nanga / Penange.
# CORRESPONDENCE CALCULATION:  78%|███████████████████████████████████████           | 225/288.0 [00:09<00:03, 20.31it/s]2024-04-23 14:35:47,592 [INFO] Calculating alignments for pair Nanga / PergeTegu.
# 2024-04-23 14:35:47,670 [INFO] Calculating alignments for pair Nanga / TebulUre.
# 2024-04-23 14:35:47,730 [INFO] Calculating alignments for pair Nanga / Tiranige.
# CORRESPONDENCE CALCULATION:  79%|███████████████████████████████████████▌          | 228/288.0 [00:10<00:03, 18.72it/s]2024-04-23 14:35:47,792 [INFO] Calculating alignments for pair Nanga / TogoKan.
# 2024-04-23 14:35:47,868 [INFO] Calculating alignments for pair Nanga / TommoSoTongoTongo.
# 2024-04-23 14:35:47,975 [INFO] Calculating alignments for pair Nanga / TomoKanDiangassagou.
# CORRESPONDENCE CALCULATION:  80%|████████████████████████████████████████          | 231/288.0 [00:10<00:03, 17.65it/s]2024-04-23 14:35:47,990 [INFO] Calculating alignments for pair Nanga / TomoKanSegue.
# 2024-04-23 14:35:48,015 [INFO] Calculating alignments for pair Nanga / ToroTegu.
# CORRESPONDENCE CALCULATION:  81%|████████████████████████████████████████▍         | 233/288.0 [00:10<00:03, 17.66it/s]2024-04-23 14:35:48,103 [INFO] Calculating alignments for pair Nanga / YandaDom.
# 2024-04-23 14:35:48,187 [INFO] Calculating alignments for pair Nanga / YornoSo.
# CORRESPONDENCE CALCULATION:  82%|████████████████████████████████████████▊         | 235/288.0 [00:10<00:03, 15.95it/s]2024-04-23 14:35:48,271 [INFO] Calculating alignments for pair Penange / Penange.
# 2024-04-23 14:35:48,323 [INFO] Calculating alignments for pair Penange / PergeTegu.
# 2024-04-23 14:35:48,371 [INFO] Calculating alignments for pair Penange / TebulUre.
# CORRESPONDENCE CALCULATION:  83%|█████████████████████████████████████████▎        | 238/288.0 [00:10<00:02, 17.33it/s]2024-04-23 14:35:48,412 [INFO] Calculating alignments for pair Penange / Tiranige.
# 2024-04-23 14:35:48,459 [INFO] Calculating alignments for pair Penange / TogoKan.
# 2024-04-23 14:35:48,506 [INFO] Calculating alignments for pair Penange / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  84%|█████████████████████████████████████████▊        | 241/288.0 [00:10<00:02, 17.95it/s]2024-04-23 14:35:48,566 [INFO] Calculating alignments for pair Penange / TomoKanDiangassagou.
# 2024-04-23 14:35:48,577 [INFO] Calculating alignments for pair Penange / TomoKanSegue.
# 2024-04-23 14:35:48,595 [INFO] Calculating alignments for pair Penange / ToroTegu.
# 2024-04-23 14:35:48,646 [INFO] Calculating alignments for pair Penange / YandaDom.
# CORRESPONDENCE CALCULATION:  85%|██████████████████████████████████████████▌       | 245/288.0 [00:11<00:02, 21.13it/s]2024-04-23 14:35:48,699 [INFO] Calculating alignments for pair Penange / YornoSo.
# 2024-04-23 14:35:48,749 [INFO] Calculating alignments for pair PergeTegu / PergeTegu.
# 2024-04-23 14:35:48,811 [INFO] Calculating alignments for pair PergeTegu / TebulUre.
# CORRESPONDENCE CALCULATION:  86%|███████████████████████████████████████████       | 248/288.0 [00:11<00:01, 20.39it/s]2024-04-23 14:35:48,860 [INFO] Calculating alignments for pair PergeTegu / Tiranige.
# 2024-04-23 14:35:48,908 [INFO] Calculating alignments for pair PergeTegu / TogoKan.
# 2024-04-23 14:35:48,968 [INFO] Calculating alignments for pair PergeTegu / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  87%|███████████████████████████████████████████▌      | 251/288.0 [00:11<00:01, 18.77it/s]2024-04-23 14:35:49,050 [INFO] Calculating alignments for pair PergeTegu / TomoKanDiangassagou.
# 2024-04-23 14:35:49,060 [INFO] Calculating alignments for pair PergeTegu / TomoKanSegue.
# 2024-04-23 14:35:49,079 [INFO] Calculating alignments for pair PergeTegu / ToroTegu.
# 2024-04-23 14:35:49,144 [INFO] Calculating alignments for pair PergeTegu / YandaDom.
# CORRESPONDENCE CALCULATION:  89%|████████████████████████████████████████████▎     | 255/288.0 [00:11<00:01, 20.68it/s]2024-04-23 14:35:49,209 [INFO] Calculating alignments for pair PergeTegu / YornoSo.
# 2024-04-23 14:35:49,275 [INFO] Calculating alignments for pair TebulUre / TebulUre.
# 2024-04-23 14:35:49,326 [INFO] Calculating alignments for pair TebulUre / Tiranige.
# CORRESPONDENCE CALCULATION:  90%|████████████████████████████████████████████▊     | 258/288.0 [00:11<00:01, 20.08it/s]2024-04-23 14:35:49,370 [INFO] Calculating alignments for pair TebulUre / TogoKan.
# 2024-04-23 14:35:49,416 [INFO] Calculating alignments for pair TebulUre / TommoSoTongoTongo.
# 2024-04-23 14:35:49,476 [INFO] Calculating alignments for pair TebulUre / TomoKanDiangassagou.
# CORRESPONDENCE CALCULATION:  91%|█████████████████████████████████████████████▎    | 261/288.0 [00:11<00:01, 21.37it/s]2024-04-23 14:35:49,487 [INFO] Calculating alignments for pair TebulUre / TomoKanSegue.
# 2024-04-23 14:35:49,507 [INFO] Calculating alignments for pair TebulUre / ToroTegu.
# 2024-04-23 14:35:49,556 [INFO] Calculating alignments for pair TebulUre / YandaDom.
# CORRESPONDENCE CALCULATION:  92%|█████████████████████████████████████████████▊    | 264/288.0 [00:11<00:01, 22.35it/s]2024-04-23 14:35:49,606 [INFO] Calculating alignments for pair TebulUre / YornoSo.
# 2024-04-23 14:35:49,651 [INFO] Calculating alignments for pair Tiranige / Tiranige.
# 2024-04-23 14:35:49,699 [INFO] Calculating alignments for pair Tiranige / TogoKan.
# CORRESPONDENCE CALCULATION:  93%|██████████████████████████████████████████████▎   | 267/288.0 [00:12<00:00, 22.26it/s]2024-04-23 14:35:49,742 [INFO] Calculating alignments for pair Tiranige / TommoSoTongoTongo.
# 2024-04-23 14:35:49,797 [INFO] Calculating alignments for pair Tiranige / TomoKanDiangassagou.
# 2024-04-23 14:35:49,806 [INFO] Calculating alignments for pair Tiranige / TomoKanSegue.
# 2024-04-23 14:35:49,821 [INFO] Calculating alignments for pair Tiranige / ToroTegu.
# CORRESPONDENCE CALCULATION:  94%|███████████████████████████████████████████████   | 271/288.0 [00:12<00:00, 25.03it/s]2024-04-23 14:35:49,866 [INFO] Calculating alignments for pair Tiranige / YandaDom.
# 2024-04-23 14:35:49,912 [INFO] Calculating alignments for pair Tiranige / YornoSo.
# 2024-04-23 14:35:49,957 [INFO] Calculating alignments for pair TogoKan / TogoKan.
# CORRESPONDENCE CALCULATION:  95%|███████████████████████████████████████████████▌  | 274/288.0 [00:12<00:00, 23.60it/s]2024-04-23 14:35:50,012 [INFO] Calculating alignments for pair TogoKan / TommoSoTongoTongo.
# 2024-04-23 14:35:50,082 [INFO] Calculating alignments for pair TogoKan / TomoKanDiangassagou.
# 2024-04-23 14:35:50,091 [INFO] Calculating alignments for pair TogoKan / TomoKanSegue.
# 2024-04-23 14:35:50,108 [INFO] Calculating alignments for pair TogoKan / ToroTegu.
# CORRESPONDENCE CALCULATION:  97%|████████████████████████████████████████████████▎ | 278/288.0 [00:12<00:00, 24.42it/s]2024-04-23 14:35:50,165 [INFO] Calculating alignments for pair TogoKan / YandaDom.
# 2024-04-23 14:35:50,222 [INFO] Calculating alignments for pair TogoKan / YornoSo.
# 2024-04-23 14:35:50,281 [INFO] Calculating alignments for pair TommoSoTongoTongo / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  98%|████████████████████████████████████████████████▊ | 281/288.0 [00:12<00:00, 20.43it/s]2024-04-23 14:35:50,377 [INFO] Calculating alignments for pair TommoSoTongoTongo / TomoKanDiangassagou.
# 2024-04-23 14:35:50,389 [INFO] Calculating alignments for pair TommoSoTongoTongo / TomoKanSegue.
# 2024-04-23 14:35:50,412 [INFO] Calculating alignments for pair TommoSoTongoTongo / ToroTegu.
# CORRESPONDENCE CALCULATION:  99%|█████████████████████████████████████████████████▎| 284/288.0 [00:12<00:00, 21.31it/s]2024-04-23 14:35:50,501 [INFO] Calculating alignments for pair TommoSoTongoTongo / YandaDom.
# 2024-04-23 14:35:50,587 [INFO] Calculating alignments for pair TommoSoTongoTongo / YornoSo.
# 2024-04-23 14:35:50,681 [INFO] Calculating alignments for pair TomoKanDiangassagou / TomoKanDiangassagou.
# CORRESPONDENCE CALCULATION: 100%|█████████████████████████████████████████████████▊| 287/288.0 [00:13<00:00, 19.28it/s]2024-04-23 14:35:50,695 [INFO] Calculating alignments for pair TomoKanDiangassagou / TomoKanSegue.
# 2024-04-23 14:35:50,708 [INFO] Calculating alignments for pair TomoKanDiangassagou / ToroTegu.
# 2024-04-23 14:35:50,719 [INFO] Calculating alignments for pair TomoKanDiangassagou / YandaDom.
# 2024-04-23 14:35:50,731 [INFO] Calculating alignments for pair TomoKanDiangassagou / YornoSo.
# 2024-04-23 14:35:50,742 [INFO] Calculating alignments for pair TomoKanSegue / TomoKanSegue.
# 2024-04-23 14:35:50,764 [INFO] Calculating alignments for pair TomoKanSegue / ToroTegu.
# 2024-04-23 14:35:50,784 [INFO] Calculating alignments for pair TomoKanSegue / YandaDom.
# CORRESPONDENCE CALCULATION: 294it [00:13, 29.18it/s]                                                                   2024-04-23 14:35:50,804 [INFO] Calculating alignments for pair TomoKanSegue / YornoSo.
# 2024-04-23 14:35:50,824 [INFO] Calculating alignments for pair ToroTegu / ToroTegu.
# 2024-04-23 14:35:50,892 [INFO] Calculating alignments for pair ToroTegu / YandaDom.
# 2024-04-23 14:35:50,963 [INFO] Calculating alignments for pair ToroTegu / YornoSo.
# CORRESPONDENCE CALCULATION: 298it [00:13, 24.51it/s]2024-04-23 14:35:51,033 [INFO] Calculating alignments for pair YandaDom / YandaDom.
# 2024-04-23 14:35:51,101 [INFO] Calculating alignments for pair YandaDom / YornoSo.
# 2024-04-23 14:35:51,170 [INFO] Calculating alignments for pair YornoSo / YornoSo.
# RANDOM CORRESPONDENCE CALCULATION:   0%|                                                     | 0/288.0 [00:00<?, ?it/s]2024-04-23 14:35:51,241 [INFO] Calculating random alignmentsfor pair Ampari/Ampari.
# RANDOM CORRESPONDENCE CALCULATION:   1%|▎                                            | 2/288.0 [00:00<01:15,  3.78it/s]2024-04-23 14:35:51,771 [INFO] Calculating random alignmentsfor pair Ampari/BankanTey.
# RANDOM CORRESPONDENCE CALCULATION:   1%|▍                                            | 3/288.0 [00:01<01:50,  2.58it/s]2024-04-23 14:35:52,330 [INFO] Calculating random alignmentsfor pair Ampari/BenTey.
# RANDOM CORRESPONDENCE CALCULATION:   1%|▋                                            | 4/288.0 [00:01<02:06,  2.25it/s]2024-04-23 14:35:52,869 [INFO] Calculating random alignmentsfor pair Ampari/BonduSoNajamba.
# RANDOM CORRESPONDENCE CALCULATION:   2%|▊                                            | 5/288.0 [00:02<02:21,  1.99it/s]2024-04-23 14:35:53,479 [INFO] Calculating random alignmentsfor pair Ampari/Bunoge.
# RANDOM CORRESPONDENCE CALCULATION:   2%|▉                                            | 6/288.0 [00:02<02:25,  1.93it/s]2024-04-23 14:35:54,029 [INFO] Calculating random alignmentsfor pair Ampari/DogulDomBendiely.
# RANDOM CORRESPONDENCE CALCULATION:   2%|█                                            | 7/288.0 [00:03<02:25,  1.93it/s]2024-04-23 14:35:54,550 [INFO] Calculating random alignmentsfor pair Ampari/DogulDomKundialang.
# RANDOM CORRESPONDENCE CALCULATION:   3%|█▎                                           | 8/288.0 [00:04<02:58,  1.57it/s]2024-04-23 14:35:55,449 [INFO] Calculating random alignmentsfor pair Ampari/DonnoSo.
# RANDOM CORRESPONDENCE CALCULATION:   3%|█▍                                           | 9/288.0 [00:04<02:46,  1.68it/s]2024-04-23 14:35:55,953 [INFO] Calculating random alignmentsfor pair Ampari/JamsayDouentza.
# RANDOM CORRESPONDENCE CALCULATION:   3%|█▌                                          | 10/288.0 [00:05<02:36,  1.78it/s]2024-04-23 14:35:56,437 [INFO] Calculating random alignmentsfor pair Ampari/JamsayGourou.
# RANDOM CORRESPONDENCE CALCULATION:   4%|█▋                                          | 11/288.0 [00:05<02:26,  1.89it/s]2024-04-23 14:35:56,887 [INFO] Calculating random alignmentsfor pair Ampari/JamsayMondoro.
# RANDOM CORRESPONDENCE CALCULATION:   4%|█▊                                          | 12/288.0 [00:05<02:01,  2.28it/s]2024-04-23 14:35:57,121 [INFO] Calculating random alignmentsfor pair Ampari/Mombo.
# RANDOM CORRESPONDENCE CALCULATION:   5%|█▉                                          | 13/288.0 [00:06<02:10,  2.11it/s]2024-04-23 14:35:57,677 [INFO] Calculating random alignmentsfor pair Ampari/Nanga.
# RANDOM CORRESPONDENCE CALCULATION:   5%|██▏                                         | 14/288.0 [00:06<02:13,  2.05it/s]2024-04-23 14:35:58,195 [INFO] Calculating random alignmentsfor pair Ampari/Penange.
# RANDOM CORRESPONDENCE CALCULATION:   5%|██▎                                         | 15/288.0 [00:07<02:12,  2.05it/s]2024-04-23 14:35:58,682 [INFO] Calculating random alignmentsfor pair Ampari/PergeTegu.
# RANDOM CORRESPONDENCE CALCULATION:   6%|██▍                                         | 16/288.0 [00:07<02:09,  2.10it/s]2024-04-23 14:35:59,130 [INFO] Calculating random alignmentsfor pair Ampari/TebulUre.
# RANDOM CORRESPONDENCE CALCULATION:   6%|██▌                                         | 17/288.0 [00:08<02:08,  2.11it/s]2024-04-23 14:35:59,601 [INFO] Calculating random alignmentsfor pair Ampari/Tiranige.
# RANDOM CORRESPONDENCE CALCULATION:   6%|██▊                                         | 18/288.0 [00:09<02:39,  1.69it/s]2024-04-23 14:36:00,465 [INFO] Calculating random alignmentsfor pair Ampari/TogoKan.
# RANDOM CORRESPONDENCE CALCULATION:   7%|██▉                                         | 19/288.0 [00:09<02:31,  1.77it/s]2024-04-23 14:36:00,967 [INFO] Calculating random alignmentsfor pair Ampari/TommoSoTongoTongo.
# RANDOM CORRESPONDENCE CALCULATION:   7%|███                                         | 20/288.0 [00:10<02:27,  1.82it/s]2024-04-23 14:36:01,482 [INFO] Calculating random alignmentsfor pair Ampari/TomoKanDiangassagou.
# 2024-04-23 14:36:01,522 [INFO] Calculating random alignmentsfor pair Ampari/TomoKanSegue.
# RANDOM CORRESPONDENCE CALCULATION:   8%|███▎                                        | 22/288.0 [00:10<01:27,  3.05it/s]2024-04-23 14:36:01,623 [INFO] Calculating random alignmentsfor pair Ampari/ToroTegu.
# RANDOM CORRESPONDENCE CALCULATION:   8%|███▌                                        | 23/288.0 [00:10<01:39,  2.67it/s]2024-04-23 14:36:02,136 [INFO] Calculating random alignmentsfor pair Ampari/YandaDom.
# RANDOM CORRESPONDENCE CALCULATION:   8%|███▋                                        | 24/288.0 [00:11<01:51,  2.38it/s]2024-04-23 14:36:02,688 [INFO] Calculating random alignmentsfor pair Ampari/YornoSo.
# RANDOM CORRESPONDENCE CALCULATION:   9%|███▊                                        | 25/288.0 [00:11<01:53,  2.31it/s]2024-04-23 14:36:03,153 [INFO] Calculating random alignmentsfor pair BankanTey/BankanTey.
# RANDOM CORRESPONDENCE CALCULATION:   9%|███▉                                        | 26/288.0 [00:12<02:25,  1.80it/s]2024-04-23 14:36:04,027 [INFO] Calculating random alignmentsfor pair BankanTey/BenTey.
# RANDOM CORRESPONDENCE CALCULATION:   9%|████▏                                       | 27/288.0 [00:13<02:48,  1.55it/s]2024-04-23 14:36:04,891 [INFO] Calculating random alignmentsfor pair BankanTey/BonduSoNajamba.
# RANDOM CORRESPONDENCE CALCULATION:  10%|████▎                                       | 28/288.0 [00:14<03:09,  1.37it/s]2024-04-23 14:36:05,829 [INFO] Calculating random alignmentsfor pair BankanTey/Bunoge.
# RANDOM CORRESPONDENCE CALCULATION:  10%|████▍                                       | 29/288.0 [00:15<03:45,  1.15it/s]2024-04-23 14:36:07,039 [INFO] Calculating random alignmentsfor pair BankanTey/DogulDomBendiely.
# RANDOM CORRESPONDENCE CALCULATION:  10%|████▌                                       | 30/288.0 [00:16<03:35,  1.20it/s]2024-04-23 14:36:07,787 [INFO] Calculating random alignmentsfor pair BankanTey/DogulDomKundialang.
# RANDOM CORRESPONDENCE CALCULATION:  11%|████▋                                       | 31/288.0 [00:17<03:28,  1.24it/s]2024-04-23 14:36:08,538 [INFO] Calculating random alignmentsfor pair BankanTey/DonnoSo.
# RANDOM CORRESPONDENCE CALCULATION:  11%|████▉                                       | 32/288.0 [00:18<03:27,  1.24it/s]2024-04-23 14:36:09,347 [INFO] Calculating random alignmentsfor pair BankanTey/JamsayDouentza.
# RANDOM CORRESPONDENCE CALCULATION:  11%|█████                                       | 33/288.0 [00:18<03:27,  1.23it/s]2024-04-23 14:36:10,175 [INFO] Calculating random alignmentsfor pair BankanTey/JamsayGourou.
# RANDOM CORRESPONDENCE CALCULATION:  12%|█████▏                                      | 34/288.0 [00:19<03:16,  1.29it/s]2024-04-23 14:36:10,847 [INFO] Calculating random alignmentsfor pair BankanTey/JamsayMondoro.
# RANDOM CORRESPONDENCE CALCULATION:  12%|█████▎                                      | 35/288.0 [00:20<03:00,  1.40it/s]2024-04-23 14:36:11,424 [INFO] Calculating random alignmentsfor pair BankanTey/Mombo.
# RANDOM CORRESPONDENCE CALCULATION:  12%|█████▌                                      | 36/288.0 [00:21<03:15,  1.29it/s]2024-04-23 14:36:12,344 [INFO] Calculating random alignmentsfor pair BankanTey/Nanga.
# RANDOM CORRESPONDENCE CALCULATION:  13%|█████▋                                      | 37/288.0 [00:21<03:23,  1.23it/s]2024-04-23 14:36:13,234 [INFO] Calculating random alignmentsfor pair BankanTey/Penange.
# RANDOM CORRESPONDENCE CALCULATION:  13%|█████▊                                      | 38/288.0 [00:23<03:49,  1.09it/s]2024-04-23 14:36:14,399 [INFO] Calculating random alignmentsfor pair BankanTey/PergeTegu.
# RANDOM CORRESPONDENCE CALCULATION:  14%|█████▉                                      | 39/288.0 [00:23<03:40,  1.13it/s]2024-04-23 14:36:15,212 [INFO] Calculating random alignmentsfor pair BankanTey/TebulUre.
# RANDOM CORRESPONDENCE CALCULATION:  14%|██████                                      | 40/288.0 [00:24<03:30,  1.18it/s]2024-04-23 14:36:15,970 [INFO] Calculating random alignmentsfor pair BankanTey/Tiranige.
# RANDOM CORRESPONDENCE CALCULATION:  14%|██████▎                                     | 41/288.0 [00:25<03:26,  1.20it/s]2024-04-23 14:36:16,781 [INFO] Calculating random alignmentsfor pair BankanTey/TogoKan.
# RANDOM CORRESPONDENCE CALCULATION:  15%|██████▍                                     | 42/288.0 [00:26<03:21,  1.22it/s]2024-04-23 14:36:17,565 [INFO] Calculating random alignmentsfor pair BankanTey/TommoSoTongoTongo.
# RANDOM CORRESPONDENCE CALCULATION:  15%|██████▌                                     | 43/288.0 [00:27<03:26,  1.19it/s]2024-04-23 14:36:18,454 [INFO] Calculating random alignmentsfor pair BankanTey/TomoKanDiangassagou.
# RANDOM CORRESPONDENCE CALCULATION:  15%|██████▋                                     | 44/288.0 [00:28<03:38,  1.12it/s]2024-04-23 14:36:19,480 [INFO] Calculating random alignmentsfor pair BankanTey/TomoKanSegue.
# RANDOM CORRESPONDENCE CALCULATION:  16%|██████▉                                     | 45/288.0 [00:29<03:35,  1.13it/s]2024-04-23 14:36:20,347 [INFO] Calculating random alignmentsfor pair BankanTey/ToroTegu.
# RANDOM CORRESPONDENCE CALCULATION:  16%|███████                                     | 46/288.0 [00:29<03:28,  1.16it/s]2024-04-23 14:36:21,152 [INFO] Calculating random alignmentsfor pair BankanTey/YandaDom.
# RANDOM CORRESPONDENCE CALCULATION:  16%|███████▏                                    | 47/288.0 [00:31<03:49,  1.05it/s]2024-04-23 14:36:22,316 [INFO] Calculating random alignmentsfor pair BankanTey/YornoSo.
# RANDOM CORRESPONDENCE CALCULATION:  17%|███████▎                                    | 48/288.0 [00:31<03:36,  1.11it/s]2024-04-23 14:36:23,095 [INFO] Calculating random alignmentsfor pair BenTey/BenTey.
# RANDOM CORRESPONDENCE CALCULATION:  17%|███████▍                                    | 49/288.0 [00:32<03:31,  1.13it/s]2024-04-23 14:36:23,943 [INFO] Calculating random alignmentsfor pair BenTey/BonduSoNajamba.
# RANDOM CORRESPONDENCE CALCULATION:  17%|███████▋                                    | 50/288.0 [00:33<03:33,  1.11it/s]2024-04-23 14:36:24,868 [INFO] Calculating random alignmentsfor pair BenTey/Bunoge.
# RANDOM CORRESPONDENCE CALCULATION:  18%|███████▊                                    | 51/288.0 [00:34<03:26,  1.15it/s]2024-04-23 14:36:25,681 [INFO] Calculating random alignmentsfor pair BenTey/DogulDomBendiely.
# RANDOM CORRESPONDENCE CALCULATION:  18%|███████▉                                    | 52/288.0 [00:35<03:15,  1.20it/s]2024-04-23 14:36:26,415 [INFO] Calculating random alignmentsfor pair BenTey/DogulDomKundialang.
# RANDOM CORRESPONDENCE CALCULATION:  18%|████████                                    | 53/288.0 [00:35<03:07,  1.25it/s]2024-04-23 14:36:27,142 [INFO] Calculating random alignmentsfor pair BenTey/DonnoSo.
# RANDOM CORRESPONDENCE CALCULATION:  19%|████████▎                                   | 54/288.0 [00:36<03:08,  1.24it/s]2024-04-23 14:36:27,965 [INFO] Calculating random alignmentsfor pair BenTey/JamsayDouentza.
# RANDOM CORRESPONDENCE CALCULATION:  19%|████████▍                                   | 55/288.0 [00:37<03:11,  1.22it/s]2024-04-23 14:36:28,823 [INFO] Calculating random alignmentsfor pair BenTey/JamsayGourou.
# ...
# 2024-04-23 14:39:56,245 [INFO] Analyzing words for concept <stand, be in standing position>.
# 2024-04-23 14:39:56,254 [INFO] Analyzing words for concept <star>.
# 2024-04-23 14:39:56,275 [INFO] Analyzing words for concept <statuette>.
# 2024-04-23 14:39:56,294 [INFO] Analyzing words for concept <steal (sth)>.
# SEQUENCE CLUSTERING:  83%|█████████████████████████████████████████████████          | 788/947 [00:11<00:02, 60.59it/s]2024-04-23 14:39:56,307 [INFO] Analyzing words for concept <step-father>.
# 2024-04-23 14:39:56,314 [INFO] Analyzing words for concept <step-mother, mother's co-wife>.
# 2024-04-23 14:39:56,321 [INFO] Analyzing words for concept <stingy, miserly (with money)>.
# 2024-04-23 14:39:56,330 [INFO] Analyzing words for concept <stink, smell bad>.
# 2024-04-23 14:39:56,335 [INFO] Analyzing words for concept <stomach>.
# 2024-04-23 14:39:56,360 [INFO] Analyzing words for concept <stone, rock>.
# 2024-04-23 14:39:56,381 [INFO] Analyzing words for concept <storm, wind and rain>.
# 2024-04-23 14:39:56,388 [INFO] Analyzing words for concept <straight (object)>.
# 2024-04-23 14:39:56,396 [INFO] Analyzing words for concept <straight and long or tall (staff, tree, person)>.
# 2024-04-23 14:39:56,397 [INFO] Analyzing words for concept <straight, direct (road)>.
# 2024-04-23 14:39:56,404 [INFO] Analyzing words for concept <strangle>.
# SEQUENCE CLUSTERING:  84%|█████████████████████████████████████████████████▊         | 799/947 [00:11<00:02, 71.48it/s]2024-04-23 14:39:56,416 [INFO] Analyzing words for concept <stretch (e.g. animal hide, slingshot) out to its full length by pulling>.
# 2024-04-23 14:39:56,425 [INFO] Analyzing words for concept <stroll (noun), (a) walk>.
# 2024-04-23 14:39:56,438 [INFO] Analyzing words for concept <stroll, take (a walk) (verb only)>.
# 2024-04-23 14:39:56,455 [INFO] Analyzing words for concept <study (verb only)>.
# 2024-04-23 14:39:56,463 [INFO] Analyzing words for concept <stump (of a chopped-down tree)>.
# 2024-04-23 14:39:56,495 [INFO] Analyzing words for concept <stutter (verb only)>.
# 2024-04-23 14:39:56,505 [INFO] Analyzing words for concept <suck (e.g. candy)>.
# 2024-04-23 14:39:56,520 [INFO] Analyzing words for concept <sugar>.
# SEQUENCE CLUSTERING:  85%|██████████████████████████████████████████████████▎        | 807/947 [00:11<00:02, 66.74it/s]2024-04-23 14:39:56,559 [INFO] Analyzing words for concept <sugar cane>.
# 2024-04-23 14:39:56,587 [INFO] Analyzing words for concept <sun>.
# 2024-04-23 14:39:56,605 [INFO] Analyzing words for concept <supper>.
# 2024-04-23 14:39:56,646 [INFO] Analyzing words for concept <swallow>.
# 2024-04-23 14:39:56,664 [INFO] Analyzing words for concept <swear (verb only)>.
# 2024-04-23 14:39:56,675 [INFO] Analyzing words for concept <sweep (ground, courtyard)>.
# 2024-04-23 14:39:56,692 [INFO] Analyzing words for concept <sweet potato>.
# SEQUENCE CLUSTERING:  86%|██████████████████████████████████████████████████▋        | 814/947 [00:11<00:02, 56.75it/s]2024-04-23 14:39:56,733 [INFO] Analyzing words for concept <sweet, sugary (taste)>.
# 2024-04-23 14:39:56,749 [INFO] Analyzing words for concept <swim (verb only)>.
# 2024-04-23 14:39:56,757 [INFO] Analyzing words for concept <sword, saber (any type)>.
# 2024-04-23 14:39:56,773 [INFO] Analyzing words for concept <table, selling stand>.
# 2024-04-23 14:39:56,786 [INFO] Analyzing words for concept <tail (of dog, sheep, etc.)>.
# 2024-04-23 14:39:56,798 [INFO] Analyzing words for concept <tail (of scorpion)>.
# 2024-04-23 14:39:56,808 [INFO] Analyzing words for concept <take (sth) (general word)>.
# 2024-04-23 14:39:56,821 [INFO] Analyzing words for concept <take a bath or shower, bathe>.
# SEQUENCE CLUSTERING:  87%|███████████████████████████████████████████████████▏       | 822/947 [00:11<00:02, 61.06it/s]2024-04-23 14:39:56,838 [INFO] Analyzing words for concept <talk (noun), speech, words>.
# 2024-04-23 14:39:56,850 [INFO] Analyzing words for concept <taste (a food, etc.)>.
# 2024-04-23 14:39:56,865 [INFO] Analyzing words for concept <taste (sth, by licking)>.
# 2024-04-23 14:39:56,866 [INFO] Analyzing words for concept <tax>.
# 2024-04-23 14:39:56,882 [INFO] Analyzing words for concept <tea-making gear (burner, kettle, etc.)>.
# 2024-04-23 14:39:56,898 [INFO] Analyzing words for concept <teach, instruct (sb, how to do sth)>.
# 2024-04-23 14:39:56,907 [INFO] Analyzing words for concept <tears (liquid)>.
# 2024-04-23 14:39:56,914 [INFO] Analyzing words for concept <temple, side of eye>.
# 2024-04-23 14:39:56,921 [INFO] Analyzing words for concept <ten>.
# 2024-04-23 14:39:56,934 [INFO] Analyzing words for concept <tent>.
# SEQUENCE CLUSTERING:  88%|███████████████████████████████████████████████████▊       | 832/947 [00:11<00:01, 69.28it/s]2024-04-23 14:39:56,946 [INFO] Analyzing words for concept <testicles>.
# 2024-04-23 14:39:56,966 [INFO] Analyzing words for concept <the day after tomorrow>.
# 2024-04-23 14:39:56,981 [INFO] Analyzing words for concept <thick (planar object, e.g. wall)>.
# 2024-04-23 14:39:56,992 [INFO] Analyzing words for concept <thief>.
# 2024-04-23 14:39:57,022 [INFO] Analyzing words for concept <thigh, upper leg (of person)>.
# 2024-04-23 14:39:57,035 [INFO] Analyzing words for concept <thing (general term)>.
# 2024-04-23 14:39:57,051 [INFO] Analyzing words for concept <third (ordinal)>.
# 2024-04-23 14:39:57,067 [INFO] Analyzing words for concept <thirst>.
# SEQUENCE CLUSTERING:  89%|████████████████████████████████████████████████████▎      | 840/947 [00:12<00:01, 64.87it/s]2024-04-23 14:39:57,091 [INFO] Analyzing words for concept <thousand>.
# 2024-04-23 14:39:57,112 [INFO] Analyzing words for concept <thread (any kind)>.
# 2024-04-23 14:39:57,124 [INFO] Analyzing words for concept <threaten (scare)>.
# 2024-04-23 14:39:57,130 [INFO] Analyzing words for concept <three>.
# 2024-04-23 14:39:57,149 [INFO] Analyzing words for concept <three times>.
# 2024-04-23 14:39:57,178 [INFO] Analyzing words for concept <thresh by pounding hard (rice, occasionally millet) with large clubs on the ground or on a mat>.
# 2024-04-23 14:39:57,183 [INFO] Analyzing words for concept <throat (exterior)>.
# SEQUENCE CLUSTERING:  89%|████████████████████████████████████████████████████▊      | 847/947 [00:12<00:01, 65.82it/s]2024-04-23 14:39:57,190 [INFO] Analyzing words for concept <throat (interior)>.
# 2024-04-23 14:39:57,217 [INFO] Analyzing words for concept <throw (e.g. stone)>.
# 2024-04-23 14:39:57,230 [INFO] Analyzing words for concept <thumb>.
# 2024-04-23 14:39:57,243 [INFO] Analyzing words for concept <thunder (noun)>.
# 2024-04-23 14:39:57,270 [INFO] Analyzing words for concept <tie, tie up (sth or sb, with a rope)>.
# 2024-04-23 14:39:57,285 [INFO] Analyzing words for concept <time, moment in time>.
# 2024-04-23 14:39:57,351 [INFO] Analyzing words for concept <tobacco (leaves, or for cigarettes)>.
# SEQUENCE CLUSTERING:  90%|█████████████████████████████████████████████████████▏     | 854/947 [00:12<00:01, 56.58it/s]2024-04-23 14:39:57,363 [INFO] Analyzing words for concept <tobacco pipe>.
# 2024-04-23 14:39:57,380 [INFO] Analyzing words for concept <today>.
# 2024-04-23 14:39:57,386 [INFO] Analyzing words for concept <toe>.
# 2024-04-23 14:39:57,405 [INFO] Analyzing words for concept <tomorrow>.
# 2024-04-23 14:39:57,416 [INFO] Analyzing words for concept <tongs (blacksmith's large pliers-like instrument)>.
# 2024-04-23 14:39:57,424 [INFO] Analyzing words for concept <tongue>.
# 2024-04-23 14:39:57,447 [INFO] Analyzing words for concept <tooth>.
# SEQUENCE CLUSTERING:  91%|█████████████████████████████████████████████████████▋     | 861/947 [00:12<00:01, 59.66it/s]2024-04-23 14:39:57,467 [INFO] Analyzing words for concept <touch (with hand)>.
# 2024-04-23 14:39:57,482 [INFO] Analyzing words for concept <trap>.
# 2024-04-23 14:39:57,499 [INFO] Analyzing words for concept <tree bark>.
# 2024-04-23 14:39:57,533 [INFO] Analyzing words for concept <tree or large woody shrub>.
# 2024-04-23 14:39:57,556 [INFO] Analyzing words for concept <trough (of wood or metal, for drinking or to beat as a drum)>.
# 2024-04-23 14:39:57,571 [INFO] Analyzing words for concept <trunk (of tree)>.
# 2024-04-23 14:39:57,580 [INFO] Analyzing words for concept <turn off (light)>.
# SEQUENCE CLUSTERING:  92%|██████████████████████████████████████████████████████     | 868/947 [00:12<00:01, 58.56it/s]2024-04-23 14:39:57,587 [INFO] Analyzing words for concept <turn on (lights)>.
# 2024-04-23 14:39:57,606 [INFO] Analyzing words for concept <turn over (earth in field, with daba, to hold rainwater or to weed around peanut plants)>.
# 2024-04-23 14:39:57,615 [INFO] Analyzing words for concept <twelve>.
# 2024-04-23 14:39:57,639 [INFO] Analyzing words for concept <twenty>.
# 2024-04-23 14:39:57,655 [INFO] Analyzing words for concept <twice>.
# 2024-04-23 14:39:57,674 [INFO] Analyzing words for concept <twin (person)>.
# 2024-04-23 14:39:57,692 [INFO] Analyzing words for concept <two>.
# SEQUENCE CLUSTERING:  92%|██████████████████████████████████████████████████████▌    | 875/947 [00:12<00:01, 58.64it/s]2024-04-23 14:39:57,709 [INFO] Analyzing words for concept <udder>.
# 2024-04-23 14:39:57,719 [INFO] Analyzing words for concept <ugly>.
# 2024-04-23 14:39:57,733 [INFO] Analyzing words for concept <un>.
# 2024-04-23 14:39:57,734 [INFO] Analyzing words for concept <understand>.
# 2024-04-23 14:39:57,750 [INFO] Analyzing words for concept <unripe (fruit)>.
# 2024-04-23 14:39:57,765 [INFO] Analyzing words for concept <unripe (grain)>.
# 2024-04-23 14:39:57,777 [INFO] Analyzing words for concept <untie, undo, loosen (knot)>.
# 2024-04-23 14:39:57,795 [INFO] Analyzing words for concept <urinate, have a piss>.
# SEQUENCE CLUSTERING:  93%|███████████████████████████████████████████████████████    | 883/947 [00:12<00:01, 58.98it/s]2024-04-23 14:39:57,842 [INFO] Analyzing words for concept <vegetable garden>.
# 2024-04-23 14:39:57,857 [INFO] Analyzing words for concept <village, town, settlement>.
# 2024-04-23 14:39:57,873 [INFO] Analyzing words for concept <voice (of sb), characteristic call (of animal)>.
# 2024-04-23 14:39:57,880 [INFO] Analyzing words for concept <vomir, emit vomit>.
# 2024-04-23 14:39:57,906 [INFO] Analyzing words for concept <wake up, awaken>.
# 2024-04-23 14:39:57,916 [INFO] Analyzing words for concept <wall (of house)>.
# 2024-04-23 14:39:57,938 [INFO] Analyzing words for concept <want, like, love (sth)>.
# SEQUENCE CLUSTERING:  94%|███████████████████████████████████████████████████████▍   | 890/947 [00:12<00:00, 60.54it/s]2024-04-23 14:39:57,949 [INFO] Analyzing words for concept <wash (clothing)>.
# 2024-04-23 14:39:57,962 [INFO] Analyzing words for concept <wash (one's hands)>.
# 2024-04-23 14:39:57,968 [INFO] Analyzing words for concept <wash (pots, knives, etc.)>.
# 2024-04-23 14:39:57,978 [INFO] Analyzing words for concept <water>.
# 2024-04-23 14:39:57,989 [INFO] Analyzing words for concept <waves (of water)>.
# 2024-04-23 14:39:57,994 [INFO] Analyzing words for concept <weak, feeble (person or animal)>.
# 2024-04-23 14:39:58,002 [INFO] Analyzing words for concept <weave (fabric, from cotton thread)>.
# 2024-04-23 14:39:58,015 [INFO] Analyzing words for concept <week>.
# 2024-04-23 14:39:58,028 [INFO] Analyzing words for concept <weep (verb only)>.
# 2024-04-23 14:39:58,040 [INFO] Analyzing words for concept <west>.
# SEQUENCE CLUSTERING:  95%|████████████████████████████████████████████████████████   | 900/947 [00:13<00:00, 66.84it/s]2024-04-23 14:39:58,073 [INFO] Analyzing words for concept <wet (adjective)>.
# 2024-04-23 14:39:58,088 [INFO] Analyzing words for concept <what?>.
# 2024-04-23 14:39:58,103 [INFO] Analyzing words for concept <wheat>.
# 2024-04-23 14:39:58,114 [INFO] Analyzing words for concept <when? (at what time?)>.
# 2024-04-23 14:39:58,160 [INFO] Analyzing words for concept <where? (location)>.
# 2024-04-23 14:39:58,174 [INFO] Analyzing words for concept <which?>.
# 2024-04-23 14:39:58,186 [INFO] Analyzing words for concept <whisper (verb only)>.
# SEQUENCE CLUSTERING:  96%|████████████████████████████████████████████████████████▌  | 907/947 [00:13<00:00, 64.31it/s]2024-04-23 14:39:58,191 [INFO] Analyzing words for concept <whistle (from the mouth) (verb only)>.
# 2024-04-23 14:39:58,202 [INFO] Analyzing words for concept <white, light-colored>.
# 2024-04-23 14:39:58,221 [INFO] Analyzing words for concept <who?>.
# 2024-04-23 14:39:58,228 [INFO] Analyzing words for concept <why?>.
# 2024-04-23 14:39:58,278 [INFO] Analyzing words for concept <wide (passageway)>.
# 2024-04-23 14:39:58,288 [INFO] Analyzing words for concept <widow (not yet remarried)>.
# 2024-04-23 14:39:58,304 [INFO] Analyzing words for concept <widower>.
# SEQUENCE CLUSTERING:  97%|████████████████████████████████████████████████████████▉  | 914/947 [00:13<00:00, 62.22it/s]2024-04-23 14:39:58,313 [INFO] Analyzing words for concept <wife>.
# 2024-04-23 14:39:58,320 [INFO] Analyzing words for concept <wind (airflow)>.
# 2024-04-23 14:39:58,339 [INFO] Analyzing words for concept <window (full-sized)>.
# 2024-04-23 14:39:58,357 [INFO] Analyzing words for concept <wing (of bird)>.
# 2024-04-23 14:39:58,380 [INFO] Analyzing words for concept <witness (person)>.
# 2024-04-23 14:39:58,393 [INFO] Analyzing words for concept <woman, female person>.
# 2024-04-23 14:39:58,406 [INFO] Analyzing words for concept <womb>.
# SEQUENCE CLUSTERING:  97%|█████████████████████████████████████████████████████████▍ | 921/947 [00:13<00:00, 62.94it/s]2024-04-23 14:39:58,421 [INFO] Analyzing words for concept <wood>.
# 2024-04-23 14:39:58,435 [INFO] Analyzing words for concept <wooden board, plank>.
# 2024-04-23 14:39:58,442 [INFO] Analyzing words for concept <wool (substance)>.
# 2024-04-23 14:39:58,443 [INFO] Analyzing words for concept <word, name (of sth)>.
# 2024-04-23 14:39:58,449 [INFO] Analyzing words for concept <work (noun), productive activity>.
# 2024-04-23 14:39:58,460 [INFO] Analyzing words for concept <work in the fields, do farm work (verb only)>.
# 2024-04-23 14:39:58,474 [INFO] Analyzing words for concept <world (of the living)>.
# 2024-04-23 14:39:58,512 [INFO] Analyzing words for concept <worn out, old, no longer useful (object)>.
# SEQUENCE CLUSTERING:  98%|█████████████████████████████████████████████████████████▉ | 929/947 [00:13<00:00, 66.78it/s]2024-04-23 14:39:58,525 [INFO] Analyzing words for concept <worship (God)>.
# 2024-04-23 14:39:58,535 [INFO] Analyzing words for concept <wound, injury>.
# 2024-04-23 14:39:58,553 [INFO] Analyzing words for concept <wrinkled (adjective)>.
# 2024-04-23 14:39:58,555 [INFO] Analyzing words for concept <wrist>.
# 2024-04-23 14:39:58,569 [INFO] Analyzing words for concept <write (sth)>.
# 2024-04-23 14:39:58,580 [INFO] Analyzing words for concept <yam (Dioscorea)>.
# 2024-04-23 14:39:58,589 [INFO] Analyzing words for concept <yawn (verb only)>.
# 2024-04-23 14:39:58,600 [INFO] Analyzing words for concept <year>.
# 2024-04-23 14:39:58,620 [INFO] Analyzing words for concept <yell, shout loudly (e.g. a general warning, to anyone within earshot)>.
# 2024-04-23 14:39:58,623 [INFO] Analyzing words for concept <yellow>.
# SEQUENCE CLUSTERING:  99%|██████████████████████████████████████████████████████████▌| 939/947 [00:13<00:00, 70.48it/s]2024-04-23 14:39:58,655 [INFO] Analyzing words for concept <yes!>.
# 2024-04-23 14:39:58,668 [INFO] Analyzing words for concept <yesterday>.
# 2024-04-23 14:39:58,677 [INFO] Analyzing words for concept <yoke wrapped in cloth around donkey's neck and tied by a rope to the two long poles of a cart>.
# 2024-04-23 14:39:58,726 [INFO] Analyzing words for concept <young>.
# 2024-04-23 14:39:58,739 [INFO] Analyzing words for concept <young (adolescent) man, not yet bearded>.
# 2024-04-23 14:39:58,741 [INFO] Analyzing words for concept <young (adolescent) woman, not yet a mother>.
# 2024-04-23 14:39:58,746 [INFO] Analyzing words for concept <younger brother (of man or woman)>.
# 2024-04-23 14:39:58,747 [INFO] Analyzing words for concept <younger sister (of a woman)>.
# 2024-04-23 14:39:59,515 [INFO] Data has been written to file <new_beginining_clusters.tsv>.
# 2024-04-23 14:40:00,287 [INFO] Data has been written to file <part_beginining_clusters.csv>.

# %% [markdown]
# # ALIGNMENTS

# %%
lex=LexStat("new_beginining_clusters.tsv")
alm = Alignments(lex, ref='cogid')
alm.align()
alm.output("tsv", filename='new_beginining_alignments', subset=True,
cols=['doculect', 'concept', 'ipa', 'tokens', 'cogid', 'alignment'],
prettify=False, ignore='all')
# Out:
# 2024-04-23 13:24:52,434 [INFO] Data has been written to file <new_beginining_alignments.tsv>.
