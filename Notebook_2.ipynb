# %% [markdown]
# # Imports

# %%
from utils import NounParser,VerbParser,AdjectiveNumeralParser
import pandas as pd
from lingpy import *
from lingpy.sequence.sound_classes import check_tokens
from lingpy.compare.util import (mutual_coverage_check, mutual_coverage_subset)
from lingpy.compare.sanity import average_coverage
from lingpy.compare.sanity import synonymy
from segments.tokenizer import Tokenizer
from collections import defaultdict
import matplotlib.pyplot as plt
import os
from pprint import pprint
from lingpy.evaluate.acd import bcubes
from lingpy.compare.partial import Partial

# %% [markdown]
# # Functions

# %%
#dictionaries, sets and lists
replacement_dict={"DogulDomBendiely":"DogulDomKundialang",
                  "JamsayGourou":"JamsayDouentza",
                  "JamsayMondoro":"JamsayDouentza",
                  "PergeTegu":"JamsayDouentza",
                  "TomoKanSegue":"TomoKanDiangassagou"}

new_name={'TommoSoTongoTongo': "TommoSo",
         "BonduSoNajamba": "BonduSo",
          
         "TomoKanDiangassagou": "TomoKan",
         "TomoKanSegue":"TomoKan",
          
         "DogulDomKundialang": "DogulDom",
         'DogulDomBendiely':"DogulDom",
          
          "JamsayDouentza":"Jamsay",
         'JamsayGourou':"Jamsay",
         'JamsayMondoro':"Jamsay",
          "PergeTegu": "Jamsay"}
replacements={'j':'j','á':'a','w': 'w','d':'d','ì': 'i','-':'-','m':'m',':': ':','b': 'b','à': 'a','r':'r',
              's':'s','ɛ':'ɛ','k':'k','ɔ': 'ɔ','l':'l','g':'g','ù':'u','ú':'u','è':'e','í':'i','ŋ': 'ŋ',
              'ó':'o','n': 'n','ⁿ': '\u207F','ý':'y','z':'z','ɲ':'\u0272','y':'y','ò':'o','ɣ': 'ɣ',
              'ʔ': '\u0294','ǎ':'a','â':'a','é':'e','ě':'e','ê':'e','î':'i','ǐ': 'i','ǹ': 'n','û':'u',
              'š':'s','ə': 'ə','p':'p','ǒ':'o','t':'t','e':'e','ô':'o','ǔ':'u','ń':'n','ỳ':'y','c':'c',
              'h':'h','f': 'f','ʷ': '\u02B7','i':'i','?': '\u0294','x':'x','o':'o','a':'a','ɗ': 'ɗ',
              'ḱ':'k','ǽ':'ae','ẁ':'w','ʒ': '\u0292','v':'v','ḿ':'m','ẃ':'w','å':'a','u':'u','q':'q',
              'ʄ': 'ƒ','ɓ':'b','ᵇ': '\u1D47','ʸ':'\u02B9','Ǹ':'n','V': 'v', " ": " "}

#Instantiating parser objects
noun_parser=NounParser()
verb_parser=VerbParser()
adj_num_parser=AdjectiveNumeralParser()


def prior_forms(row):
    """
    puts all forms that have been parsed into a single column
    """
    if pd.isna(row["POS"]):  
        return None
    elif row["POS"] in ["noun", "numeral", "adjective"]:
        form = str(row["SINGULAR"]) if isinstance(row["SINGULAR"], str) else ""
        return form
    elif row["POS"] == "verb":
        verb = row["FORM"]
        if pd.isna(verb):
            return None
        else:
            return verb
    else:
        form = str(row["SINGULAR"]) if isinstance(row["SINGULAR"], str) else ""
        return form




def parsing_data(row):
    """
    puts all forms that have been parsed into a single column
    """
    if pd.isna(row["POS"]):  
        return None
    elif row["POS"]=="noun":
        noun=row["BEFORE_PARSE"]
        if pd.isna(noun):
            return None
        else:
            noun=(noun_parser.identified_suffixes(
            noun_parser.hyphen_space(
                noun_parser.nasalized_stops(
                    noun_parser.cvcv_segmentation(
                        noun_parser.parse_noun_durationals(
                            noun_parser.parse_off_final_nasals(
                                noun_parser.existing_parses(
                                    adj_num_parser.y_suffixes(noun.strip("()/_")))))))))) if (noun.endswith("y") or (noun.endswith("ⁿ") and noun[-2]=="y")) else \
                            (noun_parser.identified_suffixes(
                                noun_parser.hyphen_space(
                                    noun_parser.nasalized_stops(
                                        noun_parser.cvcv_segmentation(
                                            noun_parser.parse_noun_durationals(
                                                noun_parser.parse_off_final_nasals(
                                                    noun_parser.existing_parses(noun.strip("()/_")))))))))
            return noun
            
    elif row["POS"] == "numeral" or row["POS"] == "adjective":
        form = row["BEFORE_PARSE"]
        if pd.isna(form):
            return None
        else:
            form=adj_num_parser.miscellaneous(
            adj_num_parser.switch_hyphen_position(
                adj_num_parser.replace_hyphens_keep_last(
                    adj_num_parser.y_suffixes(
                        adj_num_parser.isolating_suffixes(
                            adj_num_parser.parse_verb_durationals(
                                adj_num_parser.existing_parses(form.strip("()/_"))))))))
            return form
    elif row["POS"] == "verb":
        verb = row["BEFORE_PARSE"]
        if pd.isna(verb):
            return None
        else:
            verb=verb_parser.post_editing_short_strings(
            verb_parser.segment_cvcs(
                verb_parser.parse_verb_durationals(
                    verb_parser.existing_parses(verb.strip(")(_")))))
            return verb
    else:
        form = str(row["BEFORE_PARSE"]) if isinstance(row["BEFORE_PARSE"], str) else ""
        return noun_parser.parse_noun_durationals(form)



def data_prep_for_ortho_profile(input_file):
    """
    prepares data so that command line can run on it to output an orthography profile
    """
    df = pd.read_csv(input_file, delimiter='\t')
    df["ID"]=df["ID"].astype(str)
    df['ID'] = pd.to_numeric(df['ID'].str.replace(',', '').str.replace('.', ''), errors='coerce')
    df = df.dropna(subset=['ID'])
    df['ID'] = df['ID'].astype(int)
    return df.to_csv('heathdogon2.tsv', index=False, sep='\t')



def add_tab_after_quote(input_file, output_file, encoding='utf-8'):
    """
    creates a tsv file in which quotation characters are eliminated
    input_file: orthography profile created via the command line: $ lingpy profile -i heathdogon2.tsv -o  P_created-profile.tsv --column=ipa
    """
    with open(input_file, 'r', encoding=encoding) as infile, open(output_file, 'w', encoding=encoding) as outfile:
        for line in infile:
            new_line = ''
            quote_added = False
            for char in line:
                if char == '"':
                    new_line += char + '\t'
                    quote_added = True
                else:
                    new_line += char
                    if quote_added:
                        quote_added = False
            outfile.write(new_line)


def merges(row, concepts, replacement_dict):
    """
    merges various rows based on the presence of a gloss
    """
    
    if not isinstance(row["CONCEPT"], str) or not isinstance(row["DOCULECT"], str):
        # Handle unexpected types
        return None
    
    for concept in concepts:
        for key, value in replacement_dict.items():
            if concept in row["CONCEPT"] and row["DOCULECT"] == value and row["DOCULECT"] == key:
                return row["DOCULECT"] == value
            elif concept in row["CONCEPT"] and row["DOCULECT"] != value:
                if row["CONCEPT"] == key:
                    return row["CONCEPT"] == key
            elif concept in row["CONCEPT"] and row["DOCULECT"] != value or row["DOCULECT"] != key:
                return row



def change_name(name, new_name):
    """
    changes the names of various language dialects into language
    """
    for key, value in new_name.items():  
        keep_name = value
        discard_name = key
        if name == discard_name:  
            return keep_name
    return name


def remove_tones(word):
    """
    removes tones and keeps only segments
    """
    if word is None:
        return None

    new_word=""
    for letter in word:
        if letter in replacements.keys():
            new_word += replacements.get(letter)
        elif letter==" ":
            new_word +="#"
        else:
            new_word +=""
    return new_word

def remove_spaces(word):
    if word is None:
        return None
    new_word=""
    for letter in word:
        if letter==" ":
            new_word += ""
        else:
            new_word += letter
    return new_word

# %% [markdown]
# # Loading data

# %%
#loading data
pd.set_option('display.max_rows', None)
path = r"D:\ERC_Bang\Tasks\data_cleaning" 
os.chdir(path)
data = pd.read_csv("data.tsv", sep="\t", encoding="utf-8")
list_to_drop=["ID","FRENCH", "ENGLISH_SHORT", "FRENCH_SHORT", "ENGLISH_CATEGORY", "FRENCH_CATEGORY", "PARSED FORM", "MCF", "RECONSTRUCTION", "NOTE", "NOTES","Unnamed: 18", "Unnamed: 19", "Unnamed: 20", "Unnamed: 21", "COGID", "COGIDS", "Unnamed: 24"]
data=data.drop(list_to_drop, axis=1)

# %%
#visualizing data
data.head()
# Out:
#    VARID          DOCULECT                             GLOSS  \
# 0    0.0         BankanTey  domestic animal (esp. livestock)
# 1    1.0         BankanTey  domestic animal (esp. livestock)
# 2    0.0            BenTey  domestic animal (esp. livestock)
# 3    0.0            Bunoge  domestic animal (esp. livestock)
# 4    0.0  DogulDomBendiely  domestic animal (esp. livestock)
#
#                         VALUE_ORG  SINGULAR     PLURAL FORM    CONCEPT   POS
# 0  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   jáwdì-m      jáwdì  NaN  LIVESTOCK  noun
# 1  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   dá:bà-m      dá:bà  NaN  LIVESTOCK  noun
# 2                àrsɛ̌:-m\\àrsɛ̌:  àrsɛ̌:-m     àrsɛ̌:  NaN  LIVESTOCK  noun
# 3                         kɔ́mbɔ̀   kɔ́mbɔ̀   kɔmbɔ=gè  NaN  LIVESTOCK  noun
# 4               bɛ́lɛ̀g, bɛ́lɛ̀gù  bɛ́lɛ̀-g  bɛlɛ-g-yà  NaN  LIVESTOCK  noun

# %% [markdown]
# # Creating new columns

# %%
data["BEFORE_PARSE"]=data.apply(prior_forms, axis=1) #put all eligible data in one columns

# %%
data.head()
# Out:
#    VARID          DOCULECT                             GLOSS  \
# 0    0.0         BankanTey  domestic animal (esp. livestock)
# 1    1.0         BankanTey  domestic animal (esp. livestock)
# 2    0.0            BenTey  domestic animal (esp. livestock)
# 3    0.0            Bunoge  domestic animal (esp. livestock)
# 4    0.0  DogulDomBendiely  domestic animal (esp. livestock)
#
#                         VALUE_ORG  SINGULAR     PLURAL FORM    CONCEPT   POS  \
# 0  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   jáwdì-m      jáwdì  NaN  LIVESTOCK  noun
# 1  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   dá:bà-m      dá:bà  NaN  LIVESTOCK  noun
# 2                àrsɛ̌:-m\\àrsɛ̌:  àrsɛ̌:-m     àrsɛ̌:  NaN  LIVESTOCK  noun
# 3                         kɔ́mbɔ̀   kɔ́mbɔ̀   kɔmbɔ=gè  NaN  LIVESTOCK  noun
# 4               bɛ́lɛ̀g, bɛ́lɛ̀gù  bɛ́lɛ̀-g  bɛlɛ-g-yà  NaN  LIVESTOCK  noun
#
#   BEFORE_PARSE
# 0      jáwdì-m
# 1      dá:bà-m
# 2     àrsɛ̌:-m
# 3      kɔ́mbɔ̀
# 4     bɛ́lɛ̀-g

# %%
data["PARSED"]=data.apply(parsing_data,axis=1)#parse all eligible data

# %%
data.head()
# Out:
#    VARID          DOCULECT                             GLOSS  \
# 0    0.0         BankanTey  domestic animal (esp. livestock)
# 1    1.0         BankanTey  domestic animal (esp. livestock)
# 2    0.0            BenTey  domestic animal (esp. livestock)
# 3    0.0            Bunoge  domestic animal (esp. livestock)
# 4    0.0  DogulDomBendiely  domestic animal (esp. livestock)
#
#                         VALUE_ORG  SINGULAR     PLURAL FORM    CONCEPT   POS  \
# 0  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   jáwdì-m      jáwdì  NaN  LIVESTOCK  noun
# 1  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   dá:bà-m      dá:bà  NaN  LIVESTOCK  noun
# 2                àrsɛ̌:-m\\àrsɛ̌:  àrsɛ̌:-m     àrsɛ̌:  NaN  LIVESTOCK  noun
# 3                         kɔ́mbɔ̀   kɔ́mbɔ̀   kɔmbɔ=gè  NaN  LIVESTOCK  noun
# 4               bɛ́lɛ̀g, bɛ́lɛ̀gù  bɛ́lɛ̀-g  bɛlɛ-g-yà  NaN  LIVESTOCK  noun
#
#   BEFORE_PARSE     PARSED
# 0      jáwdì-m   jáw-dì-m
# 1      dá:bà-m    dáábà-m
# 2     àrsɛ̌:-m  àrsɛ̌ɛ̌-m
# 3      kɔ́mbɔ̀   kɔ́-mbɔ̀
# 4     bɛ́lɛ̀-g   bɛ́lɛ̀-g

# %%
data["TONES_REMOVED"] = data["PARSED"].apply(lambda x: remove_tones(x)) #remove tones

# %%
data.head()
# Out:
#    VARID          DOCULECT                             GLOSS  \
# 0    0.0         BankanTey  domestic animal (esp. livestock)
# 1    1.0         BankanTey  domestic animal (esp. livestock)
# 2    0.0            BenTey  domestic animal (esp. livestock)
# 3    0.0            Bunoge  domestic animal (esp. livestock)
# 4    0.0  DogulDomBendiely  domestic animal (esp. livestock)
#
#                         VALUE_ORG  SINGULAR     PLURAL FORM    CONCEPT   POS  \
# 0  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   jáwdì-m      jáwdì  NaN  LIVESTOCK  noun
# 1  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   dá:bà-m      dá:bà  NaN  LIVESTOCK  noun
# 2                àrsɛ̌:-m\\àrsɛ̌:  àrsɛ̌:-m     àrsɛ̌:  NaN  LIVESTOCK  noun
# 3                         kɔ́mbɔ̀   kɔ́mbɔ̀   kɔmbɔ=gè  NaN  LIVESTOCK  noun
# 4               bɛ́lɛ̀g, bɛ́lɛ̀gù  bɛ́lɛ̀-g  bɛlɛ-g-yà  NaN  LIVESTOCK  noun
#
#   BEFORE_PARSE     PARSED TONES_REMOVED
# 0      jáwdì-m   jáw-dì-m      jaw-di-m
# 1      dá:bà-m    dáábà-m       daaba-m
# 2     àrsɛ̌:-m  àrsɛ̌ɛ̌-m       arsɛɛ-m
# 3      kɔ́mbɔ̀   kɔ́-mbɔ̀        kɔ-mbɔ
# 4     bɛ́lɛ̀-g   bɛ́lɛ̀-g        bɛlɛ-g

# %%
tk = Tokenizer('profile.tsv')
data["IPA"]=data["TONES_REMOVED"].apply(lambda x: tk(x, column="IPA") if isinstance(x, str) else x) #running orthography profile
data["IPA"]=data["IPA"].apply(remove_spaces)#removing spaces, else Lingpy throws an error

# %%
data.head()
# Out:
#    VARID          DOCULECT                             GLOSS  \
# 0    0.0         BankanTey  domestic animal (esp. livestock)
# 1    1.0         BankanTey  domestic animal (esp. livestock)
# 2    0.0            BenTey  domestic animal (esp. livestock)
# 3    0.0            Bunoge  domestic animal (esp. livestock)
# 4    0.0  DogulDomBendiely  domestic animal (esp. livestock)
#
#                         VALUE_ORG  SINGULAR     PLURAL FORM    CONCEPT   POS  \
# 0  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   jáwdì-m      jáwdì  NaN  LIVESTOCK  noun
# 1  jáwdì-m\\jáwdì, dá:bà-m\\dá:bà   dá:bà-m      dá:bà  NaN  LIVESTOCK  noun
# 2                àrsɛ̌:-m\\àrsɛ̌:  àrsɛ̌:-m     àrsɛ̌:  NaN  LIVESTOCK  noun
# 3                         kɔ́mbɔ̀   kɔ́mbɔ̀   kɔmbɔ=gè  NaN  LIVESTOCK  noun
# 4               bɛ́lɛ̀g, bɛ́lɛ̀gù  bɛ́lɛ̀-g  bɛlɛ-g-yà  NaN  LIVESTOCK  noun
#
#   BEFORE_PARSE     PARSED TONES_REMOVED       IPA
# 0      jáwdì-m   jáw-dì-m      jaw-di-m  jaw+di+m
# 1      dá:bà-m    dáábà-m       daaba-m   daaba+m
# 2     àrsɛ̌:-m  àrsɛ̌ɛ̌-m       arsɛɛ-m   arsɛɛ+m
# 3      kɔ́mbɔ̀   kɔ́-mbɔ̀        kɔ-mbɔ    kɔ+mbɔ
# 4     bɛ́lɛ̀-g   bɛ́lɛ̀-g        bɛlɛ-g    bɛlɛ+g

# %%
data=data[["DOCULECT", "GLOSS", "IPA"]].dropna(subset=["DOCULECT", "GLOSS", "IPA"])

# %%
data.head()
# Out:
#            DOCULECT                             GLOSS       IPA
# 0         BankanTey  domestic animal (esp. livestock)  jaw+di+m
# 1         BankanTey  domestic animal (esp. livestock)   daaba+m
# 2            BenTey  domestic animal (esp. livestock)   arsɛɛ+m
# 3            Bunoge  domestic animal (esp. livestock)    kɔ+mbɔ
# 4  DogulDomBendiely  domestic animal (esp. livestock)    bɛlɛ+g

# %%
data.to_csv("new_beginining_1.csv", index=False, encoding="utf-8")#empty spaces cleaned in Google sheets

# %% [markdown]
# # Special data processing(with Lingpy)

# %%
wl=Wordlist("new_beginining_2.tsv")

# %%
wl.header
# Out:
# {'doculect': 0, 'concept': 1, 'ipa': 2}

# %%
x=25
count, results = mutual_coverage_subset(wl, x)
coverage, languages = results[0]

# %%
concepts={}
for i in languages:
    concepts[i]=set(wl.get_dict(language=i, entry="concepts"))

# %%
wl.output("tsv", filename="new_beginining_3", subset=True, rows=dict(doculect = "in "+str(languages)))
wl.output("csv", filename="new_beginining_3", subset=True, rows=dict(doculect = "in "+str(languages))) #empty spaces cleaned in Google sheets
# Out:
# 2024-04-23 13:03:47,223 [INFO] Data has been written to file <new_beginining_3.tsv>.
# 2024-04-23 13:03:47,926 [INFO] Data has been written to file <new_beginining_3.csv>.

# %% [markdown]
# # Running algorithm

# %%
path = r"D:\ERC_Bang\Tasks\data_cleaning" 
os.chdir(path)

# %%
wl=Wordlist("new_beginining_4.tsv")

# %%
part=Partial(wl)

# %%
part.get_scorer(runs=10000)
part.cluster(method='lexstat', threshold=0.55, ref='cogid')
part.output('tsv', filename='part_beginining_clusters')
part.output('csv', filename='part_beginining_clusters')
# Out:
# CORRESPONDENCE CALCULATION:   0%|                                                            | 0/288.0 [00:00<?, ?it/s]2024-04-23 14:22:52,040 [INFO] Calculating alignments for pair Ampari / Ampari.
# 2024-04-23 14:22:52,053 [INFO] Calculating alignments for pair Ampari / BankanTey.
# 2024-04-23 14:22:52,064 [INFO] Calculating alignments for pair Ampari / BenTey.
# 2024-04-23 14:22:52,073 [INFO] Calculating alignments for pair Ampari / BonduSoNajamba.
# 2024-04-23 14:22:52,082 [INFO] Calculating alignments for pair Ampari / Bunoge.
# 2024-04-23 14:22:52,089 [INFO] Calculating alignments for pair Ampari / DogulDomBendiely.
# 2024-04-23 14:22:52,096 [INFO] Calculating alignments for pair Ampari / DogulDomKundialang.
# 2024-04-23 14:22:52,103 [INFO] Calculating alignments for pair Ampari / DonnoSo.
# 2024-04-23 14:22:52,111 [INFO] Calculating alignments for pair Ampari / JamsayDouentza.
# 2024-04-23 14:22:52,119 [INFO] Calculating alignments for pair Ampari / JamsayGourou.
# 2024-04-23 14:22:52,124 [INFO] Calculating alignments for pair Ampari / JamsayMondoro.
# 2024-04-23 14:22:52,128 [INFO] Calculating alignments for pair Ampari / Mombo.
# 2024-04-23 14:22:52,135 [INFO] Calculating alignments for pair Ampari / Nanga.
# CORRESPONDENCE CALCULATION:   5%|██▍                                               | 14/288.0 [00:00<00:02, 135.93it/s]2024-04-23 14:22:52,144 [INFO] Calculating alignments for pair Ampari / Penange.
# 2024-04-23 14:22:52,151 [INFO] Calculating alignments for pair Ampari / PergeTegu.
# 2024-04-23 14:22:52,157 [INFO] Calculating alignments for pair Ampari / TebulUre.
# 2024-04-23 14:22:52,165 [INFO] Calculating alignments for pair Ampari / Tiranige.
# 2024-04-23 14:22:52,171 [INFO] Calculating alignments for pair Ampari / TogoKan.
# 2024-04-23 14:22:52,179 [INFO] Calculating alignments for pair Ampari / TommoSoTongoTongo.
# 2024-04-23 14:22:52,186 [INFO] Calculating alignments for pair Ampari / TomoKanDiangassagou.
# 2024-04-23 14:22:52,189 [INFO] Calculating alignments for pair Ampari / TomoKanSegue.
# 2024-04-23 14:22:52,192 [INFO] Calculating alignments for pair Ampari / ToroTegu.
# 2024-04-23 14:22:52,200 [INFO] Calculating alignments for pair Ampari / YandaDom.
# 2024-04-23 14:22:52,209 [INFO] Calculating alignments for pair Ampari / YornoSo.
# 2024-04-23 14:22:52,216 [INFO] Calculating alignments for pair BankanTey / BankanTey.
# 2024-04-23 14:22:52,291 [INFO] Calculating alignments for pair BankanTey / BenTey.
# 2024-04-23 14:22:52,375 [INFO] Calculating alignments for pair BankanTey / BonduSoNajamba.
# CORRESPONDENCE CALCULATION:  10%|████▉                                              | 28/288.0 [00:00<00:04, 61.01it/s]2024-04-23 14:22:52,462 [INFO] Calculating alignments for pair BankanTey / Bunoge.
# 2024-04-23 14:22:52,515 [INFO] Calculating alignments for pair BankanTey / DogulDomBendiely.
# 2024-04-23 14:22:52,556 [INFO] Calculating alignments for pair BankanTey / DogulDomKundialang.
# 2024-04-23 14:22:52,600 [INFO] Calculating alignments for pair BankanTey / DonnoSo.
# 2024-04-23 14:22:52,662 [INFO] Calculating alignments for pair BankanTey / JamsayDouentza.
# 2024-04-23 14:22:52,744 [INFO] Calculating alignments for pair BankanTey / JamsayGourou.
# 2024-04-23 14:22:52,777 [INFO] Calculating alignments for pair BankanTey / JamsayMondoro.
# 2024-04-23 14:22:52,796 [INFO] Calculating alignments for pair BankanTey / Mombo.
# 2024-04-23 14:22:52,869 [INFO] Calculating alignments for pair BankanTey / Nanga.
# CORRESPONDENCE CALCULATION:  13%|██████▌                                            | 37/288.0 [00:00<00:07, 33.41it/s]2024-04-23 14:22:52,957 [INFO] Calculating alignments for pair BankanTey / Penange.
# 2024-04-23 14:22:53,011 [INFO] Calculating alignments for pair BankanTey / PergeTegu.
# 2024-04-23 14:22:53,079 [INFO] Calculating alignments for pair BankanTey / TebulUre.
# 2024-04-23 14:22:53,129 [INFO] Calculating alignments for pair BankanTey / Tiranige.
# 2024-04-23 14:22:53,181 [INFO] Calculating alignments for pair BankanTey / TogoKan.
# 2024-04-23 14:22:53,244 [INFO] Calculating alignments for pair BankanTey / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  15%|███████▌                                           | 43/288.0 [00:01<00:09, 26.20it/s]2024-04-23 14:22:53,333 [INFO] Calculating alignments for pair BankanTey / TomoKanDiangassagou.
# 2024-04-23 14:22:53,347 [INFO] Calculating alignments for pair BankanTey / TomoKanSegue.
# 2024-04-23 14:22:53,368 [INFO] Calculating alignments for pair BankanTey / ToroTegu.
# 2024-04-23 14:22:53,439 [INFO] Calculating alignments for pair BankanTey / YandaDom.
# CORRESPONDENCE CALCULATION:  16%|████████▎                                          | 47/288.0 [00:01<00:09, 25.51it/s]2024-04-23 14:22:53,508 [INFO] Calculating alignments for pair BankanTey / YornoSo.
# 2024-04-23 14:22:53,578 [INFO] Calculating alignments for pair BenTey / BenTey.
# 2024-04-23 14:22:53,660 [INFO] Calculating alignments for pair BenTey / BonduSoNajamba.
# 2024-04-23 14:22:53,753 [INFO] Calculating alignments for pair BenTey / Bunoge.
# CORRESPONDENCE CALCULATION:  18%|█████████                                          | 51/288.0 [00:01<00:11, 21.21it/s]2024-04-23 14:22:53,812 [INFO] Calculating alignments for pair BenTey / DogulDomBendiely.
# 2024-04-23 14:22:53,860 [INFO] Calculating alignments for pair BenTey / DogulDomKundialang.
# 2024-04-23 14:22:53,910 [INFO] Calculating alignments for pair BenTey / DonnoSo.
# CORRESPONDENCE CALCULATION:  19%|█████████▌                                         | 54/288.0 [00:01<00:11, 20.41it/s]2024-04-23 14:22:53,982 [INFO] Calculating alignments for pair BenTey / JamsayDouentza.
# 2024-04-23 14:22:54,078 [INFO] Calculating alignments for pair BenTey / JamsayGourou.
# 2024-04-23 14:22:54,114 [INFO] Calculating alignments for pair BenTey / JamsayMondoro.
# CORRESPONDENCE CALCULATION:  20%|██████████                                         | 57/288.0 [00:02<00:11, 20.21it/s]2024-04-23 14:22:54,136 [INFO] Calculating alignments for pair BenTey / Mombo.
# 2024-04-23 14:22:54,219 [INFO] Calculating alignments for pair BenTey / Nanga.
# 2024-04-23 14:22:54,321 [INFO] Calculating alignments for pair BenTey / Penange.
# CORRESPONDENCE CALCULATION:  21%|██████████▋                                        | 60/288.0 [00:02<00:12, 17.61it/s]2024-04-23 14:22:54,379 [INFO] Calculating alignments for pair BenTey / PergeTegu.
# 2024-04-23 14:22:54,466 [INFO] Calculating alignments for pair BenTey / TebulUre.
# CORRESPONDENCE CALCULATION:  22%|██████████▉                                        | 62/288.0 [00:02<00:13, 16.74it/s]2024-04-23 14:22:54,525 [INFO] Calculating alignments for pair BenTey / Tiranige.
# 2024-04-23 14:22:54,584 [INFO] Calculating alignments for pair BenTey / TogoKan.
# CORRESPONDENCE CALCULATION:  22%|███████████▎                                       | 64/288.0 [00:02<00:13, 16.39it/s]2024-04-23 14:22:54,657 [INFO] Calculating alignments for pair BenTey / TommoSoTongoTongo.
# 2024-04-23 14:22:54,759 [INFO] Calculating alignments for pair BenTey / TomoKanDiangassagou.
# CORRESPONDENCE CALCULATION:  23%|███████████▋                                       | 66/288.0 [00:02<00:13, 16.64it/s]2024-04-23 14:22:54,772 [INFO] Calculating alignments for pair BenTey / TomoKanSegue.
# 2024-04-23 14:22:54,796 [INFO] Calculating alignments for pair BenTey / ToroTegu.
# CORRESPONDENCE CALCULATION:  24%|████████████                                       | 68/288.0 [00:02<00:12, 17.06it/s]2024-04-23 14:22:54,880 [INFO] Calculating alignments for pair BenTey / YandaDom.
# 2024-04-23 14:22:54,960 [INFO] Calculating alignments for pair BenTey / YornoSo.
# CORRESPONDENCE CALCULATION:  24%|████████████▍                                      | 70/288.0 [00:02<00:14, 15.56it/s]2024-04-23 14:22:55,041 [INFO] Calculating alignments for pair BonduSoNajamba / BonduSoNajamba.
# 2024-04-23 14:22:55,127 [INFO] Calculating alignments for pair BonduSoNajamba / Bunoge.
# CORRESPONDENCE CALCULATION:  25%|████████████▊                                      | 72/288.0 [00:03<00:14, 15.22it/s]2024-04-23 14:22:55,179 [INFO] Calculating alignments for pair BonduSoNajamba / DogulDomBendiely.
# 2024-04-23 14:22:55,221 [INFO] Calculating alignments for pair BonduSoNajamba / DogulDomKundialang.
# 2024-04-23 14:22:55,266 [INFO] Calculating alignments for pair BonduSoNajamba / DonnoSo.
# CORRESPONDENCE CALCULATION:  26%|█████████████▎                                     | 75/288.0 [00:03<00:12, 16.65it/s]2024-04-23 14:22:55,331 [INFO] Calculating alignments for pair BonduSoNajamba / JamsayDouentza.
# 2024-04-23 14:22:55,411 [INFO] Calculating alignments for pair BonduSoNajamba / JamsayGourou.
# CORRESPONDENCE CALCULATION:  27%|█████████████▋                                     | 77/288.0 [00:03<00:12, 16.95it/s]2024-04-23 14:22:55,442 [INFO] Calculating alignments for pair BonduSoNajamba / JamsayMondoro.
# 2024-04-23 14:22:55,462 [INFO] Calculating alignments for pair BonduSoNajamba / Mombo.
# 2024-04-23 14:22:55,534 [INFO] Calculating alignments for pair BonduSoNajamba / Nanga.
# CORRESPONDENCE CALCULATION:  28%|██████████████▏                                    | 80/288.0 [00:03<00:12, 16.95it/s]2024-04-23 14:22:55,619 [INFO] Calculating alignments for pair BonduSoNajamba / Penange.
# 2024-04-23 14:22:55,671 [INFO] Calculating alignments for pair BonduSoNajamba / PergeTegu.
# CORRESPONDENCE CALCULATION:  28%|██████████████▌                                    | 82/288.0 [00:03<00:12, 16.91it/s]2024-04-23 14:22:55,739 [INFO] Calculating alignments for pair BonduSoNajamba / TebulUre.
# 2024-04-23 14:22:55,789 [INFO] Calculating alignments for pair BonduSoNajamba / Tiranige.
# CORRESPONDENCE CALCULATION:  29%|██████████████▉                                    | 84/288.0 [00:03<00:11, 17.04it/s]2024-04-23 14:22:55,854 [INFO] Calculating alignments for pair BonduSoNajamba / TogoKan.
# 2024-04-23 14:22:55,919 [INFO] Calculating alignments for pair BonduSoNajamba / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  30%|███████████████▏                                   | 86/288.0 [00:03<00:12, 15.62it/s]2024-04-23 14:22:56,010 [INFO] Calculating alignments for pair BonduSoNajamba / TomoKanDiangassagou.
# 2024-04-23 14:22:56,023 [INFO] Calculating alignments for pair BonduSoNajamba / TomoKanSegue.
# 2024-04-23 14:22:56,044 [INFO] Calculating alignments for pair BonduSoNajamba / ToroTegu.
# CORRESPONDENCE CALCULATION:  31%|███████████████▊                                   | 89/288.0 [00:04<00:10, 18.76it/s]2024-04-23 14:22:56,116 [INFO] Calculating alignments for pair BonduSoNajamba / YandaDom.
# 2024-04-23 14:22:56,184 [INFO] Calculating alignments for pair BonduSoNajamba / YornoSo.
# CORRESPONDENCE CALCULATION:  32%|████████████████                                   | 91/288.0 [00:04<00:11, 17.30it/s]2024-04-23 14:22:56,256 [INFO] Calculating alignments for pair Bunoge / Bunoge.
# 2024-04-23 14:22:56,306 [INFO] Calculating alignments for pair Bunoge / DogulDomBendiely.
# 2024-04-23 14:22:56,336 [INFO] Calculating alignments for pair Bunoge / DogulDomKundialang.
# CORRESPONDENCE CALCULATION:  33%|████████████████▋                                  | 94/288.0 [00:04<00:09, 19.78it/s]2024-04-23 14:22:56,370 [INFO] Calculating alignments for pair Bunoge / DonnoSo.
# 2024-04-23 14:22:56,414 [INFO] Calculating alignments for pair Bunoge / JamsayDouentza.
# 2024-04-23 14:22:56,466 [INFO] Calculating alignments for pair Bunoge / JamsayGourou.
# CORRESPONDENCE CALCULATION:  34%|█████████████████▏                                 | 97/288.0 [00:04<00:09, 21.18it/s]2024-04-23 14:22:56,491 [INFO] Calculating alignments for pair Bunoge / JamsayMondoro.
# 2024-04-23 14:22:56,507 [INFO] Calculating alignments for pair Bunoge / Mombo.
# 2024-04-23 14:22:56,553 [INFO] Calculating alignments for pair Bunoge / Nanga.
# CORRESPONDENCE CALCULATION:  35%|█████████████████▎                                | 100/288.0 [00:04<00:08, 22.45it/s]2024-04-23 14:22:56,608 [INFO] Calculating alignments for pair Bunoge / Penange.
# 2024-04-23 14:22:56,655 [INFO] Calculating alignments for pair Bunoge / PergeTegu.
# 2024-04-23 14:22:56,697 [INFO] Calculating alignments for pair Bunoge / TebulUre.
# CORRESPONDENCE CALCULATION:  36%|█████████████████▉                                | 103/288.0 [00:04<00:08, 22.98it/s]2024-04-23 14:22:56,733 [INFO] Calculating alignments for pair Bunoge / Tiranige.
# 2024-04-23 14:22:56,774 [INFO] Calculating alignments for pair Bunoge / TogoKan.
# 2024-04-23 14:22:56,815 [INFO] Calculating alignments for pair Bunoge / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  37%|██████████████████▍                               | 106/288.0 [00:04<00:08, 22.68it/s]2024-04-23 14:22:56,868 [INFO] Calculating alignments for pair Bunoge / TomoKanDiangassagou.
# 2024-04-23 14:22:56,877 [INFO] Calculating alignments for pair Bunoge / TomoKanSegue.
# 2024-04-23 14:22:56,893 [INFO] Calculating alignments for pair Bunoge / ToroTegu.
# 2024-04-23 14:22:56,938 [INFO] Calculating alignments for pair Bunoge / YandaDom.
# CORRESPONDENCE CALCULATION:  38%|███████████████████                               | 110/288.0 [00:04<00:06, 26.13it/s]2024-04-23 14:22:56,983 [INFO] Calculating alignments for pair Bunoge / YornoSo.
# 2024-04-23 14:22:57,025 [INFO] Calculating alignments for pair DogulDomBendiely / DogulDomBendiely.
# 2024-04-23 14:22:57,060 [INFO] Calculating alignments for pair DogulDomBendiely / DogulDomKundialang.
# CORRESPONDENCE CALCULATION:  39%|███████████████████▌                              | 113/288.0 [00:05<00:06, 26.65it/s]2024-04-23 14:22:57,089 [INFO] Calculating alignments for pair DogulDomBendiely / DonnoSo.
# 2024-04-23 14:22:57,127 [INFO] Calculating alignments for pair DogulDomBendiely / JamsayDouentza.
# 2024-04-23 14:22:57,172 [INFO] Calculating alignments for pair DogulDomBendiely / JamsayGourou.
# CORRESPONDENCE CALCULATION:  40%|████████████████████▏                             | 116/288.0 [00:05<00:06, 27.18it/s]2024-04-23 14:22:57,194 [INFO] Calculating alignments for pair DogulDomBendiely / JamsayMondoro.
# 2024-04-23 14:22:57,209 [INFO] Calculating alignments for pair DogulDomBendiely / Mombo.
# 2024-04-23 14:22:57,249 [INFO] Calculating alignments for pair DogulDomBendiely / Nanga.
# CORRESPONDENCE CALCULATION:  41%|████████████████████▋                             | 119/288.0 [00:05<00:06, 27.80it/s]2024-04-23 14:22:57,296 [INFO] Calculating alignments for pair DogulDomBendiely / Penange.
# 2024-04-23 14:22:57,330 [INFO] Calculating alignments for pair DogulDomBendiely / PergeTegu.
# 2024-04-23 14:22:57,368 [INFO] Calculating alignments for pair DogulDomBendiely / TebulUre.
# CORRESPONDENCE CALCULATION:  42%|█████████████████████▏                            | 122/288.0 [00:05<00:05, 28.02it/s]2024-04-23 14:22:57,402 [INFO] Calculating alignments for pair DogulDomBendiely / Tiranige.
# 2024-04-23 14:22:57,435 [INFO] Calculating alignments for pair DogulDomBendiely / TogoKan.
# 2024-04-23 14:22:57,472 [INFO] Calculating alignments for pair DogulDomBendiely / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  43%|█████████████████████▋                            | 125/288.0 [00:05<00:06, 27.12it/s]2024-04-23 14:22:57,521 [INFO] Calculating alignments for pair DogulDomBendiely / TomoKanDiangassagou.
# 2024-04-23 14:22:57,529 [INFO] Calculating alignments for pair DogulDomBendiely / TomoKanSegue.
# 2024-04-23 14:22:57,542 [INFO] Calculating alignments for pair DogulDomBendiely / ToroTegu.
# 2024-04-23 14:22:57,583 [INFO] Calculating alignments for pair DogulDomBendiely / YandaDom.
# CORRESPONDENCE CALCULATION:  45%|██████████████████████▍                           | 129/288.0 [00:05<00:05, 30.44it/s]2024-04-23 14:22:57,623 [INFO] Calculating alignments for pair DogulDomBendiely / YornoSo.
# 2024-04-23 14:22:57,663 [INFO] Calculating alignments for pair DogulDomKundialang / DogulDomKundialang.
# 2024-04-23 14:22:57,706 [INFO] Calculating alignments for pair DogulDomKundialang / DonnoSo.
# 2024-04-23 14:22:57,749 [INFO] Calculating alignments for pair DogulDomKundialang / JamsayDouentza.
# CORRESPONDENCE CALCULATION:  46%|███████████████████████                           | 133/288.0 [00:05<00:05, 27.35it/s]2024-04-23 14:22:57,799 [INFO] Calculating alignments for pair DogulDomKundialang / JamsayGourou.
# 2024-04-23 14:22:57,823 [INFO] Calculating alignments for pair DogulDomKundialang / JamsayMondoro.
# 2024-04-23 14:22:57,837 [INFO] Calculating alignments for pair DogulDomKundialang / Mombo.
# 2024-04-23 14:22:57,881 [INFO] Calculating alignments for pair DogulDomKundialang / Nanga.
# CORRESPONDENCE CALCULATION:  48%|███████████████████████▊                          | 137/288.0 [00:05<00:05, 28.12it/s]2024-04-23 14:22:57,933 [INFO] Calculating alignments for pair DogulDomKundialang / Penange.
# 2024-04-23 14:22:57,970 [INFO] Calculating alignments for pair DogulDomKundialang / PergeTegu.
# 2024-04-23 14:22:58,011 [INFO] Calculating alignments for pair DogulDomKundialang / TebulUre.
# CORRESPONDENCE CALCULATION:  49%|████████████████████████▎                         | 140/288.0 [00:06<00:05, 27.30it/s]2024-04-23 14:22:58,051 [INFO] Calculating alignments for pair DogulDomKundialang / Tiranige.
# 2024-04-23 14:22:58,089 [INFO] Calculating alignments for pair DogulDomKundialang / TogoKan.
# 2024-04-23 14:22:58,130 [INFO] Calculating alignments for pair DogulDomKundialang / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  50%|████████████████████████▊                         | 143/288.0 [00:06<00:05, 25.83it/s]2024-04-23 14:22:58,185 [INFO] Calculating alignments for pair DogulDomKundialang / TomoKanDiangassagou.
# 2024-04-23 14:22:58,194 [INFO] Calculating alignments for pair DogulDomKundialang / TomoKanSegue.
# 2024-04-23 14:22:58,212 [INFO] Calculating alignments for pair DogulDomKundialang / ToroTegu.
# 2024-04-23 14:22:58,254 [INFO] Calculating alignments for pair DogulDomKundialang / YandaDom.
# CORRESPONDENCE CALCULATION:  51%|█████████████████████████▌                        | 147/288.0 [00:06<00:04, 28.31it/s]2024-04-23 14:22:58,300 [INFO] Calculating alignments for pair DogulDomKundialang / YornoSo.
# 2024-04-23 14:22:58,343 [INFO] Calculating alignments for pair DonnoSo / DonnoSo.
# 2024-04-23 14:22:58,405 [INFO] Calculating alignments for pair DonnoSo / JamsayDouentza.
# CORRESPONDENCE CALCULATION:  52%|██████████████████████████                        | 150/288.0 [00:06<00:05, 23.96it/s]2024-04-23 14:22:58,478 [INFO] Calculating alignments for pair DonnoSo / JamsayGourou.
# 2024-04-23 14:22:58,508 [INFO] Calculating alignments for pair DonnoSo / JamsayMondoro.
# 2024-04-23 14:22:58,528 [INFO] Calculating alignments for pair DonnoSo / Mombo.
# CORRESPONDENCE CALCULATION:  53%|██████████████████████████▌                       | 153/288.0 [00:06<00:05, 24.57it/s]2024-04-23 14:22:58,592 [INFO] Calculating alignments for pair DonnoSo / Nanga.
# 2024-04-23 14:22:58,681 [INFO] Calculating alignments for pair DonnoSo / Penange.
# 2024-04-23 14:22:58,733 [INFO] Calculating alignments for pair DonnoSo / PergeTegu.
# CORRESPONDENCE CALCULATION:  54%|███████████████████████████                       | 156/288.0 [00:06<00:06, 20.73it/s]2024-04-23 14:22:58,793 [INFO] Calculating alignments for pair DonnoSo / TebulUre.
# 2024-04-23 14:22:58,843 [INFO] Calculating alignments for pair DonnoSo / Tiranige.
# 2024-04-23 14:22:58,893 [INFO] Calculating alignments for pair DonnoSo / TogoKan.
# CORRESPONDENCE CALCULATION:  55%|███████████████████████████▌                      | 159/288.0 [00:06<00:06, 20.12it/s]2024-04-23 14:22:58,953 [INFO] Calculating alignments for pair DonnoSo / TommoSoTongoTongo.
# 2024-04-23 14:22:59,028 [INFO] Calculating alignments for pair DonnoSo / TomoKanDiangassagou.
# 2024-04-23 14:22:59,040 [INFO] Calculating alignments for pair DonnoSo / TomoKanSegue.
# CORRESPONDENCE CALCULATION:  56%|████████████████████████████▏                     | 162/288.0 [00:07<00:05, 21.92it/s]2024-04-23 14:22:59,060 [INFO] Calculating alignments for pair DonnoSo / ToroTegu.
# 2024-04-23 14:22:59,124 [INFO] Calculating alignments for pair DonnoSo / YandaDom.
# 2024-04-23 14:22:59,183 [INFO] Calculating alignments for pair DonnoSo / YornoSo.
# CORRESPONDENCE CALCULATION:  57%|████████████████████████████▋                     | 165/288.0 [00:07<00:06, 20.18it/s]2024-04-23 14:22:59,237 [INFO] Calculating alignments for pair JamsayDouentza / JamsayDouentza.
# 2024-04-23 14:22:59,306 [INFO] Calculating alignments for pair JamsayDouentza / JamsayGourou.
# 2024-04-23 14:22:59,338 [INFO] Calculating alignments for pair JamsayDouentza / JamsayMondoro.
# CORRESPONDENCE CALCULATION:  58%|█████████████████████████████▏                    | 168/288.0 [00:07<00:05, 21.36it/s]2024-04-23 14:22:59,359 [INFO] Calculating alignments for pair JamsayDouentza / Mombo.
# 2024-04-23 14:22:59,431 [INFO] Calculating alignments for pair JamsayDouentza / Nanga.
# 2024-04-23 14:22:59,519 [INFO] Calculating alignments for pair JamsayDouentza / Penange.
# CORRESPONDENCE CALCULATION:  59%|█████████████████████████████▋                    | 171/288.0 [00:07<00:06, 18.54it/s]2024-04-23 14:22:59,570 [INFO] Calculating alignments for pair JamsayDouentza / PergeTegu.
# 2024-04-23 14:22:59,636 [INFO] Calculating alignments for pair JamsayDouentza / TebulUre.
# CORRESPONDENCE CALCULATION:  60%|██████████████████████████████                    | 173/288.0 [00:07<00:06, 18.20it/s]2024-04-23 14:22:59,688 [INFO] Calculating alignments for pair JamsayDouentza / Tiranige.
# 2024-04-23 14:22:59,740 [INFO] Calculating alignments for pair JamsayDouentza / TogoKan.
# CORRESPONDENCE CALCULATION:  61%|██████████████████████████████▍                   | 175/288.0 [00:07<00:06, 17.89it/s]2024-04-23 14:22:59,806 [INFO] Calculating alignments for pair JamsayDouentza / TommoSoTongoTongo.
# 2024-04-23 14:22:59,895 [INFO] Calculating alignments for pair JamsayDouentza / TomoKanDiangassagou.
# CORRESPONDENCE CALCULATION:  61%|██████████████████████████████▋                   | 177/288.0 [00:07<00:06, 18.33it/s]2024-04-23 14:22:59,907 [INFO] Calculating alignments for pair JamsayDouentza / TomoKanSegue.
# 2024-04-23 14:22:59,927 [INFO] Calculating alignments for pair JamsayDouentza / ToroTegu.
# 2024-04-23 14:23:00,000 [INFO] Calculating alignments for pair JamsayDouentza / YandaDom.
# CORRESPONDENCE CALCULATION:  62%|███████████████████████████████▎                  | 180/288.0 [00:08<00:05, 18.25it/s]2024-04-23 14:23:00,073 [INFO] Calculating alignments for pair JamsayDouentza / YornoSo.
# 2024-04-23 14:23:00,145 [INFO] Calculating alignments for pair JamsayGourou / JamsayGourou.
# 2024-04-23 14:23:00,171 [INFO] Calculating alignments for pair JamsayGourou / JamsayMondoro.
# CORRESPONDENCE CALCULATION:  64%|███████████████████████████████▊                  | 183/288.0 [00:08<00:05, 20.38it/s]2024-04-23 14:23:00,185 [INFO] Calculating alignments for pair JamsayGourou / Mombo.
# 2024-04-23 14:23:00,217 [INFO] Calculating alignments for pair JamsayGourou / Nanga.
# 2024-04-23 14:23:00,254 [INFO] Calculating alignments for pair JamsayGourou / Penange.
# 2024-04-23 14:23:00,282 [INFO] Calculating alignments for pair JamsayGourou / PergeTegu.
# CORRESPONDENCE CALCULATION:  65%|████████████████████████████████▍                 | 187/288.0 [00:08<00:04, 23.63it/s]2024-04-23 14:23:00,312 [INFO] Calculating alignments for pair JamsayGourou / TebulUre.
# 2024-04-23 14:23:00,338 [INFO] Calculating alignments for pair JamsayGourou / Tiranige.
# 2024-04-23 14:23:00,364 [INFO] Calculating alignments for pair JamsayGourou / TogoKan.
# 2024-04-23 14:23:00,395 [INFO] Calculating alignments for pair JamsayGourou / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  66%|█████████████████████████████████▏                | 191/288.0 [00:08<00:03, 26.43it/s]2024-04-23 14:23:00,432 [INFO] Calculating alignments for pair JamsayGourou / TomoKanDiangassagou.
# 2024-04-23 14:23:00,439 [INFO] Calculating alignments for pair JamsayGourou / TomoKanSegue.
# 2024-04-23 14:23:00,452 [INFO] Calculating alignments for pair JamsayGourou / ToroTegu.
# 2024-04-23 14:23:00,482 [INFO] Calculating alignments for pair JamsayGourou / YandaDom.
# 2024-04-23 14:23:00,514 [INFO] Calculating alignments for pair JamsayGourou / YornoSo.
# CORRESPONDENCE CALCULATION:  68%|██████████████████████████████████                | 196/288.0 [00:08<00:02, 31.20it/s]2024-04-23 14:23:00,546 [INFO] Calculating alignments for pair JamsayMondoro / JamsayMondoro.
# 2024-04-23 14:23:00,563 [INFO] Calculating alignments for pair JamsayMondoro / Mombo.
# 2024-04-23 14:23:00,582 [INFO] Calculating alignments for pair JamsayMondoro / Nanga.
# 2024-04-23 14:23:00,603 [INFO] Calculating alignments for pair JamsayMondoro / Penange.
# 2024-04-23 14:23:00,621 [INFO] Calculating alignments for pair JamsayMondoro / PergeTegu.
# 2024-04-23 14:23:00,640 [INFO] Calculating alignments for pair JamsayMondoro / TebulUre.
# CORRESPONDENCE CALCULATION:  70%|███████████████████████████████████               | 202/288.0 [00:08<00:02, 37.55it/s]2024-04-23 14:23:00,657 [INFO] Calculating alignments for pair JamsayMondoro / Tiranige.
# 2024-04-23 14:23:00,673 [INFO] Calculating alignments for pair JamsayMondoro / TogoKan.
# 2024-04-23 14:23:00,691 [INFO] Calculating alignments for pair JamsayMondoro / TommoSoTongoTongo.
# 2024-04-23 14:23:00,713 [INFO] Calculating alignments for pair JamsayMondoro / TomoKanDiangassagou.
# 2024-04-23 14:23:00,718 [INFO] Calculating alignments for pair JamsayMondoro / TomoKanSegue.
# 2024-04-23 14:23:00,725 [INFO] Calculating alignments for pair JamsayMondoro / ToroTegu.
# 2024-04-23 14:23:00,744 [INFO] Calculating alignments for pair JamsayMondoro / YandaDom.
# CORRESPONDENCE CALCULATION:  73%|████████████████████████████████████▎             | 209/288.0 [00:08<00:01, 45.27it/s]2024-04-23 14:23:00,765 [INFO] Calculating alignments for pair JamsayMondoro / YornoSo.
# 2024-04-23 14:23:00,784 [INFO] Calculating alignments for pair Mombo / Mombo.
# 2024-04-23 14:23:00,868 [INFO] Calculating alignments for pair Mombo / Nanga.
# 2024-04-23 14:23:00,954 [INFO] Calculating alignments for pair Mombo / Penange.
# 2024-04-23 14:23:01,006 [INFO] Calculating alignments for pair Mombo / PergeTegu.
# CORRESPONDENCE CALCULATION:  74%|█████████████████████████████████████▏            | 214/288.0 [00:09<00:02, 29.79it/s]2024-04-23 14:23:01,073 [INFO] Calculating alignments for pair Mombo / TebulUre.
# 2024-04-23 14:23:01,123 [INFO] Calculating alignments for pair Mombo / Tiranige.
# 2024-04-23 14:23:01,176 [INFO] Calculating alignments for pair Mombo / TogoKan.
# 2024-04-23 14:23:01,243 [INFO] Calculating alignments for pair Mombo / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  76%|█████████████████████████████████████▊            | 218/288.0 [00:09<00:02, 24.12it/s]2024-04-23 14:23:01,335 [INFO] Calculating alignments for pair Mombo / TomoKanDiangassagou.
# 2024-04-23 14:23:01,347 [INFO] Calculating alignments for pair Mombo / TomoKanSegue.
# 2024-04-23 14:23:01,368 [INFO] Calculating alignments for pair Mombo / ToroTegu.
# 2024-04-23 14:23:01,441 [INFO] Calculating alignments for pair Mombo / YandaDom.
# CORRESPONDENCE CALCULATION:  77%|██████████████████████████████████████▌           | 222/288.0 [00:09<00:02, 23.73it/s]2024-04-23 14:23:01,511 [INFO] Calculating alignments for pair Mombo / YornoSo.
# 2024-04-23 14:23:01,580 [INFO] Calculating alignments for pair Nanga / Nanga.
# 2024-04-23 14:23:01,668 [INFO] Calculating alignments for pair Nanga / Penange.
# CORRESPONDENCE CALCULATION:  78%|███████████████████████████████████████           | 225/288.0 [00:09<00:03, 20.45it/s]2024-04-23 14:23:01,729 [INFO] Calculating alignments for pair Nanga / PergeTegu.
# 2024-04-23 14:23:01,807 [INFO] Calculating alignments for pair Nanga / TebulUre.
# 2024-04-23 14:23:01,866 [INFO] Calculating alignments for pair Nanga / Tiranige.
# CORRESPONDENCE CALCULATION:  79%|███████████████████████████████████████▌          | 228/288.0 [00:09<00:03, 18.87it/s]2024-04-23 14:23:01,928 [INFO] Calculating alignments for pair Nanga / TogoKan.
# 2024-04-23 14:23:02,004 [INFO] Calculating alignments for pair Nanga / TommoSoTongoTongo.
# 2024-04-23 14:23:02,110 [INFO] Calculating alignments for pair Nanga / TomoKanDiangassagou.
# CORRESPONDENCE CALCULATION:  80%|████████████████████████████████████████          | 231/288.0 [00:10<00:03, 17.76it/s]2024-04-23 14:23:02,125 [INFO] Calculating alignments for pair Nanga / TomoKanSegue.
# 2024-04-23 14:23:02,150 [INFO] Calculating alignments for pair Nanga / ToroTegu.
# CORRESPONDENCE CALCULATION:  81%|████████████████████████████████████████▍         | 233/288.0 [00:10<00:03, 17.81it/s]2024-04-23 14:23:02,237 [INFO] Calculating alignments for pair Nanga / YandaDom.
# 2024-04-23 14:23:02,320 [INFO] Calculating alignments for pair Nanga / YornoSo.
# CORRESPONDENCE CALCULATION:  82%|████████████████████████████████████████▊         | 235/288.0 [00:10<00:03, 16.10it/s]2024-04-23 14:23:02,404 [INFO] Calculating alignments for pair Penange / Penange.
# 2024-04-23 14:23:02,456 [INFO] Calculating alignments for pair Penange / PergeTegu.
# 2024-04-23 14:23:02,503 [INFO] Calculating alignments for pair Penange / TebulUre.
# CORRESPONDENCE CALCULATION:  83%|█████████████████████████████████████████▎        | 238/288.0 [00:10<00:02, 17.45it/s]2024-04-23 14:23:02,544 [INFO] Calculating alignments for pair Penange / Tiranige.
# 2024-04-23 14:23:02,590 [INFO] Calculating alignments for pair Penange / TogoKan.
# 2024-04-23 14:23:02,637 [INFO] Calculating alignments for pair Penange / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  84%|█████████████████████████████████████████▊        | 241/288.0 [00:10<00:02, 18.05it/s]2024-04-23 14:23:02,699 [INFO] Calculating alignments for pair Penange / TomoKanDiangassagou.
# 2024-04-23 14:23:02,710 [INFO] Calculating alignments for pair Penange / TomoKanSegue.
# 2024-04-23 14:23:02,728 [INFO] Calculating alignments for pair Penange / ToroTegu.
# 2024-04-23 14:23:02,779 [INFO] Calculating alignments for pair Penange / YandaDom.
# CORRESPONDENCE CALCULATION:  85%|██████████████████████████████████████████▌       | 245/288.0 [00:10<00:02, 21.21it/s]2024-04-23 14:23:02,831 [INFO] Calculating alignments for pair Penange / YornoSo.
# 2024-04-23 14:23:02,879 [INFO] Calculating alignments for pair PergeTegu / PergeTegu.
# 2024-04-23 14:23:02,935 [INFO] Calculating alignments for pair PergeTegu / TebulUre.
# CORRESPONDENCE CALCULATION:  86%|███████████████████████████████████████████       | 248/288.0 [00:10<00:01, 21.02it/s]2024-04-23 14:23:02,978 [INFO] Calculating alignments for pair PergeTegu / Tiranige.
# 2024-04-23 14:23:03,021 [INFO] Calculating alignments for pair PergeTegu / TogoKan.
# 2024-04-23 14:23:03,074 [INFO] Calculating alignments for pair PergeTegu / TommoSoTongoTongo.
# CORRESPONDENCE CALCULATION:  87%|███████████████████████████████████████████▌      | 251/288.0 [00:11<00:01, 19.92it/s]2024-04-23 14:23:03,147 [INFO] Calculating alignments for pair PergeTegu / TomoKanDiangassagou.
# 2024-04-23 14:23:03,157 [INFO] Calculating alignments for pair PergeTegu / TomoKanSegue.
# 2024-04-23 14:23:03,174 [INFO] Calculating alignments for pair PergeTegu / ToroTegu.
# 2024-04-23 14:23:03,233 [INFO] Calculating alignments for pair PergeTegu / YandaDom.
# CORRESPONDENCE CALCULATION:  89%|████████████████████████████████████████████▎     | 255/288.0 [00:11<00:01, 21.89it/s]2024-04-23 14:23:03,298 [INFO] Calculating alignments for pair PergeTegu / YornoSo.
# 2024-04-23 14:23:03,364 [INFO] Calculating alignments for pair TebulUre / TebulUre.
# 2024-04-23 14:23:03,414 [INFO] Calculating alignments for pair TebulUre / Tiranige.
# CORRESPONDENCE CALCULATION:  90%|████████████████████████████████████████████▊     | 258/288.0 [00:11<00:01, 21.00it/s]2024-04-23 14:23:03,456 [INFO] Calculating alignments for pair TebulUre / TogoKan.
# 2024-04-23 14:23:03,502 [INFO] Calculating alignments for pair TebulUre / TommoSoTongoTongo.
# 2024-04-23 14:23:03,561 [INFO] Calculating alignments for pair TebulUre / TomoKanDiangassagou.
# CORRESPONDENCE CALCULATION:  91%|█████████████████████████████████████████████▎    | 261/288.0 [00:11<00:01, 22.13it/s]2024-04-23 14:23:03,572 [INFO] Calculating alignments for pair TebulUre / TomoKanSegue.
# 2024-04-23 14:23:03,591 [INFO] Calculating alignments for pair TebulUre / ToroTegu.
# 2024-04-23 14:23:03,639 [INFO] Calculating alignments for pair TebulUre / YandaDom.
# CORRESPONDENCE CALCULATION:  92%|█████████████████████████████████████████████▊    | 264/288.0 [00:11<00:01, 22.89it/s]2024-04-23 14:23:03,693 [INFO] Calculating alignments for pair TebulUre / YornoSo.
# 2024-04-23 14:23:03,744 [INFO] Calculating alignments for pair Tiranige / Tiranige.
# 2024-04-23 14:23:03,797 [INFO] Calculating alignments for pair Tiranige / TogoKan.
# CORRESPONDENCE CALCULATION:  93%|██████████████████████████████████████████████▎   | 267/288.0 [00:11<00:00, 21.87it/s]2024-04-23 14:23:03,845 [INFO] Calculating alignments for pair Tiranige / TommoSoTongoTongo.
# 2024-04-23 14:23:03,906 [INFO] Calculating alignments for pair Tiranige / TomoKanDiangassagou.
# 2024-04-23 14:23:03,915 [INFO] Calculating alignments for pair Tiranige / TomoKanSegue.
# 2024-04-23 14:23:03,931 [INFO] Calculating alignments for pair Tiranige / ToroTegu.
# CORRESPONDENCE CALCULATION:  94%|███████████████████████████████████████████████   | 271/288.0 [00:11<00:00, 24.07it/s]2024-04-23 14:23:03,981 [INFO] Calculating alignments for pair Tiranige / YandaDom.
# 2024-04-23 14:23:04,032 [INFO] Calculating alignments for pair Tiranige / YornoSo.
# 2024-04-23 14:23:04,081 [INFO] Calculating alignments for pair TogoKan / TogoKan.
# CORRESPONDENCE CALCULATION:  95%|███████████████████████████████████████████████▌  | 274/288.0 [00:12<00:00, 22.28it/s]2024-04-23 14:23:04,142 [INFO] Calculating alignments for pair TogoKan / TommoSoTongoTongo.
# 2024-04-23 14:23:04,222 [INFO] Calculating alignments for pair TogoKan / TomoKanDiangassagou.
# 2024-04-23 14:23:04,233 [INFO] Calculating alignments for pair TogoKan / TomoKanSegue.
# CORRESPONDENCE CALCULATION:  96%|████████████████████████████████████████████████  | 277/288.0 [00:12<00:00, 23.49it/s]2024-04-23 14:23:04,252 [INFO] Calculating alignments for pair TogoKan / ToroTegu.
# 2024-04-23 14:23:04,314 [INFO] Calculating alignments for pair TogoKan / YandaDom.
# 2024-04-23 14:23:04,378 [INFO] Calculating alignments for pair TogoKan / YornoSo.
# CORRESPONDENCE CALCULATION:  97%|████████████████████████████████████████████████▌ | 280/288.0 [00:12<00:00, 20.56it/s]2024-04-23 14:23:04,443 [INFO] Calculating alignments for pair TommoSoTongoTongo / TommoSoTongoTongo.
# 2024-04-23 14:23:04,544 [INFO] Calculating alignments for pair TommoSoTongoTongo / TomoKanDiangassagou.
# 2024-04-23 14:23:04,556 [INFO] Calculating alignments for pair TommoSoTongoTongo / TomoKanSegue.
# CORRESPONDENCE CALCULATION:  98%|█████████████████████████████████████████████████▏| 283/288.0 [00:12<00:00, 20.93it/s]2024-04-23 14:23:04,579 [INFO] Calculating alignments for pair TommoSoTongoTongo / ToroTegu.
# 2024-04-23 14:23:04,666 [INFO] Calculating alignments for pair TommoSoTongoTongo / YandaDom.
# 2024-04-23 14:23:04,749 [INFO] Calculating alignments for pair TommoSoTongoTongo / YornoSo.
# CORRESPONDENCE CALCULATION:  99%|█████████████████████████████████████████████████▋| 286/288.0 [00:12<00:00, 16.83it/s]2024-04-23 14:23:04,842 [INFO] Calculating alignments for pair TomoKanDiangassagou / TomoKanDiangassagou.
# 2024-04-23 14:23:04,856 [INFO] Calculating alignments for pair TomoKanDiangassagou / TomoKanSegue.
# 2024-04-23 14:23:04,869 [INFO] Calculating alignments for pair TomoKanDiangassagou / ToroTegu.
# 2024-04-23 14:23:04,881 [INFO] Calculating alignments for pair TomoKanDiangassagou / YandaDom.
# 2024-04-23 14:23:04,892 [INFO] Calculating alignments for pair TomoKanDiangassagou / YornoSo.
# 2024-04-23 14:23:04,903 [INFO] Calculating alignments for pair TomoKanSegue / TomoKanSegue.
# 2024-04-23 14:23:04,925 [INFO] Calculating alignments for pair TomoKanSegue / ToroTegu.
# CORRESPONDENCE CALCULATION: 293it [00:12, 26.82it/s]                                                                   2024-04-23 14:23:04,944 [INFO] Calculating alignments for pair TomoKanSegue / YandaDom.
# 2024-04-23 14:23:04,964 [INFO] Calculating alignments for pair TomoKanSegue / YornoSo.
# 2024-04-23 14:23:04,984 [INFO] Calculating alignments for pair ToroTegu / ToroTegu.
# 2024-04-23 14:23:05,049 [INFO] Calculating alignments for pair ToroTegu / YandaDom.
# CORRESPONDENCE CALCULATION: 297it [00:13, 25.64it/s]2024-04-23 14:23:05,117 [INFO] Calculating alignments for pair ToroTegu / YornoSo.
# 2024-04-23 14:23:05,187 [INFO] Calculating alignments for pair YandaDom / YandaDom.
# 2024-04-23 14:23:05,254 [INFO] Calculating alignments for pair YandaDom / YornoSo.
# 2024-04-23 14:23:05,322 [INFO] Calculating alignments for pair YornoSo / YornoSo.
# RANDOM CORRESPONDENCE CALCULATION:   0%|                                                     | 0/288.0 [00:00<?, ?it/s]2024-04-23 14:23:05,391 [INFO] Calculating random alignmentsfor pair Ampari/Ampari.
# RANDOM CORRESPONDENCE CALCULATION:   1%|▎                                            | 2/288.0 [00:00<01:16,  3.73it/s]2024-04-23 14:23:05,928 [INFO] Calculating random alignmentsfor pair Ampari/BankanTey.
# RANDOM CORRESPONDENCE CALCULATION:   1%|▍                                            | 3/288.0 [00:01<02:01,  2.35it/s]2024-04-23 14:23:06,575 [INFO] Calculating random alignmentsfor pair Ampari/BenTey.
# RANDOM CORRESPONDENCE CALCULATION:   1%|▋                                            | 4/288.0 [00:01<02:12,  2.14it/s]2024-04-23 14:23:07,110 [INFO] Calculating random alignmentsfor pair Ampari/BonduSoNajamba.
# RANDOM CORRESPONDENCE CALCULATION:   2%|▊                                            | 5/288.0 [00:02<02:25,  1.95it/s]2024-04-23 14:23:07,711 [INFO] Calculating random alignmentsfor pair Ampari/Bunoge.
# RANDOM CORRESPONDENCE CALCULATION:   2%|▉                                            | 6/288.0 [00:02<02:27,  1.91it/s]2024-04-23 14:23:08,253 [INFO] Calculating random alignmentsfor pair Ampari/DogulDomBendiely.
# RANDOM CORRESPONDENCE CALCULATION:   2%|█                                            | 7/288.0 [00:03<02:35,  1.81it/s]2024-04-23 14:23:08,871 [INFO] Calculating random alignmentsfor pair Ampari/DogulDomKundialang.
# RANDOM CORRESPONDENCE CALCULATION:   3%|█▎                                           | 8/288.0 [00:04<02:33,  1.83it/s]2024-04-23 14:23:09,405 [INFO] Calculating random alignmentsfor pair Ampari/DonnoSo.
# RANDOM CORRESPONDENCE CALCULATION:   3%|█▍                                           | 9/288.0 [00:04<02:28,  1.88it/s]2024-04-23 14:23:09,903 [INFO] Calculating random alignmentsfor pair Ampari/JamsayDouentza.
# RANDOM CORRESPONDENCE CALCULATION:   3%|█▌                                          | 10/288.0 [00:04<02:22,  1.95it/s]2024-04-23 14:23:10,375 [INFO] Calculating random alignmentsfor pair Ampari/JamsayGourou.
# RANDOM CORRESPONDENCE CALCULATION:   4%|█▋                                          | 11/288.0 [00:05<02:24,  1.92it/s]2024-04-23 14:23:10,912 [INFO] Calculating random alignmentsfor pair Ampari/JamsayMondoro.
# RANDOM CORRESPONDENCE CALCULATION:   4%|█▊                                          | 12/288.0 [00:05<01:59,  2.30it/s]2024-04-23 14:23:11,148 [INFO] Calculating random alignmentsfor pair Ampari/Mombo.
# RANDOM CORRESPONDENCE CALCULATION:   5%|█▉                                          | 13/288.0 [00:06<02:09,  2.13it/s]2024-04-23 14:23:11,699 [INFO] Calculating random alignmentsfor pair Ampari/Nanga.
# RANDOM CORRESPONDENCE CALCULATION:   5%|██▏                                         | 14/288.0 [00:06<02:12,  2.07it/s]2024-04-23 14:23:12,213 [INFO] Calculating random alignmentsfor pair Ampari/Penange.
# RANDOM CORRESPONDENCE CALCULATION:   5%|██▎                                         | 15/288.0 [00:07<02:13,  2.04it/s]2024-04-23 14:23:12,721 [INFO] Calculating random alignmentsfor pair Ampari/PergeTegu.
# RANDOM CORRESPONDENCE CALCULATION:   6%|██▍                                         | 16/288.0 [00:07<02:21,  1.92it/s]2024-04-23 14:23:13,311 [INFO] Calculating random alignmentsfor pair Ampari/TebulUre.
# RANDOM CORRESPONDENCE CALCULATION:   6%|██▌                                         | 17/288.0 [00:08<02:20,  1.93it/s]2024-04-23 14:23:13,823 [INFO] Calculating random alignmentsfor pair Ampari/Tiranige.
# RANDOM CORRESPONDENCE CALCULATION:   6%|██▊                                         | 18/288.0 [00:08<02:17,  1.96it/s]2024-04-23 14:23:14,318 [INFO] Calculating random alignmentsfor pair Ampari/TogoKan.
# RANDOM CORRESPONDENCE CALCULATION:   7%|██▉                                         | 19/288.0 [00:09<02:16,  1.98it/s]2024-04-23 14:23:14,812 [INFO] Calculating random alignmentsfor pair Ampari/TommoSoTongoTongo.
# RANDOM CORRESPONDENCE CALCULATION:   7%|███                                         | 20/288.0 [00:10<02:24,  1.86it/s]2024-04-23 14:23:15,426 [INFO] Calculating random alignmentsfor pair Ampari/TomoKanDiangassagou.
# 2024-04-23 14:23:15,465 [INFO] Calculating random alignmentsfor pair Ampari/TomoKanSegue.
# RANDOM CORRESPONDENCE CALCULATION:   8%|███▎                                        | 22/288.0 [00:10<01:25,  3.11it/s]2024-04-23 14:23:15,566 [INFO] Calculating random alignmentsfor pair Ampari/ToroTegu.
# RANDOM CORRESPONDENCE CALCULATION:   8%|███▌                                        | 23/288.0 [00:10<01:37,  2.71it/s]2024-04-23 14:23:16,078 [INFO] Calculating random alignmentsfor pair Ampari/YandaDom.
# RANDOM CORRESPONDENCE CALCULATION:   8%|███▋                                        | 24/288.0 [00:11<01:50,  2.40it/s]2024-04-23 14:23:16,630 [INFO] Calculating random alignmentsfor pair Ampari/YornoSo.
# RANDOM CORRESPONDENCE CALCULATION:   9%|███▊                                        | 25/288.0 [00:11<01:51,  2.36it/s]2024-04-23 14:23:17,069 [INFO] Calculating random alignmentsfor pair BankanTey/BankanTey.
# RANDOM CORRESPONDENCE CALCULATION:   9%|███▉                                        | 26/288.0 [00:12<02:26,  1.79it/s]2024-04-23 14:23:17,982 [INFO] Calculating random alignmentsfor pair BankanTey/BenTey.
# RANDOM CORRESPONDENCE CALCULATION:   9%|████▏                                       | 27/288.0 [00:13<02:47,  1.56it/s]2024-04-23 14:23:18,822 [INFO] Calculating random alignmentsfor pair BankanTey/BonduSoNajamba.
# RANDOM CORRESPONDENCE CALCULATION:  10%|████▎                                       | 28/288.0 [00:14<03:07,  1.38it/s]2024-04-23 14:23:19,746 [INFO] Calculating random alignmentsfor pair BankanTey/Bunoge.
# RANDOM CORRESPONDENCE CALCULATION:  10%|████▍                                       | 29/288.0 [00:15<03:13,  1.34it/s]2024-04-23 14:23:20,558 [INFO] Calculating random alignmentsfor pair BankanTey/DogulDomBendiely.
# RANDOM CORRESPONDENCE CALCULATION:  10%|████▌                                       | 30/288.0 [00:15<03:18,  1.30it/s]2024-04-23 14:23:21,378 [INFO] Calculating random alignmentsfor pair BankanTey/DogulDomKundialang.
# RANDOM CORRESPONDENCE CALCULATION:  11%|████▋                                       | 31/288.0 [00:16<03:15,  1.31it/s]2024-04-23 14:23:22,118 [INFO] Calculating random alignmentsfor pair BankanTey/DonnoSo.
# RANDOM CORRESPONDENCE CALCULATION:  11%|████▉                                       | 32/288.0 [00:17<03:16,  1.30it/s]2024-04-23 14:23:22,902 [INFO] Calculating random alignmentsfor pair BankanTey/JamsayDouentza.
# RANDOM CORRESPONDENCE CALCULATION:  11%|█████                                       | 33/288.0 [00:18<03:18,  1.28it/s]2024-04-23 14:23:23,711 [INFO] Calculating random alignmentsfor pair BankanTey/JamsayGourou.
# RANDOM CORRESPONDENCE CALCULATION:  12%|█████▏                                      | 34/288.0 [00:19<03:15,  1.30it/s]2024-04-23 14:23:24,462 [INFO] Calculating random alignmentsfor pair BankanTey/JamsayMondoro.
# RANDOM CORRESPONDENCE CALCULATION:  12%|█████▎                                      | 35/288.0 [00:19<03:00,  1.40it/s]2024-04-23 14:23:25,043 [INFO] Calculating random alignmentsfor pair BankanTey/Mombo.
# RANDOM CORRESPONDENCE CALCULATION:  12%|█████▌                                      | 36/288.0 [00:20<03:14,  1.30it/s]2024-04-23 14:23:25,947 [INFO] Calculating random alignmentsfor pair BankanTey/Nanga.
# RANDOM CORRESPONDENCE CALCULATION:  13%|█████▋                                      | 37/288.0 [00:21<03:20,  1.25it/s]2024-04-23 14:23:26,813 [INFO] Calculating random alignmentsfor pair BankanTey/Penange.
# RANDOM CORRESPONDENCE CALCULATION:  13%|█████▊                                      | 38/288.0 [00:22<03:27,  1.20it/s]2024-04-23 14:23:27,715 [INFO] Calculating random alignmentsfor pair BankanTey/PergeTegu.
# RANDOM CORRESPONDENCE CALCULATION:  14%|█████▉                                      | 39/288.0 [00:23<03:24,  1.22it/s]2024-04-23 14:23:28,516 [INFO] Calculating random alignmentsfor pair BankanTey/TebulUre.
# RANDOM CORRESPONDENCE CALCULATION:  14%|██████                                      | 40/288.0 [00:23<03:12,  1.29it/s]2024-04-23 14:23:29,188 [INFO] Calculating random alignmentsfor pair BankanTey/Tiranige.
# RANDOM CORRESPONDENCE CALCULATION:  14%|██████▎                                     | 41/288.0 [00:24<03:07,  1.32it/s]2024-04-23 14:23:29,901 [INFO] Calculating random alignmentsfor pair BankanTey/TogoKan.
# RANDOM CORRESPONDENCE CALCULATION:  15%|██████▍                                     | 42/288.0 [00:25<03:07,  1.31it/s]2024-04-23 14:23:30,669 [INFO] Calculating random alignmentsfor pair BankanTey/TommoSoTongoTongo.
# RANDOM CORRESPONDENCE CALCULATION:  15%|██████▌                                     | 43/288.0 [00:26<03:14,  1.26it/s]2024-04-23 14:23:31,537 [INFO] Calculating random alignmentsfor pair BankanTey/TomoKanDiangassagou.
# RANDOM CORRESPONDENCE CALCULATION:  15%|██████▋                                     | 44/288.0 [00:27<03:29,  1.16it/s]2024-04-23 14:23:32,552 [INFO] Calculating random alignmentsfor pair BankanTey/TomoKanSegue.
# RANDOM CORRESPONDENCE CALCULATION:  16%|██████▉                                     | 45/288.0 [00:28<03:28,  1.17it/s]2024-04-23 14:23:33,407 [INFO] Calculating random alignmentsfor pair BankanTey/ToroTegu.
# RANDOM CORRESPONDENCE CALCULATION:  16%|███████                                     | 46/288.0 [00:28<03:31,  1.15it/s]2024-04-23 14:23:34,311 [INFO] Calculating random alignmentsfor pair BankanTey/YandaDom.
# RANDOM CORRESPONDENCE CALCULATION:  16%|███████▏                                    | 47/288.0 [00:29<03:23,  1.18it/s]2024-04-23 14:23:35,096 [INFO] Calculating random alignmentsfor pair BankanTey/YornoSo.
# RANDOM CORRESPONDENCE CALCULATION:  17%|███████▎                                    | 48/288.0 [00:30<03:18,  1.21it/s]2024-04-23 14:23:35,878 [INFO] Calculating random alignmentsfor pair BenTey/BenTey.
# RANDOM CORRESPONDENCE CALCULATION:  17%|███████▍                                    | 49/288.0 [00:31<03:19,  1.20it/s]2024-04-23 14:23:36,725 [INFO] Calculating random alignmentsfor pair BenTey/BonduSoNajamba.
# RANDOM CORRESPONDENCE CALCULATION:  17%|███████▋                                    | 50/288.0 [00:32<03:31,  1.13it/s]2024-04-23 14:23:37,743 [INFO] Calculating random alignmentsfor pair BenTey/Bunoge.
# RANDOM CORRESPONDENCE CALCULATION:  18%|███████▊                                    | 51/288.0 [00:33<03:25,  1.16it/s]2024-04-23 14:23:38,554 [INFO] Calculating random alignmentsfor pair BenTey/DogulDomBendiely.
# RANDOM CORRESPONDENCE CALCULATION:  18%|███████▉                                    | 52/288.0 [00:33<03:13,  1.22it/s]2024-04-23 14:23:39,275 [INFO] Calculating random alignmentsfor pair BenTey/DogulDomKundialang.
# RANDOM CORRESPONDENCE CALCULATION:  18%|████████                                    | 53/288.0 [00:34<03:06,  1.26it/s]2024-04-23 14:23:40,002 [INFO] Calculating random alignmentsfor pair BenTey/DonnoSo.
# RANDOM CORRESPONDENCE CALCULATION:  19%|████████▎                                   | 54/288.0 [00:35<03:14,  1.21it/s]2024-04-23 14:23:40,915 [INFO] Calculating random alignmentsfor pair BenTey/JamsayDouentza.
# RANDOM CORRESPONDENCE CALCULATION:  19%|████████▍                                   | 55/288.0 [00:36<03:13,  1.20it/s]2024-04-23 14:23:41,755 [INFO] Calculating random alignmentsfor pair BenTey/JamsayGourou.
# ...
# 2024-04-23 14:27:02,767 [INFO] Analyzing words for concept <spread out, separate (legs, arms)>.
# 2024-04-23 14:27:02,781 [INFO] Analyzing words for concept <square, rectangle>.
# 2024-04-23 14:27:02,787 [INFO] Analyzing words for concept <squash>.
# 2024-04-23 14:27:02,795 [INFO] Analyzing words for concept <squat>.
# SEQUENCE CLUSTERING:  83%|████████████████████████████████████████████████▊          | 783/947 [00:09<00:02, 72.83it/s]2024-04-23 14:27:02,815 [INFO] Analyzing words for concept <squeeze, mash (sth. soft)>.
# 2024-04-23 14:27:02,823 [INFO] Analyzing words for concept <stand, be in standing position>.
# 2024-04-23 14:27:02,830 [INFO] Analyzing words for concept <star>.
# 2024-04-23 14:27:02,848 [INFO] Analyzing words for concept <statuette>.
# 2024-04-23 14:27:02,864 [INFO] Analyzing words for concept <steal (sth)>.
# 2024-04-23 14:27:02,876 [INFO] Analyzing words for concept <step-father>.
# 2024-04-23 14:27:02,882 [INFO] Analyzing words for concept <step-mother, mother's co-wife>.
# 2024-04-23 14:27:02,887 [INFO] Analyzing words for concept <stingy, miserly (with money)>.
# 2024-04-23 14:27:02,895 [INFO] Analyzing words for concept <stink, smell bad>.
# 2024-04-23 14:27:02,900 [INFO] Analyzing words for concept <stomach>.
# SEQUENCE CLUSTERING:  84%|█████████████████████████████████████████████████▍         | 793/947 [00:09<00:01, 78.31it/s]2024-04-23 14:27:02,922 [INFO] Analyzing words for concept <stone, rock>.
# 2024-04-23 14:27:02,940 [INFO] Analyzing words for concept <storm, wind and rain>.
# 2024-04-23 14:27:02,946 [INFO] Analyzing words for concept <straight (object)>.
# 2024-04-23 14:27:02,953 [INFO] Analyzing words for concept <straight and long or tall (staff, tree, person)>.
# 2024-04-23 14:27:02,954 [INFO] Analyzing words for concept <straight, direct (road)>.
# 2024-04-23 14:27:02,960 [INFO] Analyzing words for concept <strangle>.
# 2024-04-23 14:27:02,969 [INFO] Analyzing words for concept <stretch (e.g. animal hide, slingshot) out to its full length by pulling>.
# 2024-04-23 14:27:02,977 [INFO] Analyzing words for concept <stroll (noun), (a) walk>.
# 2024-04-23 14:27:02,987 [INFO] Analyzing words for concept <stroll, take (a walk) (verb only)>.
# 2024-04-23 14:27:03,001 [INFO] Analyzing words for concept <study (verb only)>.
# 2024-04-23 14:27:03,007 [INFO] Analyzing words for concept <stump (of a chopped-down tree)>.
# SEQUENCE CLUSTERING:  85%|██████████████████████████████████████████████████         | 804/947 [00:09<00:01, 84.10it/s]2024-04-23 14:27:03,033 [INFO] Analyzing words for concept <stutter (verb only)>.
# 2024-04-23 14:27:03,042 [INFO] Analyzing words for concept <suck (e.g. candy)>.
# 2024-04-23 14:27:03,053 [INFO] Analyzing words for concept <sugar>.
# 2024-04-23 14:27:03,084 [INFO] Analyzing words for concept <sugar cane>.
# 2024-04-23 14:27:03,106 [INFO] Analyzing words for concept <sun>.
# 2024-04-23 14:27:03,121 [INFO] Analyzing words for concept <supper>.
# 2024-04-23 14:27:03,154 [INFO] Analyzing words for concept <swallow>.
# 2024-04-23 14:27:03,168 [INFO] Analyzing words for concept <swear (verb only)>.
# 2024-04-23 14:27:03,177 [INFO] Analyzing words for concept <sweep (ground, courtyard)>.
# SEQUENCE CLUSTERING:  86%|██████████████████████████████████████████████████▋        | 813/947 [00:10<00:01, 74.24it/s]2024-04-23 14:27:03,191 [INFO] Analyzing words for concept <sweet potato>.
# 2024-04-23 14:27:03,226 [INFO] Analyzing words for concept <sweet, sugary (taste)>.
# 2024-04-23 14:27:03,238 [INFO] Analyzing words for concept <swim (verb only)>.
# 2024-04-23 14:27:03,244 [INFO] Analyzing words for concept <sword, saber (any type)>.
# 2024-04-23 14:27:03,259 [INFO] Analyzing words for concept <table, selling stand>.
# 2024-04-23 14:27:03,270 [INFO] Analyzing words for concept <tail (of dog, sheep, etc.)>.
# 2024-04-23 14:27:03,281 [INFO] Analyzing words for concept <tail (of scorpion)>.
# 2024-04-23 14:27:03,289 [INFO] Analyzing words for concept <take (sth) (general word)>.
# SEQUENCE CLUSTERING:  87%|███████████████████████████████████████████████████▏       | 821/947 [00:10<00:01, 74.02it/s]2024-04-23 14:27:03,300 [INFO] Analyzing words for concept <take a bath or shower, bathe>.
# 2024-04-23 14:27:03,315 [INFO] Analyzing words for concept <talk (noun), speech, words>.
# 2024-04-23 14:27:03,325 [INFO] Analyzing words for concept <taste (a food, etc.)>.
# 2024-04-23 14:27:03,336 [INFO] Analyzing words for concept <taste (sth, by licking)>.
# 2024-04-23 14:27:03,337 [INFO] Analyzing words for concept <tax>.
# 2024-04-23 14:27:03,351 [INFO] Analyzing words for concept <tea-making gear (burner, kettle, etc.)>.
# 2024-04-23 14:27:03,364 [INFO] Analyzing words for concept <teach, instruct (sb, how to do sth)>.
# 2024-04-23 14:27:03,371 [INFO] Analyzing words for concept <tears (liquid)>.
# 2024-04-23 14:27:03,377 [INFO] Analyzing words for concept <temple, side of eye>.
# 2024-04-23 14:27:03,383 [INFO] Analyzing words for concept <ten>.
# 2024-04-23 14:27:03,393 [INFO] Analyzing words for concept <tent>.
# SEQUENCE CLUSTERING:  88%|███████████████████████████████████████████████████▊       | 832/947 [00:10<00:01, 82.49it/s]2024-04-23 14:27:03,403 [INFO] Analyzing words for concept <testicles>.
# 2024-04-23 14:27:03,419 [INFO] Analyzing words for concept <the day after tomorrow>.
# 2024-04-23 14:27:03,431 [INFO] Analyzing words for concept <thick (planar object, e.g. wall)>.
# 2024-04-23 14:27:03,440 [INFO] Analyzing words for concept <thief>.
# 2024-04-23 14:27:03,464 [INFO] Analyzing words for concept <thigh, upper leg (of person)>.
# 2024-04-23 14:27:03,474 [INFO] Analyzing words for concept <thing (general term)>.
# 2024-04-23 14:27:03,487 [INFO] Analyzing words for concept <third (ordinal)>.
# 2024-04-23 14:27:03,500 [INFO] Analyzing words for concept <thirst>.
# 2024-04-23 14:27:03,519 [INFO] Analyzing words for concept <thousand>.
# SEQUENCE CLUSTERING:  89%|████████████████████████████████████████████████████▍      | 841/947 [00:10<00:01, 77.83it/s]2024-04-23 14:27:03,536 [INFO] Analyzing words for concept <thread (any kind)>.
# 2024-04-23 14:27:03,546 [INFO] Analyzing words for concept <threaten (scare)>.
# 2024-04-23 14:27:03,551 [INFO] Analyzing words for concept <three>.
# 2024-04-23 14:27:03,565 [INFO] Analyzing words for concept <three times>.
# 2024-04-23 14:27:03,590 [INFO] Analyzing words for concept <thresh by pounding hard (rice, occasionally millet) with large clubs on the ground or on a mat>.
# 2024-04-23 14:27:03,595 [INFO] Analyzing words for concept <throat (exterior)>.
# 2024-04-23 14:27:03,601 [INFO] Analyzing words for concept <throat (interior)>.
# 2024-04-23 14:27:03,623 [INFO] Analyzing words for concept <throw (e.g. stone)>.
# 2024-04-23 14:27:03,634 [INFO] Analyzing words for concept <thumb>.
# SEQUENCE CLUSTERING:  90%|████████████████████████████████████████████████████▉      | 850/947 [00:10<00:01, 78.75it/s]2024-04-23 14:27:03,647 [INFO] Analyzing words for concept <thunder (noun)>.
# 2024-04-23 14:27:03,669 [INFO] Analyzing words for concept <tie, tie up (sth or sb, with a rope)>.
# 2024-04-23 14:27:03,682 [INFO] Analyzing words for concept <time, moment in time>.
# 2024-04-23 14:27:03,737 [INFO] Analyzing words for concept <tobacco (leaves, or for cigarettes)>.
# 2024-04-23 14:27:03,746 [INFO] Analyzing words for concept <tobacco pipe>.
# 2024-04-23 14:27:03,760 [INFO] Analyzing words for concept <today>.
# 2024-04-23 14:27:03,765 [INFO] Analyzing words for concept <toe>.
# 2024-04-23 14:27:03,781 [INFO] Analyzing words for concept <tomorrow>.
# 2024-04-23 14:27:03,790 [INFO] Analyzing words for concept <tongs (blacksmith's large pliers-like instrument)>.
# SEQUENCE CLUSTERING:  91%|█████████████████████████████████████████████████████▌     | 859/947 [00:10<00:01, 72.14it/s]2024-04-23 14:27:03,797 [INFO] Analyzing words for concept <tongue>.
# 2024-04-23 14:27:03,815 [INFO] Analyzing words for concept <tooth>.
# 2024-04-23 14:27:03,830 [INFO] Analyzing words for concept <touch (with hand)>.
# 2024-04-23 14:27:03,841 [INFO] Analyzing words for concept <trap>.
# 2024-04-23 14:27:03,854 [INFO] Analyzing words for concept <tree bark>.
# 2024-04-23 14:27:03,882 [INFO] Analyzing words for concept <tree or large woody shrub>.
# 2024-04-23 14:27:03,902 [INFO] Analyzing words for concept <trough (of wood or metal, for drinking or to beat as a drum)>.
# 2024-04-23 14:27:03,914 [INFO] Analyzing words for concept <trunk (of tree)>.
# SEQUENCE CLUSTERING:  92%|██████████████████████████████████████████████████████     | 867/947 [00:10<00:01, 69.41it/s]2024-04-23 14:27:03,922 [INFO] Analyzing words for concept <turn off (light)>.
# 2024-04-23 14:27:03,928 [INFO] Analyzing words for concept <turn on (lights)>.
# 2024-04-23 14:27:03,945 [INFO] Analyzing words for concept <turn over (earth in field, with daba, to hold rainwater or to weed around peanut plants)>.
# 2024-04-23 14:27:03,953 [INFO] Analyzing words for concept <twelve>.
# 2024-04-23 14:27:03,973 [INFO] Analyzing words for concept <twenty>.
# 2024-04-23 14:27:03,987 [INFO] Analyzing words for concept <twice>.
# 2024-04-23 14:27:04,003 [INFO] Analyzing words for concept <twin (person)>.
# 2024-04-23 14:27:04,019 [INFO] Analyzing words for concept <two>.
# SEQUENCE CLUSTERING:  92%|██████████████████████████████████████████████████████▌    | 875/947 [00:10<00:01, 70.65it/s]2024-04-23 14:27:04,034 [INFO] Analyzing words for concept <udder>.
# 2024-04-23 14:27:04,042 [INFO] Analyzing words for concept <ugly>.
# 2024-04-23 14:27:04,055 [INFO] Analyzing words for concept <un>.
# 2024-04-23 14:27:04,055 [INFO] Analyzing words for concept <understand>.
# 2024-04-23 14:27:04,069 [INFO] Analyzing words for concept <unripe (fruit)>.
# 2024-04-23 14:27:04,082 [INFO] Analyzing words for concept <unripe (grain)>.
# 2024-04-23 14:27:04,092 [INFO] Analyzing words for concept <untie, undo, loosen (knot)>.
# 2024-04-23 14:27:04,106 [INFO] Analyzing words for concept <urinate, have a piss>.
# SEQUENCE CLUSTERING:  93%|███████████████████████████████████████████████████████    | 883/947 [00:10<00:00, 71.05it/s]2024-04-23 14:27:04,143 [INFO] Analyzing words for concept <vegetable garden>.
# 2024-04-23 14:27:04,155 [INFO] Analyzing words for concept <village, town, settlement>.
# 2024-04-23 14:27:04,167 [INFO] Analyzing words for concept <voice (of sb), characteristic call (of animal)>.
# 2024-04-23 14:27:04,172 [INFO] Analyzing words for concept <vomir, emit vomit>.
# 2024-04-23 14:27:04,193 [INFO] Analyzing words for concept <wake up, awaken>.
# 2024-04-23 14:27:04,201 [INFO] Analyzing words for concept <wall (of house)>.
# 2024-04-23 14:27:04,219 [INFO] Analyzing words for concept <want, like, love (sth)>.
# 2024-04-23 14:27:04,226 [INFO] Analyzing words for concept <wash (clothing)>.
# 2024-04-23 14:27:04,237 [INFO] Analyzing words for concept <wash (one's hands)>.
# SEQUENCE CLUSTERING:  94%|███████████████████████████████████████████████████████▌   | 892/947 [00:11<00:00, 76.08it/s]2024-04-23 14:27:04,242 [INFO] Analyzing words for concept <wash (pots, knives, etc.)>.
# 2024-04-23 14:27:04,249 [INFO] Analyzing words for concept <water>.
# 2024-04-23 14:27:04,259 [INFO] Analyzing words for concept <waves (of water)>.
# 2024-04-23 14:27:04,263 [INFO] Analyzing words for concept <weak, feeble (person or animal)>.
# 2024-04-23 14:27:04,270 [INFO] Analyzing words for concept <weave (fabric, from cotton thread)>.
# 2024-04-23 14:27:04,280 [INFO] Analyzing words for concept <week>.
# 2024-04-23 14:27:04,291 [INFO] Analyzing words for concept <weep (verb only)>.
# 2024-04-23 14:27:04,300 [INFO] Analyzing words for concept <west>.
# 2024-04-23 14:27:04,326 [INFO] Analyzing words for concept <wet (adjective)>.
# 2024-04-23 14:27:04,339 [INFO] Analyzing words for concept <what?>.
# SEQUENCE CLUSTERING:  95%|████████████████████████████████████████████████████████▏  | 902/947 [00:11<00:00, 80.65it/s]2024-04-23 14:27:04,353 [INFO] Analyzing words for concept <wheat>.
# 2024-04-23 14:27:04,362 [INFO] Analyzing words for concept <when? (at what time?)>.
# 2024-04-23 14:27:04,402 [INFO] Analyzing words for concept <where? (location)>.
# 2024-04-23 14:27:04,413 [INFO] Analyzing words for concept <which?>.
# 2024-04-23 14:27:04,424 [INFO] Analyzing words for concept <whisper (verb only)>.
# 2024-04-23 14:27:04,428 [INFO] Analyzing words for concept <whistle (from the mouth) (verb only)>.
# 2024-04-23 14:27:04,438 [INFO] Analyzing words for concept <white, light-colored>.
# 2024-04-23 14:27:04,455 [INFO] Analyzing words for concept <who?>.
# 2024-04-23 14:27:04,460 [INFO] Analyzing words for concept <why?>.
# SEQUENCE CLUSTERING:  96%|████████████████████████████████████████████████████████▊  | 911/947 [00:11<00:00, 73.48it/s]2024-04-23 14:27:04,502 [INFO] Analyzing words for concept <wide (passageway)>.
# 2024-04-23 14:27:04,510 [INFO] Analyzing words for concept <widow (not yet remarried)>.
# 2024-04-23 14:27:04,523 [INFO] Analyzing words for concept <widower>.
# 2024-04-23 14:27:04,529 [INFO] Analyzing words for concept <wife>.
# 2024-04-23 14:27:04,535 [INFO] Analyzing words for concept <wind (airflow)>.
# 2024-04-23 14:27:04,551 [INFO] Analyzing words for concept <window (full-sized)>.
# 2024-04-23 14:27:04,564 [INFO] Analyzing words for concept <wing (of bird)>.
# 2024-04-23 14:27:04,582 [INFO] Analyzing words for concept <witness (person)>.
# 2024-04-23 14:27:04,594 [INFO] Analyzing words for concept <woman, female person>.
# SEQUENCE CLUSTERING:  97%|█████████████████████████████████████████████████████████▎ | 920/947 [00:11<00:00, 76.96it/s]2024-04-23 14:27:04,605 [INFO] Analyzing words for concept <womb>.
# 2024-04-23 14:27:04,617 [INFO] Analyzing words for concept <wood>.
# 2024-04-23 14:27:04,629 [INFO] Analyzing words for concept <wooden board, plank>.
# 2024-04-23 14:27:04,635 [INFO] Analyzing words for concept <wool (substance)>.
# 2024-04-23 14:27:04,636 [INFO] Analyzing words for concept <word, name (of sth)>.
# 2024-04-23 14:27:04,641 [INFO] Analyzing words for concept <work (noun), productive activity>.
# 2024-04-23 14:27:04,650 [INFO] Analyzing words for concept <work in the fields, do farm work (verb only)>.
# 2024-04-23 14:27:04,660 [INFO] Analyzing words for concept <world (of the living)>.
# 2024-04-23 14:27:04,692 [INFO] Analyzing words for concept <worn out, old, no longer useful (object)>.
# SEQUENCE CLUSTERING:  98%|█████████████████████████████████████████████████████████▉ | 929/947 [00:11<00:00, 80.46it/s]2024-04-23 14:27:04,703 [INFO] Analyzing words for concept <worship (God)>.
# 2024-04-23 14:27:04,711 [INFO] Analyzing words for concept <wound, injury>.
# 2024-04-23 14:27:04,726 [INFO] Analyzing words for concept <wrinkled (adjective)>.
# 2024-04-23 14:27:04,728 [INFO] Analyzing words for concept <wrist>.
# 2024-04-23 14:27:04,740 [INFO] Analyzing words for concept <write (sth)>.
# 2024-04-23 14:27:04,751 [INFO] Analyzing words for concept <yam (Dioscorea)>.
# 2024-04-23 14:27:04,758 [INFO] Analyzing words for concept <yawn (verb only)>.
# 2024-04-23 14:27:04,768 [INFO] Analyzing words for concept <year>.
# 2024-04-23 14:27:04,786 [INFO] Analyzing words for concept <yell, shout loudly (e.g. a general warning, to anyone within earshot)>.
# 2024-04-23 14:27:04,788 [INFO] Analyzing words for concept <yellow>.
# SEQUENCE CLUSTERING:  99%|██████████████████████████████████████████████████████████▌| 939/947 [00:11<00:00, 83.33it/s]2024-04-23 14:27:04,815 [INFO] Analyzing words for concept <yes!>.
# 2024-04-23 14:27:04,825 [INFO] Analyzing words for concept <yesterday>.
# 2024-04-23 14:27:04,833 [INFO] Analyzing words for concept <yoke wrapped in cloth around donkey's neck and tied by a rope to the two long poles of a cart>.
# 2024-04-23 14:27:04,873 [INFO] Analyzing words for concept <young>.
# 2024-04-23 14:27:04,884 [INFO] Analyzing words for concept <young (adolescent) man, not yet bearded>.
# 2024-04-23 14:27:04,885 [INFO] Analyzing words for concept <young (adolescent) woman, not yet a mother>.
# 2024-04-23 14:27:04,889 [INFO] Analyzing words for concept <younger brother (of man or woman)>.
# 2024-04-23 14:27:04,890 [INFO] Analyzing words for concept <younger sister (of a woman)>.
# 2024-04-23 14:27:05,548 [INFO] Data has been written to file <part_beginining_clusters.tsv>.

# %% [markdown]
# # ALIGNMENTS

# %%
part=Partial("new_beginining_clusters.tsv")
alm = Alignments(part, ref='cogid')
alm.align()
alm.output("html", filename='part_beginining_alignments', subset=True,
cols=['doculect', 'concept', 'ipa', 'tokens', 'cogid', 'alignment'],
prettify=False, ignore='all')
# Out:
# 2024-04-23 14:28:44,194 [INFO] Data has been written to file <C:\Users\PROMIS~1\AppData\Local\Temp\tmp9y24oup7.alm>.
# 2024-04-23 14:28:48,462 [INFO] Data has been written to file <part_beginining_alignments.html>.
